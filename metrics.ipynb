# %%
import pandas as pd
import ast

import glob
import os

# %%
csv_files = glob.glob('outputs/processed_outputs/*_processed.csv')  # replace with your actual directory path
csv_files
# Out:
# ['outputs/processed_outputs/qiita_processed.csv',
#  'outputs/processed_outputs/clinepidb_processed.csv',
#  'outputs/processed_outputs/accessclinicaldata_processed.csv',
#  'outputs/processed_outputs/dryad_processed.csv',
#  'outputs/processed_outputs/immport_processed.csv',
#  'outputs/processed_outputs/harvard_processed.csv',
#  'outputs/processed_outputs/vdjserver_processed.csv',
#  'outputs/processed_outputs/hubmap_processed.csv',
#  'outputs/processed_outputs/datadiscoveryengine_processed.csv',
#  'outputs/processed_outputs/lincs_processed.csv',
#  'outputs/processed_outputs/mendeley_processed.csv',
#  'outputs/processed_outputs/ncbi_geo_processed.csv',
#  'outputs/processed_outputs/ncbi_sra_processed.csv',
#  'outputs/processed_outputs/omicsdi_processed.csv',
#  'outputs/processed_outputs/reframedb_processed.csv',
#  'outputs/processed_outputs/veupathdb_processed.csv',
#  'outputs/processed_outputs/vivli_processed.csv',
#  'outputs/processed_outputs/zenodo_processed.csv']

# %%
repositories = {
    'accessclinicaldata': 'AccessClinicalData@NIAID',
    'clinepidb': 'ClinEpiDB',
    'datadiscoveryengine': 'Data Discovery Engine',
    'dryad': 'Dryad Digital Repository',
    'harvard': 'Harvard Dataverse',
    'hubmap': 'HuBMAP',
    'immport': 'ImmPort',
    'lincs': 'LINCS',
    'mendeley': 'Mendeley',
    'ncbi_geo':'NCBI GEO',
    'ncbi_sra': 'NCBI SRA',
    'omicsdi': 'Omics Discovery Index (OmicsDI)',
    'qiita': 'Qiita',
    'reframedb': 'ReframeDB',
    'vdjserver': 'VDJServer',
    'veupathdb': 'VEuPathDB',
    'vivli': 'Vivli',
    'zenodo': 'Zenodo'
}

# %%
# Read each CSV file, add a 'filename' column, and store them in a list
dfs = [pd.read_csv(f,lineterminator='\n').assign(Repository=repositories[os.path.basename(f).replace('_processed.csv', '')]) for f in csv_files]

# Concatenate all dataframes in the list into one dataframe
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df['Predictions'] = combined_df['Predictions'].apply(ast.literal_eval)

# %%
combined_df
# Out:
#                                                       Name  \
# 0        Understanding Cultivar-Specificity and Soil De...
# 1                The microbiome of uncontacted Amerindians
# 2        Changes in Microbial Ecology after Fecal Micro...
# 3                                           Fleshner tMM45
# 4        The Fecal Microbial Community of Breast-fed In...
# ...                                                    ...
# 2764275  IN00034 Kahaum Pillar Inscription of the Time ...
# 2764276               Infant Sibling Project: Sample Files
# 2764277  IN00037 Supia Pillar Inscription of the Time o...
# 2764278  KC0P 40 m SEQP Reverse Beacon Network Log of S...
# 2764279  Global Labour Journal, Editors' Introduction (...
#
#                                                Description          Model  \
# 0        This is a preliminary study to examine the mic...  gpt-3.5-turbo
# 1        Most studies of the human microbiome have focu...  gpt-3.5-turbo
# 2        Gut microbiota play a key role in maintaining ...  gpt-3.5-turbo
# 3        We hypothesize the wheel running may change th...  gpt-3.5-turbo
# 4        Oligosaccharides from breast milk are believed...  gpt-3.5-turbo
# ...                                                    ...            ...
# 2764275  Bhandarkar, Devadatta Ramakrishna, Bahadur Cha...  gpt-3.5-turbo
# 2764276  These electroencephalography (EEG) data files ...  gpt-3.5-turbo
# 2764277  Bhandarkar, Devadatta Ramakrishna, Bahadur Cha...  gpt-3.5-turbo
# 2764278  Log of the Spots generated by the Reverse Beac...  gpt-3.5-turbo
# 2764279  2015. "Editors' Introduction." Global Labour J...  gpt-3.5-turbo
#
#                                                Predictions  \
# 0        {Plant biology, Microbiology, Agricultural sci...
# 1        {Antimicrobial Resistance, Microbiology, Metag...
# 2        {Infectious disease, Gastroenterology, Microbi...
# 3                    {Biology, Microbiology, Animal study}
# 4         {Microbiology, Genetics, Environmental sciences}
# ...                                                    ...
# 2764275                                                 {}
# 2764276  {Data integration and warehousing, Electroence...
# 2764277                                                 {}
# 2764278  {Computational biology, Data mining, Machine l...
# 2764279                  {Ecology, Environmental sciences}
#
#                                      Hallucinations  \
# 0                                  {'Soil science'}
# 1                                             set()
# 2                                             set()
# 3                                             set()
# 4                                             set()
# ...                                             ...
# 2764275  {'History', 'Inscriptions', 'Archaeology'}
# 2764276                                       set()
# 2764277     {'Geography', 'History', 'Archaeology'}
# 2764278                                       set()
# 2764279                   {'Science communication'}
#
#                              filepath            _id Repository
# 0         outputs/qiita_processed.csv     qiita_1001      Qiita
# 1         outputs/qiita_processed.csv    qiita_10052      Qiita
# 2         outputs/qiita_processed.csv    qiita_10057      Qiita
# 3         outputs/qiita_processed.csv    qiita_10064      Qiita
# 4         outputs/qiita_processed.csv    qiita_10080      Qiita
# ...                               ...            ...        ...
# 2764275  outputs/zenodo_processed.csv  ZENODO_998956     Zenodo
# 2764276  outputs/zenodo_processed.csv  ZENODO_998964     Zenodo
# 2764277  outputs/zenodo_processed.csv  ZENODO_998987     Zenodo
# 2764278  outputs/zenodo_processed.csv  ZENODO_999020     Zenodo
# 2764279  outputs/zenodo_processed.csv  ZENODO_999851     Zenodo
#
# [2764280 rows x 8 columns]

# %%
# empty_sets = combined_df.groupby('Repository')['Predictions'].apply(lambda x: (x == set()).sum())
# empty_sets

counts = combined_df.groupby('Repository')['Predictions'].apply(lambda x: pd.Series({
    'empty_sets': (x == set()).sum(),
    'sets_of_1': (x.apply(len) == 1).sum(),
    'sets_of_2': (x.apply(len) == 2).sum(),
    'sets_of_3': (x.apply(len) == 3).sum(),
    'total': x.size
}))

# %%
print(counts.to_string())
# Out:
# Repository
# AccessClinicalData@NIAID         empty_sets          0
#                                  sets_of_1           0
#                                  sets_of_2           0
#                                  sets_of_3           7
#                                  total               7
# ClinEpiDB                        empty_sets          0
#                                  sets_of_1           1
#                                  sets_of_2           6
#                                  sets_of_3          43
#                                  total              50
# Data Discovery Engine            empty_sets          0
#                                  sets_of_1           2
#                                  sets_of_2          17
#                                  sets_of_3         349
#                                  total             368
# Dryad Digital Repository         empty_sets        180
#                                  sets_of_1         897
#                                  sets_of_2        5448
#                                  sets_of_3       47569
#                                  total           54208
# Harvard Dataverse                empty_sets      11243
#                                  sets_of_1        9261
#                                  sets_of_2       12649
#                                  sets_of_3       47629
#                                  total           80975
# HuBMAP                           empty_sets          6
#                                  sets_of_1         125
#                                  sets_of_2         107
#                                  sets_of_3        1707
#                                  total            1948
# ImmPort                          empty_sets          1
#                                  sets_of_1           6
#                                  sets_of_2          38
#                                  sets_of_3         661
#                                  total             721
# LINCS                            empty_sets          0
#                                  sets_of_1           1
#                                  sets_of_2           6
#                                  sets_of_3         338
#                                  total             345
# Mendeley                         empty_sets       2733
#                                  sets_of_1        4952
#                                  sets_of_2       10256
#                                  sets_of_3       35730
#                                  total           53828
# NCBI GEO                         empty_sets         21
#                                  sets_of_1         642
#                                  sets_of_2        9921
#                                  sets_of_3      199390
#                                  total          210928
# NCBI SRA                         empty_sets         92
#                                  sets_of_1        3169
#                                  sets_of_2       17606
#                                  sets_of_3      317295
#                                  total          339001
# Omics Discovery Index (OmicsDI)  empty_sets       8202
#                                  sets_of_1       41920
#                                  sets_of_2      184944
#                                  sets_of_3     1561448
#                                  total         1802736
# Qiita                            empty_sets          0
#                                  sets_of_1           4
#                                  sets_of_2          54
#                                  sets_of_3         645
#                                  total             703
# ReframeDB                        empty_sets          0
#                                  sets_of_1           0
#                                  sets_of_2           4
#                                  sets_of_3         135
#                                  total             139
# VDJServer                        empty_sets          0
#                                  sets_of_1           0
#                                  sets_of_2           6
#                                  sets_of_3          59
#                                  total              65
# VEuPathDB                        empty_sets          7
#                                  sets_of_1          89
#                                  sets_of_2         212
#                                  sets_of_3        2695
#                                  total            3005
# Vivli                            empty_sets          3
#                                  sets_of_1         151
#                                  sets_of_2        1140
#                                  sets_of_3        5833
#                                  total            7210
# Zenodo                           empty_sets       5840
#                                  sets_of_1       11495
#                                  sets_of_2       33659
#                                  sets_of_3      156483
#                                  total          208043

# %% [markdown]
# ### Get Name and Descriptions with Word Threshold

# %%
# Calculate the total number of words in the 'Name' and 'Description' columns
word_counts = combined_df.apply(lambda x: len(str(x['Name']).split()) + len(str(x['Description']).split()), axis=1)

# Get rows where the total number of words is in the range 11-20
sample_rows_10 = combined_df[word_counts <= 11].sample(n=25)

# Get rows where the total number of words is in the range 11-20
sample_rows_11_20 = combined_df[(word_counts >= 11) & (word_counts <= 20)].sample(n=25)

# Get rows where the total number of words is in the range 21-30
sample_rows_21_30 = combined_df[(word_counts >= 21) & (word_counts <= 30)].sample(n=25)

# Get rows where the total number of words is in the range 31-40
sample_rows_31_40 = combined_df[(word_counts >= 31) & (word_counts <= 40)].sample(n=25)

sample_rows_10, sample_rows_11_20, sample_rows_21_30, sample_rows_31_40
# Out:
# (                                                      Name  \
#  81751                                       hou02665c01004
#  2408106          Lactiplantibacillus plantarum strain:IRG1
#  1507968                      Listeria monocytogenes SHL015
#  985408                                                 NaN
#  433746   Sequencing INFLUENZA A VIRUS (A/MEMPHIS/3/1973...
#  1021938                                   Escherichia coli
#  1738566                                                NaN
#  1578369                   Cryptococcus neoformans A1-LIM_1
#  88709                                        A07_16248.JPG
#  1653718                                 biofilm metagenome
#  446627                                HMP reference genome
#  1581473           Sphingomonas parapaucimobilis NBRC 15100
#  2695495           Mass spectrometry imaging (MSI) datasets
#  1529806                Arabidopsis thaliana cultivar:Col-0
#  1657875                                Populus trichocarpa
#  494791                   Methanotrophics in grassland soil
#  1700084                    Penicillium expansum strain:P11
#  1574948                                    Corynebacterium
#  466471   Evolution_of_MRSA_in_a_single_institution_over...
#  1050100                                           Bacteria
#  1312918                                       Homo sapiens
#  2355158                       Cutibacterium acnes HL059PA1
#  1739654                 Metschnikowia reukaufii strain:Y41
#  1758450                                                NaN
#  2394955                                         Arthropoda
#
#                                                 Description          Model  \
#  81751                                                    L  gpt-3.5-turbo
#  2408106  Lactobacillus plantarum IRG1 Genome sequencing...  gpt-3.5-turbo
#  1507968  Listeria monocytogenes SHL015 Genome sequencin...  gpt-3.5-turbo
#  985408   Identifying SNPs in the D1RatMgh8 microsatteli...  gpt-3.5-turbo
#  433746                                                 NaN  gpt-3.5-turbo
#  1021938  Carbon nutrition of pathogenic and commensal E...  gpt-3.5-turbo
#  1738566                         Broiler chicken sequencing  gpt-3.5-turbo
#  1578369  Cryptococcus neoformans A1-LIM_1 Transcriptome...  gpt-3.5-turbo
#  88709    Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  1653718                    Responses of biofilm on tamiflu  gpt-3.5-turbo
#  446627                                                 NaN  gpt-3.5-turbo
#  1581473  Sphingomonas parapaucimobilis NBRC 15100 genom...  gpt-3.5-turbo
#  2695495          Mass spectrometry imaging (MSI) datasets.  gpt-3.5-turbo
#  1529806  Arabidopsis thaliana Col-0 wild-type transcrip...  gpt-3.5-turbo
#  1657875             Populus trichocarpa 24777 Resequencing  gpt-3.5-turbo
#  494791                                                 NaN  gpt-3.5-turbo
#  1700084  Penicillium expansum strain:P11 Genome sequencing  gpt-3.5-turbo
#  1574948  Whole genome sequencing of Corynebacterium spe...  gpt-3.5-turbo
#  466471   http://www.sanger.ac.uk/resources/downloads/ba...  gpt-3.5-turbo
#  1050100  Bacterial genomes in TP area, China Genome seq...  gpt-3.5-turbo
#  1312918          Human, multiple tumors Raw sequence reads  gpt-3.5-turbo
#  2355158  Demonstration Project Reference Genome for Hum...  gpt-3.5-turbo
#  1739654  Metschnikowia reukaufii Y41 transcriptome - fu...  gpt-3.5-turbo
#  1758450                        Spartina anglica Microbiome  gpt-3.5-turbo
#  2394955         Arthropoda from Danum Valley metabarcoding  gpt-3.5-turbo
#
#                                                 Predictions  \
#  81751         {Molecular biology, Genetics, Biotechnology}
#  2408106               {Proteomics, Genomics, Microbiology}
#  1507968        {Microbiology, Sequence analysis, Genomics}
#  985408       {Molecular biology, Bioinformatics, Genetics}
#  433746        {Virology, Microbiology, Infectious disease}
#  1021938     {Pathology, Microbiology, Nutritional science}
#  1738566            {Animal study, Biology, Bioinformatics}
#  1578369       {Genetics, Gene expression, Transcriptomics}
#  88709    {Data integration and warehousing, "Data submi...
#  1653718     {Metagenomics, Microbiology, Drug development}
#  446627            {Microbiology, Genetics, Bioinformatics}
#  1581473        {Molecular biology, Microbiology, Genomics}
#  2695495  {Molecular biology, Bioinformatics, Analytical...
#  1529806                   {Plant biology, Transcriptomics}
#  1657875     {Plant biology, Population genetics, Genomics}
#  494791   {Environmental sciences, Microbiology, Agricul...
#  1700084        {Molecular biology, Microbiology, Genomics}
#  1574948    {Computational biology, Microbiology, Genomics}
#  466471   {Antimicrobial Resistance, Infectious disease,...
#  1050100        {Sequence assembly, Microbiology, Genomics}
#  1312918                     {Genetics, Genomics, Oncology}
#  2355158           {Microbiology, Genomics, Bioinformatics}
#  1739654  {Molecular biology, Microbiology, Transcriptom...
#  1758450                  {Microbiology, Genetics, Ecology}
#  2394955             {Zoology, Metabarcoding, Biodiversity}
#
#                     Hallucinations                        filepath  \
#  81751                       set()   outputs/harvard_processed.csv
#  2408106                     set()   outputs/omicsdi_processed.csv
#  1507968                     set()   outputs/omicsdi_processed.csv
#  985408                      set()   outputs/omicsdi_processed.csv
#  433746                      set()  outputs/ncbi_sra_processed.csv
#  1021938                     set()   outputs/omicsdi_processed.csv
#  1738566                     set()   outputs/omicsdi_processed.csv
#  1578369                     set()   outputs/omicsdi_processed.csv
#  88709                       set()   outputs/harvard_processed.csv
#  1653718                     set()   outputs/omicsdi_processed.csv
#  446627                      set()  outputs/ncbi_sra_processed.csv
#  1581473                     set()   outputs/omicsdi_processed.csv
#  2695495                     set()    outputs/zenodo_processed.csv
#  1529806  {'Arabidopsis thaliana'}   outputs/omicsdi_processed.csv
#  1657875                     set()   outputs/omicsdi_processed.csv
#  494791           {'Soil Science'}  outputs/ncbi_sra_processed.csv
#  1700084                     set()   outputs/omicsdi_processed.csv
#  1574948                     set()   outputs/omicsdi_processed.csv
#  466471                      set()  outputs/ncbi_sra_processed.csv
#  1050100                     set()   outputs/omicsdi_processed.csv
#  1312918                     set()   outputs/omicsdi_processed.csv
#  2355158                     set()   outputs/omicsdi_processed.csv
#  1739654                     set()   outputs/omicsdi_processed.csv
#  1758450                     set()   outputs/omicsdi_processed.csv
#  2394955                     set()   outputs/omicsdi_processed.csv
#
#                                    _id                       Repository
#  81751    Dataverse_10.7910_DVN_BA39BT                Harvard Dataverse
#  2408106                   PRJNA428424  Omics Discovery Index (OmicsDI)
#  1507968                   PRJNA218932  Omics Discovery Index (OmicsDI)
#  985408                     PRJEB27381  Omics Discovery Index (OmicsDI)
#  433746             NCBI_SRA_SRP206023                         NCBI SRA
#  1021938                   PRJNA106765  Omics Discovery Index (OmicsDI)
#  1738566                   PRJNA643396  Omics Discovery Index (OmicsDI)
#  1578369                   PRJNA191461  Omics Discovery Index (OmicsDI)
#  88709    Dataverse_10.7910_DVN_EENM6D                Harvard Dataverse
#  1653718                   PRJNA389507  Omics Discovery Index (OmicsDI)
#  446627             NCBI_SRA_SRP044588                         NCBI SRA
#  1581473                      PRJDB328  Omics Discovery Index (OmicsDI)
#  2695495                ZENODO_4920980                           Zenodo
#  1529806                   PRJNA426772  Omics Discovery Index (OmicsDI)
#  1657875                   PRJNA458644  Omics Discovery Index (OmicsDI)
#  494791             NCBI_SRA_ERP020612                         NCBI SRA
#  1700084                   PRJNA606591  Omics Discovery Index (OmicsDI)
#  1574948                   PRJNA541849  Omics Discovery Index (OmicsDI)
#  466471             NCBI_SRA_ERP000708                         NCBI SRA
#  1050100                   PRJNA474356  Omics Discovery Index (OmicsDI)
#  1312918                   PRJNA316379  Omics Discovery Index (OmicsDI)
#  2355158                    PRJNA49215  Omics Discovery Index (OmicsDI)
#  1739654                   PRJNA652973  Omics Discovery Index (OmicsDI)
#  1758450                   PRJNA670606  Omics Discovery Index (OmicsDI)
#  2394955                   PRJNA210806  Omics Discovery Index (OmicsDI)  ,
#                                                        Name  \
#  1558576                     Bombus terrestris RNA-seq data
#  519862   The spread of chloramphenicol resistant Neisse...
#  578189   Reference genome for the Human Microbiome Project
#  1735727                       Brassica rapa cultivar:VT123
#  2400934    Sorghum bicolor strain:R09069 | cultivar:R09069
#  759365                                                 NaN
#  531655        Streptococcus equinus Sb10 genome sequencing
#  418260   Panicum virgatum Gene Expression Profiling - 2...
#  1643893                                    soil metagenome
#  1182217     Panicum virgatum cultivar:FLAME 1047-38-4-3 Pv
#  65399    Ommeren de Kroonheuvel, balk. Projectnummer de...
#  1529823                                   Boechera stricta
#  920696              Brachypodium distachyon cultivar:Bd1-1
#  1295566  snATAC-seq of the developing mouse cerebellum ...
#  427364   Marine microbial communities from Ellis Fjord,...
#  1027204  RNA-seq on SIP+-treated mating type minus cult...
#  1751363       Escherichia coli strain:UTI | isolate:P10405
#  2052041                                                NaN
#  1106858                                           bacteria
#  148944           Publications on the Micro credit research
#  1034423                     Acinetobacter baumannii 135867
#  2661529  IDSL.CSA unique CSA variants for the ST001000 ...
#  531090   Halorubrum lacusprofundi UNSW DL20 genome sequ...
#  1710319  TGFβ reprograms TNF stimulation of macrophages...
#  122990                        Haitian ason (ritual rattle)
#
#                                                 Description          Model  \
#  1558576  RNA-seq data of 27 combinations of caste and d...  gpt-3.5-turbo
#  519862                                                 NaN  gpt-3.5-turbo
#  578189   Clostridium clostridioforme 2_1_49FAA. Referen...  gpt-3.5-turbo
#  1735727  Brassica rapa VT123 Gene Expression Profiling ...  gpt-3.5-turbo
#  2400934  Sorghum bicolor strain:R09069 | cultivar:R0906...  gpt-3.5-turbo
#  759365   Breast tumors from CHEK2 1100delC mutation car...  gpt-3.5-turbo
#  531655   The Hungate 1000. A catalogue of reference gen...  gpt-3.5-turbo
#  418260   Gene Expression Profiling of Panicum virgatum ...  gpt-3.5-turbo
#  1643893  Forest soil microbial communities from Amazon ...  gpt-3.5-turbo
#  1182217  Panicum virgatum FLAME 1047-38-4-3 Pv Resequen...  gpt-3.5-turbo
#  65399                 Dendrochronological research project  gpt-3.5-turbo
#  1529823  Boechera stricta Reference Population resequen...  gpt-3.5-turbo
#  920696   Brachypodium distachyon Bd1-1 gene expression ...  gpt-3.5-turbo
#  1295566  snATAC-seq of the developing mouse cerebellum ...  gpt-3.5-turbo
#  427364   Marine microbial communities from Ellis Fjord,...  gpt-3.5-turbo
#  1027204  RNA-seq on SIP+-treated mating type minus cult...  gpt-3.5-turbo
#  1751363  Escherichia coli strain:UTI | isolate:P10405 G...  gpt-3.5-turbo
#  2052041  Pol II and its associated epigenetic marks are...  gpt-3.5-turbo
#  1106858  direct sequencing of 16S rRNA V3-V4 region of ...  gpt-3.5-turbo
#  148944   All 552  publications on the topic of the Micr...  gpt-3.5-turbo
#  1034423  Comparative genomics and transcriptomics to id...  gpt-3.5-turbo
#  2661529  IDSL.CSA unique CSA variants for the ST001000 ...  gpt-3.5-turbo
#  531090   Seasonal variation in Antarctic microbial comm...  gpt-3.5-turbo
#  1710319  TGFβ reprograms TNF stimulation of macrophages...  gpt-3.5-turbo
#  122990   Haitian Vodou ritual rattle used to conduct ce...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  1558576   {Developmental biology, Biology, Bioinformatics}
#  519862   {Tropical medicine, Antimicrobial Resistance, ...
#  578189            {Microbiology, Genomics, Bioinformatics}
#  1735727         {Plant biology, Genetics, Transcriptomics}
#  2400934                 {Plant biology, Biology, Genomics}
#  759365             {Molecular biology, Genomics, Oncology}
#  531655                   {Biology, Microbiology, Genomics}
#  418260        {Plant biology, Molecular biology, Genetics}
#  1643893    {Metagenomics, Environmental sciences, Ecology}
#  1182217                 {Plant biology, Biology, Genomics}
#  65399                    {Biology, Environmental sciences}
#  1529823                {Plant biology, Genetics, Genomics}
#  920696   {Plant biology, Gene expression, Transcriptomics}
#  1295566  {Neurobiology, Developmental biology, Transcri...
#  427364   {Metagenomics, Environmental sciences, Marine ...
#  1027204                           {RNA, Biology, Genetics}
#  1751363    {Computational biology, Microbiology, Genomics}
#  2052041              {Cell biology, Genetics, Epigenetics}
#  1106858           {Microbiology, Genetics, Bioinformatics}
#  148944                    {Public health and epidemiology}
#  1034423  {Comparative genomics, Microbiology, Antimicro...
#  2661529  {Population genetics, Proteomics, Bioinformatics}
#  531090   {Microbial ecology, Environmental sciences, Ge...
#  1710319    {Molecular biology, Bioinformatics, Immunology}
#  122990                                                  {}
#
#                                              Hallucinations  \
#  1558576                                              set()
#  519862                                               set()
#  578189                                               set()
#  1735727                                              set()
#  2400934                                              set()
#  759365                                                {''}
#  531655                                               set()
#  418260                                               set()
#  1643893                                              set()
#  1182217                                              set()
#  65399                      {'Dendrochronology', 'Geology'}
#  1529823                                         {'Botany'}
#  920696                                               set()
#  1295566                                   {'Neuroscience'}
#  427364                                               set()
#  1027204                                              set()
#  1751363                                              set()
#  2052041                                              set()
#  1106858                                              set()
#  148944                    {'Social sciences', 'Economics'}
#  1034423                                              set()
#  2661529                                              set()
#  531090                                               set()
#  1710319                                              set()
#  122990   {'Religious studies', 'Cultural studies', 'Ant...
#
#                                 filepath                           _id  \
#  1558576   outputs/omicsdi_processed.csv                     PRJEB9366
#  519862   outputs/ncbi_sra_processed.csv            NCBI_SRA_ERP113466
#  578189   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP002712
#  1735727   outputs/omicsdi_processed.csv                   PRJNA619711
#  2400934   outputs/omicsdi_processed.csv                   PRJNA331592
#  759365    outputs/omicsdi_processed.csv                   PRJNA132323
#  531655   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP087912
#  418260   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP168796
#  1643893   outputs/omicsdi_processed.csv                   PRJNA336766
#  1182217   outputs/omicsdi_processed.csv                   PRJNA829252
#  65399     outputs/harvard_processed.csv     Dataverse_10.34894_UF5X0Y
#  1529823   outputs/omicsdi_processed.csv                   PRJNA426923
#  920696    outputs/omicsdi_processed.csv                   PRJNA477073
#  1295566   outputs/omicsdi_processed.csv                    PRJEB53028
#  427364   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP191232
#  1027204   outputs/omicsdi_processed.csv                    PRJEB11784
#  1751363   outputs/omicsdi_processed.csv                   PRJNA743766
#  2052041   outputs/omicsdi_processed.csv                   PRJNA124187
#  1106858   outputs/omicsdi_processed.csv                   PRJNA303190
#  148944   outputs/mendeley_processed.csv           Mendeley_6sh3wthfdk
#  1034423   outputs/omicsdi_processed.csv                   PRJNA194705
#  2661529    outputs/zenodo_processed.csv                ZENODO_7530244
#  531090   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP087305
#  1710319   outputs/omicsdi_processed.csv                   PRJNA721180
#  122990    outputs/harvard_processed.csv  Dataverse_10.7910_DVN_TUF0PV
#
#                                Repository
#  1558576  Omics Discovery Index (OmicsDI)
#  519862                          NCBI SRA
#  578189                          NCBI SRA
#  1735727  Omics Discovery Index (OmicsDI)
#  2400934  Omics Discovery Index (OmicsDI)
#  759365   Omics Discovery Index (OmicsDI)
#  531655                          NCBI SRA
#  418260                          NCBI SRA
#  1643893  Omics Discovery Index (OmicsDI)
#  1182217  Omics Discovery Index (OmicsDI)
#  65399                  Harvard Dataverse
#  1529823  Omics Discovery Index (OmicsDI)
#  920696   Omics Discovery Index (OmicsDI)
#  1295566  Omics Discovery Index (OmicsDI)
#  427364                          NCBI SRA
#  1027204  Omics Discovery Index (OmicsDI)
#  1751363  Omics Discovery Index (OmicsDI)
#  2052041  Omics Discovery Index (OmicsDI)
#  1106858  Omics Discovery Index (OmicsDI)
#  148944                          Mendeley
#  1034423  Omics Discovery Index (OmicsDI)
#  2661529                           Zenodo
#  531090                          NCBI SRA
#  1710319  Omics Discovery Index (OmicsDI)
#  122990                 Harvard Dataverse  ,
#                                                        Name  \
#  455121   16S rRNA metagenome project for broiler chicke...
#  407690   Sorted cell/s from McNutts Creek water, Athens...
#  722316   Soil 16S rRNA and ITS  amplicon Sequencing aft...
#  688052   Marine microbial communities from Saanich Inle...
#  455250             Root-knot nematode associatied bacteria
#  1082137                                                NaN
#  1094198                                       Homo sapiens
#  1724417                                    soil metagenome
#  1558791              Epidermolysis bullosa-Pyloric Atresia
#  680286   Impact of wheat domestication on root-associat...
#  618186   Homo sapiens Raw sequence reads in 2D and 3D c...
#  608869   Serpentinite rock and fluid subsurface biosphe...
#  159777   Dataset for WGS of Vietnamese broadhead catfis...
#  422078   Marine bacterial communities from Monterey Bay...
#  718644   Transcriptome sequencing of potato for late bl...
#  2357181  Miscanthus sacchariflorus x Miscanthus sinensi...
#  1674837                                                NaN
#  414632   Metatranscriptome of Populus tremula x Populus...
#  575335   Active sludge microbial communities from Klost...
#  2654378                       Cast Al-Si-Mg alloy APT data
#  2687354  List of European Security and Defence Policy /...
#  1538592  Effect of LIMD1 knockdown on gene expression i...
#  2195942  Changes in glycogen metabolism machinery are a...
#  771099                                   marine metagenome
#  438743   Metatranscriptome of Cenococcum geophilum stra...
#
#                                                 Description          Model  \
#  455121   In this research, we aimed to understand diffe...  gpt-3.5-turbo
#  407690   Sorted cells from McNutts Creek water, Athens,...  gpt-3.5-turbo
#  722316   Soil 16S rRNA and ITS amplicon Sequencing afte...  gpt-3.5-turbo
#  688052   Marine microbial communities from Saanich Inle...  gpt-3.5-turbo
#  455250   To explored the bacterial content associated w...  gpt-3.5-turbo
#  1082137  EMG produced TPA metagenomics assembly of the ...  gpt-3.5-turbo
#  1094198  Baseline serum anti-glycan antibodies of 28 su...  gpt-3.5-turbo
#  1724417  Enriched cells from forest soil in Barre Woods...  gpt-3.5-turbo
#  1558791  Identification of a Novel Pathogenic Missense ...  gpt-3.5-turbo
#  680286   In this study, we compared root-associated mic...  gpt-3.5-turbo
#  618186   miR-29b-3p deficiency in organoid cells resist...  gpt-3.5-turbo
#  608869   Subsurface biosphere microbial communities fro...  gpt-3.5-turbo
#  159777   Dataset for genome sequencing and de novo asse...  gpt-3.5-turbo
#  422078   Marine bacterial communities from surface wate...  gpt-3.5-turbo
#  718644   This is total RNA sequencing data of potato fo...  gpt-3.5-turbo
#  2357181  Miscanthus sacchariflorus lutarioriparius PF30...  gpt-3.5-turbo
#  1674837  Isolation and re-connection: the demographic h...  gpt-3.5-turbo
#  414632   Metatranscriptome of Populus root microbial co...  gpt-3.5-turbo
#  575335   Raman-based microcolony genomics for studying ...  gpt-3.5-turbo
#  2654378  Data from publication. Will be opened when pub...  gpt-3.5-turbo
#  2687354  List of European Security and Defence Policy /...  gpt-3.5-turbo
#  1538592  Effect of LIMD1 knockdown on gene expression i...  gpt-3.5-turbo
#  2195942  Analysis of proteome changes during mouse brai...  gpt-3.5-turbo
#  771099   Marine microbial communities from the Southern...  gpt-3.5-turbo
#  438743   Metatranscriptome of Cenococcum geophilum stra...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  455121   {Animal study, Microbiology, Agricultural scie...
#  407690   {Metagenomics, Environmental sciences, Microbi...
#  722316   {Environmental sciences, Microbiology, Agricul...
#  688052   {Metagenomics, Sequence analysis, Marine biology}
#  455250   {Metagenomics, Environmental sciences, Microbi...
#  1082137       {Metagenomics, Microbiology, Marine biology}
#  1094198                          {Vaccinology, Immunology}
#  1724417  {Metagenomics, Environmental sciences, Microbi...
#  1558791       {Rare diseases, Molecular biology, Genetics}
#  680286             {Plant biology, Microbiology, Genetics}
#  618186                     {Bioinformatics, Genetics, DNA}
#  608869   {Metagenomics, Environmental sciences, Microbi...
#  159777                       {Biology, Taxonomy, Genomics}
#  422078   {Metagenomics, Environmental sciences, Marine ...
#  718644   {Plant biology, Infectious disease, Transcript...
#  2357181                {Plant biology, Genetics, Genomics}
#  1674837                  {Biodiversity, Genetics, Ecology}
#  414632   {Plant biology, Metatranscriptomics, Transcrip...
#  575335   {Microbial ecology, Metagenomics, Environmenta...
#  2654378                                        {Chemistry}
#  2687354                                                 {}
#  1538592     {Molecular biology, Genetics, Gene expression}
#  2195942          {Geriatric medicine, Biology, Proteomics}
#  771099        {Metagenomics, Marine biology, Carbon cycle}
#  438743   {Metagenomics, Bioinformatics, Metatranscripto...
#
#                                              Hallucinations  \
#  455121                                               set()
#  407690                                               set()
#  722316                                               set()
#  688052                                               set()
#  455250                                               set()
#  1082137                                              set()
#  1094198     {'Clinical immunology and immunotherapeutics'}
#  1724417                                               {''}
#  1558791                                              set()
#  680286                                               set()
#  618186                                               set()
#  608869                                               set()
#  159777                                               set()
#  422078                                               set()
#  718644                                               set()
#  2357181                                              set()
#  1674837                                              set()
#  414632                                               set()
#  575335                                               set()
#  2654378            {'Materials science', 'Nanotechnology'}
#  2687354  {'European Security', 'Defence policy', 'Commo...
#  1538592                                              set()
#  2195942                                          {'Aging'}
#  771099                                               set()
#  438743                                               set()
#
#                                 filepath                  _id  \
#  455121   outputs/ncbi_sra_processed.csv   NCBI_SRA_DRP005212
#  407690   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP156801
#  722316   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP275734
#  688052   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP317308
#  455250   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP048827
#  1082137   outputs/omicsdi_processed.csv           PRJEB28950
#  1094198   outputs/omicsdi_processed.csv          PRJNA179245
#  1724417   outputs/omicsdi_processed.csv          PRJNA466793
#  1558791   outputs/omicsdi_processed.csv           PRJEB35509
#  680286   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP252177
#  618186   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP331491
#  608869   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP122525
#  159777   outputs/mendeley_processed.csv  Mendeley_d8739nckf9
#  422078   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP174755
#  718644   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP375301
#  2357181   outputs/omicsdi_processed.csv          PRJNA581785
#  1674837   outputs/omicsdi_processed.csv          PRJNA598960
#  414632   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP164553
#  575335   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP109841
#  2654378    outputs/zenodo_processed.csv       ZENODO_6358591
#  2687354    outputs/zenodo_processed.csv       ZENODO_3243956
#  1538592   outputs/omicsdi_processed.csv          PRJNA472247
#  2195942   outputs/omicsdi_processed.csv            PXD006815
#  771099    outputs/omicsdi_processed.csv          PRJNA365364
#  438743   outputs/ncbi_sra_processed.csv   NCBI_SRA_SRP213226
#
#                                Repository
#  455121                          NCBI SRA
#  407690                          NCBI SRA
#  722316                          NCBI SRA
#  688052                          NCBI SRA
#  455250                          NCBI SRA
#  1082137  Omics Discovery Index (OmicsDI)
#  1094198  Omics Discovery Index (OmicsDI)
#  1724417  Omics Discovery Index (OmicsDI)
#  1558791  Omics Discovery Index (OmicsDI)
#  680286                          NCBI SRA
#  618186                          NCBI SRA
#  608869                          NCBI SRA
#  159777                          Mendeley
#  422078                          NCBI SRA
#  718644                          NCBI SRA
#  2357181  Omics Discovery Index (OmicsDI)
#  1674837  Omics Discovery Index (OmicsDI)
#  414632                          NCBI SRA
#  575335                          NCBI SRA
#  2654378                           Zenodo
#  2687354                           Zenodo
#  1538592  Omics Discovery Index (OmicsDI)
#  2195942  Omics Discovery Index (OmicsDI)
#  771099   Omics Discovery Index (OmicsDI)
#  438743                          NCBI SRA  ,
#                                                        Name  \
#  1054235  Study of mitotic chromatin shows involvement o...
#  1345402  Genomic, transcriptomic, and structural analys...
#  276006   Vascular endothelial cells (VECs) and lymphati...
#  2559328  Supplementary material 22 from: Branco VV, Hen...
#  171685   Vertical Gradient Variations in Radiation Budg...
#  2763686  Data repository for Jarvis et al. (2023): The ...
#  632244   RNA-seq data of the effect of volatile organic...
#  390094   RNA sequencing of exogenous RNAi mutants under...
#  1216857       (-)-(1S,5R)-2-Oxabicyclo-[3.3.1]nonan-3-one.
#  2094617  An enhancer in the middle of the Igκ locus orc...
#  374064   JunB is essential for IL-23-dependent pathogen...
#  2549852  Dataset from A Randomized, Single-blind, Place...
#  1393156  In vivo CRISPR screens reveal NOTCH regulators...
#  60057    Federico-Tena World Trade Historical Database ...
#  2727682  Natural history specimens collected and/or ide...
#  169950           Lattice Boltzmann velocity fields dataset
#  518965   Gene expression profiles of bulk tumor tissues...
#  1820808  Genome-wide analysis of retinal transcriptome ...
#  604855   Hydraulic Fracturing Flowback and Produced Wat...
#  1091644  Ezh2 is essential for activation-induced CD8+ ...
#  2650183  Законы о бюджете города Москвы на 2014-2018 го...
#  739875   Effects of water temperature on gut microbiota...
#  708634   Microbial community characteristics of the int...
#  161248   Data for Triple Bottom Line towards a holistic...
#  156837   Data for: Common and Fundamental Risk Factors ...
#
#                                                 Description          Model  \
#  1054235  Study of mitotic chromatin shows involvement o...  gpt-3.5-turbo
#  1345402  Genomic, transcriptomic, and structural analys...  gpt-3.5-turbo
#  276006   Analysis of vascular endothrial cells and lymp...  gpt-3.5-turbo
#  2559328  Distribution of Maso douro (Bosmans & Cardoso,...  gpt-3.5-turbo
#  171685   flux data\nradiation data\nprofile of day and ...  gpt-3.5-turbo
#  2763686  This is a data repository associated with Jarv...  gpt-3.5-turbo
#  632244   We performed this project aiming to identify t...  gpt-3.5-turbo
#  390094   The goal of this experiment was to identify RN...  gpt-3.5-turbo
#  1216857  In the title compound, C(8)H(12)O(2), the cycl...  gpt-3.5-turbo
#  2094617  An enhancer in the middle of the Igκ locus orc...  gpt-3.5-turbo
#  374064   To understand molecular mechanisms by which Ju...  gpt-3.5-turbo
#  2549852  To evaluate the safety and tolerability of rax...  gpt-3.5-turbo
#  1393156  In vivo CRISPR screens reveal NOTCH regulators...  gpt-3.5-turbo
#  60057    Project developed by Giovanni Federico (Univer...  gpt-3.5-turbo
#  2727682  Natural history specimen data collected and/or...  gpt-3.5-turbo
#  169950   The dataset for geometrical learning of flows....  gpt-3.5-turbo
#  518965   We report the gene expression profiles of bulk...  gpt-3.5-turbo
#  1820808  Genome-wide analysis of retinal transcriptome ...  gpt-3.5-turbo
#  604855   The sequences are associated with microbial co...  gpt-3.5-turbo
#  1091644  Ezh2 is essential for activation-induced CD8+ ...  gpt-3.5-turbo
#  2650183  Ведомственная структура расходов бюджета город...  gpt-3.5-turbo
#  739875   To describe the impact of temperature on the g...  gpt-3.5-turbo
#  708634   Microbial community characteristics of the int...  gpt-3.5-turbo
#  161248   Artigos utilizados para revisão sistemática da...  gpt-3.5-turbo
#  156837   The data set contains the time-series for the ...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  1054235     {Molecular biology, Cell biology, Epigenetics}
#  1345402    {Structural biology, Genomics, Transcriptomics}
#  276006          {Molecular biology, Cell biology, Biology}
#  2559328                   {Biodiversity, Mapping, Zoology}
#  171685     {Computational biology, Environmental sciences}
#  2763686         {Environmental sciences, Physics, Ecology}
#  632244             {Plant biology, Microbiology, Genetics}
#  390094                  {RNA, Molecular biology, Genetics}
#  1216857                     {Chemistry, X-ray diffraction}
#  2094617          {Molecular biology, Genetics, Immunology}
#  374064    {Molecular biology, Gene expression, Immunology}
#  2549852  {"Data submission, annotation, and curation", ...
#  1393156                 {Mouse clinic, Genetics, Oncology}
#  60057                              {Developmental biology}
#  2727682  {Zoology, Biodiversity, Data integration and w...
#  169950   {Computational biology, Biomedical science, Da...
#  518965          {Gene expression, Biotechnology, Oncology}
#  1820808              {Genetics, Genomics, Transcriptomics}
#  604855    {Environmental sciences, Microbiology, Genetics}
#  1091644        {Cell biology, Immunology, Gene regulation}
#  2650183  {Data governance, Data integration and warehou...
#  739875   {Animal study, Environmental sciences, Microbi...
#  708634        {Metagenomics, Microbiology, Marine biology}
#  161248   {Environmental sciences, Data integration and ...
#  156837                                                  {}
#
#                                              Hallucinations  \
#  1054235                                              set()
#  1345402                                              set()
#  276006                                               set()
#  2559328                           {'Distribution mapping'}
#  171685                                  {'Radiation data'}
#  2763686                                              set()
#  632244                                                {''}
#  390094                                               set()
#  1216857           {'Crystallography', 'Organic chemistry'}
#  2094617                                              set()
#  374064                                               set()
#  2549852     {'Clinical immunology and immunotherapeutics'}
#  1393156                                         {'Cancer'}
#  60057    {'Economics', 'International development', 'Hi...
#  2727682                                              set()
#  169950                                               set()
#  518965                                               set()
#  1820808                                              set()
#  604855                          {'Environmental Sciences'}
#  1091644                                              set()
#  2650183                                              set()
#  739875                                               set()
#  708634                                               set()
#  161248                                  {'Sustainability'}
#  156837   {'Finance', 'Statistics', 'Business and manage...
#
#                                 filepath  \
#  1054235   outputs/omicsdi_processed.csv
#  1345402   outputs/omicsdi_processed.csv
#  276006   outputs/ncbi_geo_processed.csv
#  2559328    outputs/zenodo_processed.csv
#  171685   outputs/mendeley_processed.csv
#  2763686    outputs/zenodo_processed.csv
#  632244   outputs/ncbi_sra_processed.csv
#  390094   outputs/ncbi_geo_processed.csv
#  1216857   outputs/omicsdi_processed.csv
#  2094617   outputs/omicsdi_processed.csv
#  374064   outputs/ncbi_geo_processed.csv
#  2549852     outputs/vivli_processed.csv
#  1393156   outputs/omicsdi_processed.csv
#  60057     outputs/harvard_processed.csv
#  2727682    outputs/zenodo_processed.csv
#  169950   outputs/mendeley_processed.csv
#  518965   outputs/ncbi_sra_processed.csv
#  1820808   outputs/omicsdi_processed.csv
#  604855   outputs/ncbi_sra_processed.csv
#  1091644   outputs/omicsdi_processed.csv
#  2650183    outputs/zenodo_processed.csv
#  739875   outputs/ncbi_sra_processed.csv
#  708634   outputs/ncbi_sra_processed.csv
#  161248   outputs/mendeley_processed.csv
#  156837   outputs/mendeley_processed.csv
#
#                                                  _id  \
#  1054235                                 PRJNA422751
#  1345402                                 PRJNA534259
#  276006                                    GSE104979
#  2559328                              ZENODO_3491338
#  171685                          Mendeley_m7cngsdm8c
#  2763686                              ZENODO_8245343
#  632244                           NCBI_SRA_SRP336099
#  390094                                    GSE202291
#  1216857                               S-EPMC2979232
#  2094617                                 PRJNA496404
#  374064                                     GSE86499
#  2549852  VIVLI_1d66bda0-42db-4d27-a5ea-a63ea7390876
#  1393156                                 PRJNA589895
#  60057                     Dataverse_10.21950_6SHH8V
#  2727682                              ZENODO_8137469
#  169950                          Mendeley_kbrprbvtjw
#  518965                           NCBI_SRA_SRP295303
#  1820808                                 PRJNA666388
#  604855                           NCBI_SRA_SRP118543
#  1091644                                 PRJNA416855
#  2650183                              ZENODO_4539989
#  739875                           NCBI_SRA_SRP404127
#  708634                           NCBI_SRA_SRP367441
#  161248                          Mendeley_dz58cvs99d
#  156837                          Mendeley_br52s4mrw7
#
#                                Repository
#  1054235  Omics Discovery Index (OmicsDI)
#  1345402  Omics Discovery Index (OmicsDI)
#  276006                          NCBI GEO
#  2559328                           Zenodo
#  171685                          Mendeley
#  2763686                           Zenodo
#  632244                          NCBI SRA
#  390094                          NCBI GEO
#  1216857  Omics Discovery Index (OmicsDI)
#  2094617  Omics Discovery Index (OmicsDI)
#  374064                          NCBI GEO
#  2549852                            Vivli
#  1393156  Omics Discovery Index (OmicsDI)
#  60057                  Harvard Dataverse
#  2727682                           Zenodo
#  169950                          Mendeley
#  518965                          NCBI SRA
#  1820808  Omics Discovery Index (OmicsDI)
#  604855                          NCBI SRA
#  1091644  Omics Discovery Index (OmicsDI)
#  2650183                           Zenodo
#  739875                          NCBI SRA
#  708634                          NCBI SRA
#  161248                          Mendeley
#  156837                          Mendeley  )

# %%
sample_rows_10 = sample_rows_10.assign(identifier='10 or less')
sample_rows_11_20 = sample_rows_11_20.assign(identifier='11-20')
sample_rows_21_30 = sample_rows_21_30.assign(identifier='21-30')
sample_rows_31_40 = sample_rows_31_40.assign(identifier='31-40')

sample_rows = pd.concat([sample_rows_10, sample_rows_11_20, sample_rows_21_30, sample_rows_31_40], ignore_index=True)

# %%
sample_rows.rename(columns={'identifier': 'Number of Words'}, inplace=True)

# %%
sample_rows.drop(columns=['Predictions', 'Hallucinations'], inplace=True)

# %%
sample_rows['Name'] = sample_rows['Name'].fillna('')
sample_rows['Description'] = sample_rows['Description'].fillna('')

# %%
sample_rows
# Out:
#                                                  Name  \
# 0                                      hou02665c01004
# 1           Lactiplantibacillus plantarum strain:IRG1
# 2                       Listeria monocytogenes SHL015
# 3
# 4   Sequencing INFLUENZA A VIRUS (A/MEMPHIS/3/1973...
# ..                                                ...
# 95  Законы о бюджете города Москвы на 2014-2018 го...
# 96  Effects of water temperature on gut microbiota...
# 97  Microbial community characteristics of the int...
# 98  Data for Triple Bottom Line towards a holistic...
# 99  Data for: Common and Fundamental Risk Factors ...
#
#                                           Description          Model  \
# 0                                                   L  gpt-3.5-turbo
# 1   Lactobacillus plantarum IRG1 Genome sequencing...  gpt-3.5-turbo
# 2   Listeria monocytogenes SHL015 Genome sequencin...  gpt-3.5-turbo
# 3   Identifying SNPs in the D1RatMgh8 microsatteli...  gpt-3.5-turbo
# 4                                                      gpt-3.5-turbo
# ..                                                ...            ...
# 95  Ведомственная структура расходов бюджета город...  gpt-3.5-turbo
# 96  To describe the impact of temperature on the g...  gpt-3.5-turbo
# 97  Microbial community characteristics of the int...  gpt-3.5-turbo
# 98  Artigos utilizados para revisão sistemática da...  gpt-3.5-turbo
# 99  The data set contains the time-series for the ...  gpt-3.5-turbo
#
#                           filepath                           _id  \
# 0    outputs/harvard_processed.csv  Dataverse_10.7910_DVN_BA39BT
# 1    outputs/omicsdi_processed.csv                   PRJNA428424
# 2    outputs/omicsdi_processed.csv                   PRJNA218932
# 3    outputs/omicsdi_processed.csv                    PRJEB27381
# 4   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP206023
# ..                             ...                           ...
# 95    outputs/zenodo_processed.csv                ZENODO_4539989
# 96  outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP404127
# 97  outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP367441
# 98  outputs/mendeley_processed.csv           Mendeley_dz58cvs99d
# 99  outputs/mendeley_processed.csv           Mendeley_br52s4mrw7
#
#                          Repository Number of Words
# 0                 Harvard Dataverse      10 or less
# 1   Omics Discovery Index (OmicsDI)      10 or less
# 2   Omics Discovery Index (OmicsDI)      10 or less
# 3   Omics Discovery Index (OmicsDI)      10 or less
# 4                          NCBI SRA      10 or less
# ..                              ...             ...
# 95                           Zenodo           31-40
# 96                         NCBI SRA           31-40
# 97                         NCBI SRA           31-40
# 98                         Mendeley           31-40
# 99                         Mendeley           31-40
#
# [100 rows x 7 columns]

# %%
sample_rows.to_csv('outputs/word_count_sample.csv', index=False)

# %% [markdown]
# ## Get empty set IDs
#
# Get IDs of data with no predictions

# %%
empty_set_ids = combined_df[combined_df['Predictions'].apply(len) == 0][['_id', 'Name', 'Description']]
empty_set_ids.reset_index(drop=True, inplace=True)

# %%
empty_set_ids.to_csv('outputs/empty_set_ids.csv', index=False)
