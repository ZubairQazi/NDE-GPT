# %%
import pandas as pd
import ast

import glob
import os

import re

# %%
csv_files = glob.glob('outputs/processed_outputs/*_processed.csv')  # replace with your actual directory path
csv_files
# Out:
# ['outputs/processed_outputs/qiita_processed.csv',
#  'outputs/processed_outputs/clinepidb_processed.csv',
#  'outputs/processed_outputs/accessclinicaldata_processed.csv',
#  'outputs/processed_outputs/dryad_processed.csv',
#  'outputs/processed_outputs/immport_processed.csv',
#  'outputs/processed_outputs/harvard_processed.csv',
#  'outputs/processed_outputs/vdjserver_processed.csv',
#  'outputs/processed_outputs/hubmap_processed.csv',
#  'outputs/processed_outputs/datadiscoveryengine_processed.csv',
#  'outputs/processed_outputs/lincs_processed.csv',
#  'outputs/processed_outputs/mendeley_processed.csv',
#  'outputs/processed_outputs/ncbi_geo_processed.csv',
#  'outputs/processed_outputs/ncbi_sra_processed.csv',
#  'outputs/processed_outputs/omicsdi_processed.csv',
#  'outputs/processed_outputs/reframedb_processed.csv',
#  'outputs/processed_outputs/veupathdb_processed.csv',
#  'outputs/processed_outputs/vivli_processed.csv',
#  'outputs/processed_outputs/zenodo_processed.csv']

# %%
repositories = {
    'accessclinicaldata': 'AccessClinicalData@NIAID',
    'clinepidb': 'ClinEpiDB',
    'datadiscoveryengine': 'Data Discovery Engine',
    'dryad': 'Dryad Digital Repository',
    'harvard': 'Harvard Dataverse',
    'hubmap': 'HuBMAP',
    'immport': 'ImmPort',
    'lincs': 'LINCS',
    'mendeley': 'Mendeley',
    'ncbi_geo':'NCBI GEO',
    'ncbi_sra': 'NCBI SRA',
    'omicsdi': 'Omics Discovery Index (OmicsDI)',
    'qiita': 'Qiita',
    'reframedb': 'ReframeDB',
    'vdjserver': 'VDJServer',
    'veupathdb': 'VEuPathDB',
    'vivli': 'Vivli',
    'zenodo': 'Zenodo'
}

# %%
# Read each CSV file, add a 'filename' column, and store them in a list
dfs = [pd.read_csv(f,lineterminator='\n').assign(Repository=repositories[os.path.basename(f).replace('_processed.csv', '')]) for f in csv_files]

# Concatenate all dataframes in the list into one dataframe
combined_df = pd.concat(dfs, ignore_index=True)

# %%
combined_df['Predictions'] = combined_df['Predictions'].apply(ast.literal_eval)

# %%
combined_df
# Out:
#                                                       Name  \
# 0        Understanding Cultivar-Specificity and Soil De...
# 1                The microbiome of uncontacted Amerindians
# 2        Changes in Microbial Ecology after Fecal Micro...
# 3                                           Fleshner tMM45
# 4        The Fecal Microbial Community of Breast-fed In...
# ...                                                    ...
# 2764275  IN00034 Kahaum Pillar Inscription of the Time ...
# 2764276               Infant Sibling Project: Sample Files
# 2764277  IN00037 Supia Pillar Inscription of the Time o...
# 2764278  KC0P 40 m SEQP Reverse Beacon Network Log of S...
# 2764279  Global Labour Journal, Editors' Introduction (...
#
#                                                Description          Model  \
# 0        This is a preliminary study to examine the mic...  gpt-3.5-turbo
# 1        Most studies of the human microbiome have focu...  gpt-3.5-turbo
# 2        Gut microbiota play a key role in maintaining ...  gpt-3.5-turbo
# 3        We hypothesize the wheel running may change th...  gpt-3.5-turbo
# 4        Oligosaccharides from breast milk are believed...  gpt-3.5-turbo
# ...                                                    ...            ...
# 2764275  Bhandarkar, Devadatta Ramakrishna, Bahadur Cha...  gpt-3.5-turbo
# 2764276  These electroencephalography (EEG) data files ...  gpt-3.5-turbo
# 2764277  Bhandarkar, Devadatta Ramakrishna, Bahadur Cha...  gpt-3.5-turbo
# 2764278  Log of the Spots generated by the Reverse Beac...  gpt-3.5-turbo
# 2764279  2015. "Editors' Introduction." Global Labour J...  gpt-3.5-turbo
#
#                                                Predictions  \
# 0        {Microbiology, Agricultural science, Plant bio...
# 1        {Microbiology, Metagenomics, Antimicrobial Res...
# 2        {Infectious disease, Microbial ecology, Gastro...
# 3                    {Microbiology, Biology, Animal study}
# 4         {Microbiology, Genetics, Environmental sciences}
# ...                                                    ...
# 2764275                                                 {}
# 2764276  {Electroencephalography, Data integration and ...
# 2764277                                                 {}
# 2764278  {Computational biology, Data mining, Machine l...
# 2764279                  {Ecology, Environmental sciences}
#
#                                      Hallucinations            _id Repository
# 0                                  {'Soil science'}     qiita_1001      Qiita
# 1                                             set()    qiita_10052      Qiita
# 2                                             set()    qiita_10057      Qiita
# 3                                             set()    qiita_10064      Qiita
# 4                                             set()    qiita_10080      Qiita
# ...                                             ...            ...        ...
# 2764275  {'History', 'Inscriptions', 'Archaeology'}  ZENODO_998956     Zenodo
# 2764276                                       set()  ZENODO_998964     Zenodo
# 2764277     {'Geography', 'History', 'Archaeology'}  ZENODO_998987     Zenodo
# 2764278                                       set()  ZENODO_999020     Zenodo
# 2764279                   {'Science communication'}  ZENODO_999851     Zenodo
#
# [2764280 rows x 7 columns]

# %%
# empty_sets = combined_df.groupby('Repository')['Predictions'].apply(lambda x: (x == set()).sum())
# empty_sets

counts = combined_df.groupby('Repository')['Predictions'].apply(lambda x: pd.Series({
    'empty_sets': (x == set()).sum(),
    'sets_of_1': (x.apply(len) == 1).sum(),
    'sets_of_2': (x.apply(len) == 2).sum(),
    'sets_of_3': (x.apply(len) == 3).sum(),
    'total': x.size
}))

# %%
print(counts.to_string())
# Out:
# Repository
# AccessClinicalData@NIAID         empty_sets          0
#                                  sets_of_1           0
#                                  sets_of_2           0
#                                  sets_of_3           7
#                                  total               7
# ClinEpiDB                        empty_sets          0
#                                  sets_of_1           1
#                                  sets_of_2           6
#                                  sets_of_3          43
#                                  total              50
# Data Discovery Engine            empty_sets          0
#                                  sets_of_1           2
#                                  sets_of_2          17
#                                  sets_of_3         349
#                                  total             368
# Dryad Digital Repository         empty_sets        180
#                                  sets_of_1         897
#                                  sets_of_2        5448
#                                  sets_of_3       47569
#                                  total           54208
# Harvard Dataverse                empty_sets      11243
#                                  sets_of_1        9261
#                                  sets_of_2       12649
#                                  sets_of_3       47629
#                                  total           80975
# HuBMAP                           empty_sets          6
#                                  sets_of_1         125
#                                  sets_of_2         107
#                                  sets_of_3        1707
#                                  total            1948
# ImmPort                          empty_sets          1
#                                  sets_of_1           6
#                                  sets_of_2          38
#                                  sets_of_3         661
#                                  total             721
# LINCS                            empty_sets          0
#                                  sets_of_1           1
#                                  sets_of_2           6
#                                  sets_of_3         338
#                                  total             345
# Mendeley                         empty_sets       2733
#                                  sets_of_1        4952
#                                  sets_of_2       10256
#                                  sets_of_3       35730
#                                  total           53828
# NCBI GEO                         empty_sets         21
#                                  sets_of_1         642
#                                  sets_of_2        9921
#                                  sets_of_3      199390
#                                  total          210928
# NCBI SRA                         empty_sets         92
#                                  sets_of_1        3169
#                                  sets_of_2       17606
#                                  sets_of_3      317295
#                                  total          339001
# Omics Discovery Index (OmicsDI)  empty_sets       8202
#                                  sets_of_1       41920
#                                  sets_of_2      184944
#                                  sets_of_3     1561448
#                                  total         1802736
# Qiita                            empty_sets          0
#                                  sets_of_1           4
#                                  sets_of_2          54
#                                  sets_of_3         645
#                                  total             703
# ReframeDB                        empty_sets          0
#                                  sets_of_1           0
#                                  sets_of_2           4
#                                  sets_of_3         135
#                                  total             139
# VDJServer                        empty_sets          0
#                                  sets_of_1           0
#                                  sets_of_2           6
#                                  sets_of_3          59
#                                  total              65
# VEuPathDB                        empty_sets          7
#                                  sets_of_1          89
#                                  sets_of_2         212
#                                  sets_of_3        2695
#                                  total            3005
# Vivli                            empty_sets          3
#                                  sets_of_1         151
#                                  sets_of_2        1140
#                                  sets_of_3        5833
#                                  total            7210
# Zenodo                           empty_sets       5840
#                                  sets_of_1       11495
#                                  sets_of_2       33659
#                                  sets_of_3      156483
#                                  total          208043

# %% [markdown]
# ### Get Name and Descriptions with Word Threshold

# %%
# Calculate the total number of words in the 'Name' and 'Description' columns
word_counts = combined_df.apply(lambda x: len(str(x['Name']).split()) + len(str(x['Description']).split()), axis=1)

# Get rows where the total number of words is in the range 11-20
sample_rows_10 = combined_df[word_counts <= 11].sample(n=25)

# Get rows where the total number of words is in the range 11-20
sample_rows_11_20 = combined_df[(word_counts >= 11) & (word_counts <= 20)].sample(n=25)

# Get rows where the total number of words is in the range 21-30
sample_rows_21_30 = combined_df[(word_counts >= 21) & (word_counts <= 30)].sample(n=25)

# Get rows where the total number of words is in the range 31-40
sample_rows_31_40 = combined_df[(word_counts >= 31) & (word_counts <= 40)].sample(n=25)

sample_rows_10, sample_rows_11_20, sample_rows_21_30, sample_rows_31_40
# Out:
# (                                                      Name  \
#  1300515                               Oryza longistaminata
#  1118694                                                NaN
#  87853                                        A12_20995.JPG
#  2631365                                       Library data
#  1595748                                    Solanum incanum
#  2339531                                       Homo sapiens
#  770017              Oryza sativa cultivar:Kitaake FN1669-S
#  2062403    Roseinatronobacter thiooxidans strain:DSM 13087
#  2062024                      Helicoverpa armigera armigera
#  2401013                    human gut metagenome strain:NO3
#  122335                                       A04_13972.JPG
#  87016                                        A12_22669.jpg
#  635859          Oryza sativa Kitaake FN1673-S Resequencing
#  108350                                       A92_5339a.jpg
#  1054489  ena-DATASET-KNIH-30-03-2021-05:47:45:371-459 -...
#  90478                                         A97_8890.jpg
#  1670312                        Helicobacter pylori Hp P-28
#  114991                                       A07_16495.JPG
#  447897                                         P. vivax HS
#  580892   Vibrio phage henriette 12B8 genome sequencing ...
#  1610132             bacterium strain:JGI CrystG Apr3-4-L15
#  2139415                                                NaN
#  1004694                                              Fungi
#  914720                                   Rattus norvegicus
#  1626773                                Symbiodinium sp. A2
#
#                                                 Description          Model  \
#  1300515  Oryza longistaminata Genome sequencing and ass...  gpt-3.5-turbo
#  1118694          Molecular network modulated by maize dlf1  gpt-3.5-turbo
#  87853    Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  2631365  Library list, location, date, architect and fe...  gpt-3.5-turbo
#  1595748   Solanum incanum Transcriptome or Gene expression  gpt-3.5-turbo
#  2339531  FACS-sorted Pancreatic Adenocarcinoma for Mole...  gpt-3.5-turbo
#  770017          Oryza sativa Kitaake FN1669-S Resequencing  gpt-3.5-turbo
#  2062403           Roseinatronobacter thiooxidans DSM 13087  gpt-3.5-turbo
#  2062024  Helicoverpa armigera armigera Transcriptome or...  gpt-3.5-turbo
#  2401013  Micro-Obes - Human Intestinal Tract Metagenome...  gpt-3.5-turbo
#  122335   Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  87016    Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  635859   Categorizing rice deletion mutants by re-seque...  gpt-3.5-turbo
#  108350   Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  1054489   Fat-adipocyte03 h3k27ac ChIP-Seq paired end data  gpt-3.5-turbo
#  90478    Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  1670312  Helicobacter pylori Hp P-28 Genome sequencing ...  gpt-3.5-turbo
#  114991   Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
#  447897                   Plasmodium vivax Hybrid Selection  gpt-3.5-turbo
#  580892                                                 NaN  gpt-3.5-turbo
#  1610132  bacterium strain:JGI CrystG Apr3-4-L15 Genome ...  gpt-3.5-turbo
#  2139415                       Phytophthora capsici RNA-seq  gpt-3.5-turbo
#  1004694                                   Fungi Metagenome  gpt-3.5-turbo
#  914720   DNA methylation reprogramming after spinal ner...  gpt-3.5-turbo
#  1626773  Symbiodinium sp. (Clade A) Transcriptome or Ge...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  1300515                          {Genomics, Plant biology}
#  1118694  {"Molecular interactions, pathways and network...
#  87853    {"Data submission, annotation, and curation", ...
#  2631365  {Data integration and warehousing, "Data archi...
#  1595748  {Gene expression, Transcriptomics, Plant biology}
#  2339531               {Molecular biology, Omics, Oncology}
#  770017                 {Genomics, Genetics, Plant biology}
#  2062403        {Microbiology, Molecular biology, Genomics}
#  2062024      {Bioinformatics, Genetic variation, Genomics}
#  2401013       {Microbiology, Human genetics, Metagenomics}
#  122335   {Data integration and warehousing, "Data submi...
#  87016    {Open science, "Data submission, annotation, a...
#  635859                       {Genomics, Biology, Genetics}
#  108350   {Open science, "Data submission, annotation, a...
#  1054489      {Bioinformatics, Genetics, Molecular biology}
#  90478    {"Data submission, annotation, and curation", ...
#  1670312                           {Microbiology, Genomics}
#  114991   {"Data submission, annotation, and curation", ...
#  447897         {Genomics, Molecular biology, Parasitology}
#  580892                  {Microbiology, Virology, Genomics}
#  1610132    {Microbiology, Genomics, Computational biology}
#  2139415                     {RNA, Genetics, Plant biology}
#  1004694             {Microbiology, Metagenomics, Genomics}
#  914720                   {Genomics, Genetics, Epigenetics}
#  1626773        {Biology, Gene expression, Transcriptomics}
#
#                                              Hallucinations  \
#  1300515                              {'Genome sequencing'}
#  1118694                                              set()
#  87853                                                set()
#  2631365  {'annotation', 'Library data', 'Data submissio...
#  1595748                                              set()
#  2339531                                         {'Cancer'}
#  770017                                               set()
#  2062403                                              set()
#  2062024                                              set()
#  2401013                                              set()
#  122335                                               set()
#  87016                                                set()
#  635859                                               set()
#  108350                                               set()
#  1054489                                              set()
#  90478                                                set()
#  1670312                                     {'Sequencing'}
#  114991                                               set()
#  447897                                               set()
#  580892                                               set()
#  1610132                                              set()
#  2139415                                              set()
#  1004694                                              set()
#  914720                                               set()
#  1626773                                              set()
#
#                                    _id                       Repository
#  1300515                   PRJNA169314  Omics Discovery Index (OmicsDI)
#  1118694                   PRJNA616067  Omics Discovery Index (OmicsDI)
#  87853    Dataverse_10.7910_DVN_DXU1Z5                Harvard Dataverse
#  2631365                ZENODO_3611512                           Zenodo
#  1595748                   PRJNA294364  Omics Discovery Index (OmicsDI)
#  2339531                   PRJNA111589  Omics Discovery Index (OmicsDI)
#  770017                    PRJNA345773  Omics Discovery Index (OmicsDI)
#  2062403                   PRJNA262348  Omics Discovery Index (OmicsDI)
#  2062024                   PRJNA258614  Omics Discovery Index (OmicsDI)
#  2401013                    PRJNA33307  Omics Discovery Index (OmicsDI)
#  122335   Dataverse_10.7910_DVN_TLGFEF                Harvard Dataverse
#  87016    Dataverse_10.7910_DVN_DM4IXE                Harvard Dataverse
#  635859             NCBI_SRA_SRP231404                         NCBI SRA
#  108350   Dataverse_10.7910_DVN_N9PGCH                Harvard Dataverse
#  1054489               EGAD00001007471  Omics Discovery Index (OmicsDI)
#  90478    Dataverse_10.7910_DVN_F6ORWQ                Harvard Dataverse
#  1670312                    PRJNA64199  Omics Discovery Index (OmicsDI)
#  114991   Dataverse_10.7910_DVN_QAHINE                Harvard Dataverse
#  447897             NCBI_SRA_SRP046036                         NCBI SRA
#  580892             NCBI_SRA_SRP005229                         NCBI SRA
#  1610132                   PRJNA403234  Omics Discovery Index (OmicsDI)
#  2139415                   PRJNA798776  Omics Discovery Index (OmicsDI)
#  1004694                   PRJNA383083  Omics Discovery Index (OmicsDI)
#  914720                    PRJNA392389  Omics Discovery Index (OmicsDI)
#  1626773                   PRJNA237994  Omics Discovery Index (OmicsDI)  ,
#                                                        Name  \
#  1048737                                       Mus musculus
#  499531                  Microbiota in short bowel syndrome
#  1022414                                  Rattus norvegicus
#  517077                              Streptococcus suis ST1
#  950396   Methylation for adult blood and cord blood sam...
#  1593413                                       Homo sapiens
#  2053523  Identification of the cortical neurons that me...
#  1550073     Legionella pneumophila serogroup 1 strain:JR32
#  1391304                Neurospora crassa strain:74-OR23-IV
#  1708220  Rhodopseudomonas julia strain:DSM 11549 | isol...
#  1114819                                                NaN
#  729360                             F21FTSAPJT0157_MOUgcrlR
#  743075   Drosophila  wds RNAi 3rd-instar fat body H3K4m...
#  199735   H3K9ac occupancy of Nedd4- or control-knockdow...
#  2732136          Binary black-hole simulation SXS:BBH:0426
#  1049272     Lactiplantibacillus plantarum subsp. plantarum
#  784602                                     leaf metagenome
#  2680683          Binary black-hole simulation SXS:BBH:0446
#  603989     Raw sequence reads for Cats with Kidney Disease
#  294810      Analysis of long noncoding RNAs in macrophages
#  1005908                                 aquatic metagenome
#  781829                                mouse gut metagenome
#  1126054                                                NaN
#  263061                     Bru-seq from PC-9 (ENCSR137XKP)
#  2126733                Arabidopsis thaliana cultivar:Col-0
#
#                                                 Description          Model  \
#  1048737  Expression data from C17.2 progenitor cells du...  gpt-3.5-turbo
#  499531   Feces microbial community in short bowel syndrome  gpt-3.5-turbo
#  1022414  Transcriptional profiling of the rat hypothala...  gpt-3.5-turbo
#  517077   This study aims to figure out the phylogenetic...  gpt-3.5-turbo
#  950396   Methylation for adult blood and cord blood sam...  gpt-3.5-turbo
#  1593413  Genome-wide maps of nuclear lamina interaction...  gpt-3.5-turbo
#  2053523  Identification of the cortical neurons that me...  gpt-3.5-turbo
#  1550073  Legionella pneumophila Lab strain (JR32) seque...  gpt-3.5-turbo
#  1391304  Neurospora crassa 74-OR23-IV transcriptome - r...  gpt-3.5-turbo
#  1708220  Rhodopseudomonas julia DSM 11549 genome sequen...  gpt-3.5-turbo
#  1114819  Virus genomes, with and without Cas9-based enr...  gpt-3.5-turbo
#  729360   The role of GT3 in the microenvironment of a t...  gpt-3.5-turbo
#  743075   study the function of H3K4me3 in lipid metabolism  gpt-3.5-turbo
#  199735       H3 Nedd4\nChIP seq using anti-H3K9ac antibody  gpt-3.5-turbo
#  2732136  Simulation of a black-hole binary system evolv...  gpt-3.5-turbo
#  1049272  Lactiplantibacillus plantarum subsp. plantarum...  gpt-3.5-turbo
#  784602   Metatranscriptome of Setaria viridis A10 leave...  gpt-3.5-turbo
#  2680683  Simulation of a black-hole binary system evolv...  gpt-3.5-turbo
#  603989                 Feline microbiome in kidney disease  gpt-3.5-turbo
#  294810   This SuperSeries is composed of the SubSeries ...  gpt-3.5-turbo
#  1005908  Sorted cell/s from water treatment plant in SU...  gpt-3.5-turbo
#  781829   Metagenomic and Metatranscriptomic Analysis of...  gpt-3.5-turbo
#  1126054  Genomic analysis of porcine faecal commensal E...  gpt-3.5-turbo
#  263061   For data usage terms and conditions, please re...  gpt-3.5-turbo
#  2126733  Arabidopsis thaliana Col-0 Gene Expression Pro...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  1048737  {Cell biology, Developmental biology, Neurobio...
#  499531   {Microbiology, Molecular biology, Gastroentero...
#  1022414           {Biology, Transcriptomics, Animal study}
#  517077   {Microbiology, Phylogenetics, Infectious disease}
#  950396   {Genomics, Medical informatics, Molecular biol...
#  1593413                      {Genomics, Biology, Genetics}
#  2053523     {Pharmacology, Drug development, Neurobiology}
#  1550073                           {Microbiology, Genetics}
#  1391304     {Genomics, Molecular biology, Transcriptomics}
#  1708220                  {Microbiology, Biology, Genomics}
#  1114819            {Genomics, Sequence analysis, Virology}
#  729360           {Immunology, Molecular biology, Oncology}
#  743075               {RNA, Molecular biology, Epigenetics}
#  199735             {Bioinformatics, Genetics, Epigenetics}
#  2732136                              {Physics, Biophysics}
#  1049272               {Microbiology, Proteomics, Genomics}
#  784602   {Metatranscriptomics, Metagenomics, Plant biol...
#  2680683                {Computational biology, Biophysics}
#  603989          {Microbiology, Animal study, Metagenomics}
#  294810            {Immunology, Gene transcripts, Genetics}
#  1005908  {Microbiology, Metagenomics, Environmental sci...
#  781829   {Microbiology, Nutritional science, Metagenomics}
#  1126054                 {Microbiology, Genetics, Genomics}
#  263061          {Genomics, Molecular biology, Epigenetics}
#  2126733  {Gene expression, Transcriptomics, Plant biology}
#
#                                             Hallucinations                 _id  \
#  1048737                                             set()         PRJNA381444
#  499531                                              set()  NCBI_SRA_SRP068873
#  1022414                                             set()         PRJNA119601
#  517077                                              set()  NCBI_SRA_SRP079937
#  950396                                               {''}         PRJNA629295
#  1593413                                             set()         PRJNA282151
#  2053523                                             set()         PRJNA152109
#  1550073                                    {'Sequencing'}           PRJDB4906
#  1391304                                             set()         PRJNA571445
#  1708220                                             set()         PRJNA708390
#  1114819                                             set()         PRJNA575708
#  729360                                              set()  NCBI_SRA_SRP385258
#  743075                                              set()  NCBI_SRA_SRP411943
#  199735                                              set()            GSE66340
#  2732136                                  {'Astrophysics'}      ZENODO_1235148
#  1049272                                             set()         PRJNA385751
#  784602                                              set()         PRJNA620776
#  2680683                                  {'Astrophysics'}      ZENODO_1234257
#  603989                                              set()  NCBI_SRA_SRP117611
#  294810   {'Functional, regulatory and non', 'coding RNA'}           GSE130056
#  1005908                                             set()         PRJNA404486
#  781829                                              set()         PRJNA563913
#  1126054                                             set()         PRJNA509690
#  263061                                              set()           GSE219498
#  2126733                                             set()         PRJNA697102
#
#                                Repository
#  1048737  Omics Discovery Index (OmicsDI)
#  499531                          NCBI SRA
#  1022414  Omics Discovery Index (OmicsDI)
#  517077                          NCBI SRA
#  950396   Omics Discovery Index (OmicsDI)
#  1593413  Omics Discovery Index (OmicsDI)
#  2053523  Omics Discovery Index (OmicsDI)
#  1550073  Omics Discovery Index (OmicsDI)
#  1391304  Omics Discovery Index (OmicsDI)
#  1708220  Omics Discovery Index (OmicsDI)
#  1114819  Omics Discovery Index (OmicsDI)
#  729360                          NCBI SRA
#  743075                          NCBI SRA
#  199735                          NCBI GEO
#  2732136                           Zenodo
#  1049272  Omics Discovery Index (OmicsDI)
#  784602   Omics Discovery Index (OmicsDI)
#  2680683                           Zenodo
#  603989                          NCBI SRA
#  294810                          NCBI GEO
#  1005908  Omics Discovery Index (OmicsDI)
#  781829   Omics Discovery Index (OmicsDI)
#  1126054  Omics Discovery Index (OmicsDI)
#  263061                          NCBI GEO
#  2126733  Omics Discovery Index (OmicsDI)  ,
#                                                        Name  \
#  603272   Porphyromonadaceae bacterium JGI 000176CP_C01 ...
#  360878            Control ChIP-seq from A549 (ENCSR615QEB)
#  260891   Identification of a Choroid Plexus Vascular Ba...
#  411187   Yarrowia lipolytica Gene Expression Profiling ...
#  1016360  Ultra-High Throughput Single Cell Analysis of ...
#  149539   Protocolo para coleta dos dados de pesquisa em...
#  2640306  Full summary statistics of mixQTL for GTEx v8 ...
#  732973   Sorghum bicolor TX08001 Gene Expression Profil...
#  421831   Seawater microbial communities from Monterey B...
#  605629   Saline lake microbial communities from Rauer I...
#  416295   Cleome hassleriana Gene Expression Profiling -...
#  1127731  Transcriptomic analysis of the effect of histo...
#  387036   Clonal expansion and epigenetic inheritance sh...
#  1134331  CDK9 inhibitor induces the apoptosis of acute ...
#  392153                 ChIP-seq from GM12878 (ENCSR136WQZ)
#  636326   Populus trichocarpa 7x7 parent cross progeny -...
#  1135042  Miscanthus sacchariflorus x Miscanthus sinensi...
#  687148   Enriched cells from Jinze hot spring sediment,...
#  443604   Fungi diversity in mangrove soils Targeted Loc...
#  669360   Halanaerobium saccharolyticum WC1 genome seque...
#  1069499  Epigenetic signature of human induced pluripot...
#  688230   Marine microbial communities from Saanich Inle...
#  192229   JAK inhibitors dampen activation of interferon...
#  1694634  Genome wide profiling of chromatin accessibili...
#  163936   Data for: Rate-dependent crack nucleation in c...
#
#                                                 Description          Model  \
#  603272   Single cell genome sequencing to uncover the m...  gpt-3.5-turbo
#  360878   ChIP-seq on human A549For data usage terms and...  gpt-3.5-turbo
#  260891   This SuperSeries is composed of the SubSeries ...  gpt-3.5-turbo
#  411187   Yarrowia lipolytica Gene Expression Profiling;...  gpt-3.5-turbo
#  1016360  Ultra-High Throughput Single Cell Analysis of ...  gpt-3.5-turbo
#  149539   Documento utilizado em entrevistas com os suje...  gpt-3.5-turbo
#  2640306  The mixQTL method is described in paper doi.or...  gpt-3.5-turbo
#  732973   Sorghum bicolor TX08001 Gene Expression Profil...  gpt-3.5-turbo
#  421831   Seawater microbial communities from Monterey B...  gpt-3.5-turbo
#  605629   Metagenomic analysis of microbial communities ...  gpt-3.5-turbo
#  416295   Cleome hassleriana Gene Expression Profiling t...  gpt-3.5-turbo
#  1127731  Transcriptomic analysis of the effect of histo...  gpt-3.5-turbo
#  387036   This SuperSeries is composed of the SubSeries ...  gpt-3.5-turbo
#  1134331  CDK9 inhibitor induces the apoptosis of acute ...  gpt-3.5-turbo
#  392153   Reverse Crosslink Control ChIP-seq on human GM...  gpt-3.5-turbo
#  636326   Sequencing of progeny from a 7x7 parent cross ...  gpt-3.5-turbo
#  1135042  Miscanthus sacchariflorus lutarioriparius PF30...  gpt-3.5-turbo
#  687148   Enriched cells from hot spring sediment in Ten...  gpt-3.5-turbo
#  443604   This study goal is to investigate the diversit...  gpt-3.5-turbo
#  669360   Genome sequencing from deep terrestrial subsur...  gpt-3.5-turbo
#  1069499  Epigenetic signature of human induced pluripot...  gpt-3.5-turbo
#  688230   Marine microbial communities from Saanich Inle...  gpt-3.5-turbo
#  192229               Supplemental spreadsheets and tables   gpt-3.5-turbo
#  1694634  Genome wide profiling of chromatin accessibili...  gpt-3.5-turbo
#  163936   Critical load, critical displacement, critical...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  603272         {Microbiology, Metagenomics, Biotechnology}
#  360878        {Functional genomics, Genetics, Epigenetics}
#  260891        {Immunology, Cell biology, Gastroenterology}
#  411187   {Computational biology, Transcriptomics, Bioin...
#  1016360                {Biology, Proteomics, Biochemistry}
#  149539   {Data integration and warehousing, Data acquis...
#  2640306  {Computational biology, Genetics, Bioinformatics}
#  732973   {Gene expression, Transcriptomics, Plant biology}
#  421831   {Microbial ecology, Marine biology, Metagenomics}
#  605629   {Microbiology, Metagenomics, Environmental sci...
#  416295       {Plant biology, Transcriptomics, Biosciences}
#  1127731  {Cell biology, Molecular biology, Transcriptom...
#  387036             {Immunology, Cell biology, Epigenetics}
#  1134331                 {Genetics, Biochemistry, Oncology}
#  392153               {Genomics, Cell biology, Epigenetics}
#  636326                 {Genomics, Genetics, Plant biology}
#  1135042       {Genomics, Sequence analysis, Plant biology}
#  687148   {Microbiology, Population genomics, Metagenomics}
#  443604   {Microbiology, Biodiversity, Environmental sci...
#  669360    {Microbiology, Genomics, Environmental sciences}
#  1069499    {Bioinformatics, Machine learning, Epigenetics}
#  688230   {Sequence analysis, Marine biology, Metagenomics}
#  192229             {Immunology, Transcriptomics, Virology}
#  1694634                  {Genomics, Biology, Cell biology}
#  163936                                                  {}
#
#                                              Hallucinations  \
#  603272                                               set()
#  360878                                               set()
#  260891                                                {''}
#  411187                                               set()
#  1016360                                              set()
#  149539                                               set()
#  2640306                                              set()
#  732973                                               set()
#  421831                                               set()
#  605629                                               set()
#  416295                                               set()
#  1127731                                              set()
#  387036                                               set()
#  1134331                                              set()
#  392153                                               set()
#  636326                                               set()
#  1135042                                              set()
#  687148                                               set()
#  443604                                               set()
#  669360                                               set()
#  1069499                                              set()
#  688230                                               set()
#  192229                                               set()
#  1694634                                              set()
#  163936   {'Materials Science', 'Biomechanics', 'Modelin...
#
#                           _id                       Repository
#  603272    NCBI_SRA_SRP116831                         NCBI SRA
#  360878             GSE170887                         NCBI GEO
#  260891             GSE178752                         NCBI GEO
#  411187    NCBI_SRA_SRP160578                         NCBI SRA
#  1016360          PRJNA541327  Omics Discovery Index (OmicsDI)
#  149539   Mendeley_73x88dn5fw                         Mendeley
#  2640306       ZENODO_4030076                           Zenodo
#  732973    NCBI_SRA_SRP391538                         NCBI SRA
#  421831    NCBI_SRA_SRP174090                         NCBI SRA
#  605629    NCBI_SRA_SRP119356                         NCBI SRA
#  416295    NCBI_SRA_SRP166490                         NCBI SRA
#  1127731          PRJNA521963  Omics Discovery Index (OmicsDI)
#  387036             GSE197037                         NCBI GEO
#  1134331          PRJNA700568  Omics Discovery Index (OmicsDI)
#  392153              GSE95942                         NCBI GEO
#  636326    NCBI_SRA_SRP232046                         NCBI SRA
#  1135042          PRJNA712853  Omics Discovery Index (OmicsDI)
#  687148    NCBI_SRA_SRP152371                         NCBI SRA
#  443604    NCBI_SRA_SRP041327                         NCBI SRA
#  669360    NCBI_SRA_SRP144305                         NCBI SRA
#  1069499          PRJNA593774  Omics Discovery Index (OmicsDI)
#  688230    NCBI_SRA_SRP317499                         NCBI SRA
#  192229   Mendeley_zhvggb5b44                         Mendeley
#  1694634          PRJNA629970  Omics Discovery Index (OmicsDI)
#  163936   Mendeley_gbnrxj77zv                         Mendeley  ,
#                                                        Name  \
#  565446   Determinants of persistent patterns of pepino ...
#  648274   The effect of LED light quality on fruit ripen...
#  2557993  Motivación de logro y rendimiento académico en...
#  108388   Replication Data for: Medicare for All, Some, ...
#  501714   Genome-wide expression ChIP analysis of mouse ...
#  738418    mutations induced by carbon ion beam irradiation
#  1086457  Reduced membrane fouling in an anaerobic elect...
#  1172347  3-(4-Fluoro-benzyl-idene)-1,5-dioxa-spiro-[5.5...
#  604696   Laboratory cell enriched microbial communities...
#  1081644  RNAseq from cuticles of tumor free (w1118) and...
#  2669142  On the Diversity and Frequency of Code Related...
#  492802   Tildeniella torsiva UHER 1998/13D and co-occur...
#  667557   Sorted cell/s from Aspo Hard Rock Laboratory (...
#  1490662  MicroRNA Profiling in Mucosal Biopsies of Eosi...
#  641655   16S rRNA gene amplicon sequencing of the micro...
#  405806   Sorted cell/s from subterranean lake water in ...
#  576683   Reference genome for the Human Microbiome Project
#  367623            Histone ChIP-seq from A549 (ENCSR325VCV)
#  1027773  RNA-seq analysis of neutrophils from CD40L-def...
#  1701284  Genome binding of SMARCA2 and SMARCA4 in lung ...
#  119974   Restricted Access WFHS Leef Baseline Employee/...
#  2645817                  SciExpeM - 10.5281/zenodo.5137123
#  2641336  Data collected from interviews with PMs' about...
#  2605986                        Liberia Synthetic Ecosystem
#  156788   simulating lake ice phenology using a coupled ...
#
#                                                 Description          Model  \
#  565446   The goal is to determine the genetic variabili...  gpt-3.5-turbo
#  648274   Transcriptomic and metabolomic profiling revea...  gpt-3.5-turbo
#  2557993  La matriz de datos contiene las siguientes var...  gpt-3.5-turbo
#  108388   Data and commands to replicate all analyses in...  gpt-3.5-turbo
#  501714   We report binding profiles for SPOC1 (PHF13) i...  gpt-3.5-turbo
#  738418   To understand the feature of genetic mutations...  gpt-3.5-turbo
#  1086457  Reduced membrane fouling in an anaerobic elect...  gpt-3.5-turbo
#  1172347  In the title mol-ecule, C(16)H(15)FO(4), the f...  gpt-3.5-turbo
#  604696   Large-scale microbial genome analysis of sampl...  gpt-3.5-turbo
#  1081644  RNAseq from cuticles of tumor free (w1118) and...  gpt-3.5-turbo
#  2669142  Supplementary Material to: On the Diversity an...  gpt-3.5-turbo
#  492802   Tildeniella torsiva UHER 1998/13D and co-occur...  gpt-3.5-turbo
#  667557   Sorted cells from the Aspo Hard Rock Laborator...  gpt-3.5-turbo
#  1490662  This SuperSeries is composed of the SubSeries ...  gpt-3.5-turbo
#  641655   These results provide new insight and suppleme...  gpt-3.5-turbo
#  405806   Sorted cells from subterranean lake water in W...  gpt-3.5-turbo
#  576683   Reference genome for the Human Microbiome Proj...  gpt-3.5-turbo
#  367623   H3K27ac ChIP-seq on A549 cell line treated wit...  gpt-3.5-turbo
#  1027773  RNA-seq analysis of neutrophils from CD40L-def...  gpt-3.5-turbo
#  1701284  Genome binding of SMARCA2 and SMARCA4 in lung ...  gpt-3.5-turbo
#  119974   Release 3 of the restricted-access data for th...  gpt-3.5-turbo
#  2645817  Krejci, Michael C.; Mathieu, Olivier; Vissotsk...  gpt-3.5-turbo
#  2641336  We interview professionals who work with proje...  gpt-3.5-turbo
#  2605986  Liberia synthetic ecosystem dataset consisting...  gpt-3.5-turbo
#  156788   This is a supporting data for 'simulating lake...  gpt-3.5-turbo
#
#                                                 Predictions  \
#  565446                  {Microbiology, Genetics, Genomics}
#  648274      {Metabolomics, Transcriptomics, Plant biology}
#  2557993                                                 {}
#  108388                                   {Data management}
#  501714             {Bioinformatics, Genomics, Epigenetics}
#  738418         {Genetic variation, Genetics, DNA mutation}
#  1086457  {Zoology, Environmental sciences, Membrane and...
#  1172347                     {X-ray diffraction, Chemistry}
#  604696   {Microbiology, Metagenomics, Environmental sci...
#  1081644              {Genomics, Genetics, Transcriptomics}
#  2669142  {Computational biology, Computer science, Data...
#  492802     {Biodiversity, Zoology, Environmental sciences}
#  667557          {Microbiology, Cell biology, Metagenomics}
#  1490662                {RNA, Immunology, Gastroenterology}
#  641655    {Microbiology, Genetics, Environmental sciences}
#  405806   {Microbial ecology, Metagenomics, Environmenta...
#  576683   {Bioinformatics, Sequence assembly, Metagenomics}
#  367623          {Genomics, Epigenomics, Molecular biology}
#  1027773            {Immunology, Genetics, Transcriptomics}
#  1701284                      {Genomics, Biology, Oncology}
#  119974   {Public health and epidemiology, Human genetic...
#  2645817                                                 {}
#  2641336   {Data mining, Computer science, Data management}
#  2605986  {Zoology, Environmental sciences, Synthetic bi...
#  156788   {Freshwater biology, Environmental sciences, E...
#
#                                              Hallucinations  \
#  565446                                               set()
#  648274                                               set()
#  2557993         {'Education', 'Mathematics', 'Psychology'}
#  108388                 {'Political science', 'Healthcare'}
#  501714                                               set()
#  738418                                       {'Mutations'}
#  1086457                                              set()
#  1172347  {'Crystallography', 'Molecular structure analy...
#  604696                                               set()
#  1081644                                              set()
#  2669142                                              set()
#  492802                                               set()
#  667557                                               set()
#  1490662                                              set()
#  641655                                               set()
#  405806                                               set()
#  576683                                               set()
#  367623                                               set()
#  1027773                                              set()
#  1701284               {'Tumour biology', 'Cancer biology'}
#  119974                                    {'Epidemiology'}
#  2645817  {'Engineering', 'Gas turbines', 'Turbo machine...
#  2641336                                              set()
#  2605986                                              set()
#  156788                                               set()
#
#                                    _id                       Repository
#  565446             NCBI_SRA_SRP312848                         NCBI SRA
#  648274             NCBI_SRA_SRP341840                         NCBI SRA
#  2557993                  ZENODO_20836                           Zenodo
#  108388   Dataverse_10.7910_DVN_NAH0FD                Harvard Dataverse
#  501714             NCBI_SRA_SRP071306                         NCBI SRA
#  738418             NCBI_SRA_SRP401051                         NCBI SRA
#  1086457                     PRJEB9642  Omics Discovery Index (OmicsDI)
#  1172347                 S-EPMC3051599  Omics Discovery Index (OmicsDI)
#  604696             NCBI_SRA_SRP118366                         NCBI SRA
#  1081644                   PRJNA738503  Omics Discovery Index (OmicsDI)
#  2669142                ZENODO_1252323                           Zenodo
#  492802             NCBI_SRA_SRP284490                         NCBI SRA
#  667557             NCBI_SRA_SRP142705                         NCBI SRA
#  1490662                  E-GEOD-36727  Omics Discovery Index (OmicsDI)
#  641655             NCBI_SRA_SRP337219                         NCBI SRA
#  405806             NCBI_SRA_SRP154788                         NCBI SRA
#  576683             NCBI_SRA_SRP001679                         NCBI SRA
#  367623                      GSE175172                         NCBI GEO
#  1027773                    PRJEB18810  Omics Discovery Index (OmicsDI)
#  1701284                   PRJNA613396  Omics Discovery Index (OmicsDI)
#  119974   Dataverse_10.7910_DVN_SJ7PYT                Harvard Dataverse
#  2645817                ZENODO_5137122                           Zenodo
#  2641336                ZENODO_3965804                           Zenodo
#  2605986                 ZENODO_574066                           Zenodo
#  156788            Mendeley_bpjcbdkj4c                         Mendeley  )

# %%
sample_rows_10 = sample_rows_10.assign(identifier='10 or less')
sample_rows_11_20 = sample_rows_11_20.assign(identifier='11-20')
sample_rows_21_30 = sample_rows_21_30.assign(identifier='21-30')
sample_rows_31_40 = sample_rows_31_40.assign(identifier='31-40')

sample_rows = pd.concat([sample_rows_10, sample_rows_11_20, sample_rows_21_30, sample_rows_31_40], ignore_index=True)

# %%
sample_rows.rename(columns={'identifier': 'Number of Words'}, inplace=True)

# %%
sample_rows.drop(columns=['Predictions', 'Hallucinations'], inplace=True)

# %%
sample_rows['Name'] = sample_rows['Name'].fillna('')
sample_rows['Description'] = sample_rows['Description'].fillna('')

# %%
sample_rows
# Out:
#                                                  Name  \
# 0                                      hou02665c01004
# 1           Lactiplantibacillus plantarum strain:IRG1
# 2                       Listeria monocytogenes SHL015
# 3
# 4   Sequencing INFLUENZA A VIRUS (A/MEMPHIS/3/1973...
# ..                                                ...
# 95  Законы о бюджете города Москвы на 2014-2018 го...
# 96  Effects of water temperature on gut microbiota...
# 97  Microbial community characteristics of the int...
# 98  Data for Triple Bottom Line towards a holistic...
# 99  Data for: Common and Fundamental Risk Factors ...
#
#                                           Description          Model  \
# 0                                                   L  gpt-3.5-turbo
# 1   Lactobacillus plantarum IRG1 Genome sequencing...  gpt-3.5-turbo
# 2   Listeria monocytogenes SHL015 Genome sequencin...  gpt-3.5-turbo
# 3   Identifying SNPs in the D1RatMgh8 microsatteli...  gpt-3.5-turbo
# 4                                                      gpt-3.5-turbo
# ..                                                ...            ...
# 95  Ведомственная структура расходов бюджета город...  gpt-3.5-turbo
# 96  To describe the impact of temperature on the g...  gpt-3.5-turbo
# 97  Microbial community characteristics of the int...  gpt-3.5-turbo
# 98  Artigos utilizados para revisão sistemática da...  gpt-3.5-turbo
# 99  The data set contains the time-series for the ...  gpt-3.5-turbo
#
#                           filepath                           _id  \
# 0    outputs/harvard_processed.csv  Dataverse_10.7910_DVN_BA39BT
# 1    outputs/omicsdi_processed.csv                   PRJNA428424
# 2    outputs/omicsdi_processed.csv                   PRJNA218932
# 3    outputs/omicsdi_processed.csv                    PRJEB27381
# 4   outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP206023
# ..                             ...                           ...
# 95    outputs/zenodo_processed.csv                ZENODO_4539989
# 96  outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP404127
# 97  outputs/ncbi_sra_processed.csv            NCBI_SRA_SRP367441
# 98  outputs/mendeley_processed.csv           Mendeley_dz58cvs99d
# 99  outputs/mendeley_processed.csv           Mendeley_br52s4mrw7
#
#                          Repository Number of Words
# 0                 Harvard Dataverse      10 or less
# 1   Omics Discovery Index (OmicsDI)      10 or less
# 2   Omics Discovery Index (OmicsDI)      10 or less
# 3   Omics Discovery Index (OmicsDI)      10 or less
# 4                          NCBI SRA      10 or less
# ..                              ...             ...
# 95                           Zenodo           31-40
# 96                         NCBI SRA           31-40
# 97                         NCBI SRA           31-40
# 98                         Mendeley           31-40
# 99                         Mendeley           31-40
#
# [100 rows x 7 columns]

# %%
sample_rows.to_csv('outputs/word_count_sample.csv', index=False)

# %% [markdown]
# ## Get empty set IDs
#
# Get IDs of data with no predictions

# %%
empty_set_ids = combined_df[combined_df['Predictions'].apply(len) == 0][['_id', 'Name', 'Description']]
empty_set_ids.reset_index(drop=True, inplace=True)

# %%
empty_set_ids.to_csv('outputs/empty_set_ids.csv', index=False)

# %% [markdown]
# ### Get samples of specific repositories

# %%
# Define the word count ranges
word_count_ranges = [
    (0, 10),
    (11, 20),
    (21, 30),
    (31, 40)
]

# Initialize an empty list to store the samples
samples = []

# Iterate over each repository
for repository in combined_df['Repository'].unique():
    if repository not in ['Harvard Dataverse', 'Zenodo', 'Mendeley']:
        continue
    repository_df = combined_df[combined_df['Repository'] == repository]
    
    # Iterate over each word count range
    for word_count_range in word_count_ranges:
        min_count, max_count = word_count_range
        
        # Get the samples with the specified word count range
        samples_in_range = repository_df[
            (repository_df['Name'].str.split().str.len() + repository_df['Description'].str.split().str.len() >= min_count) &
            (repository_df['Name'].str.split().str.len() + repository_df['Description'].str.split().str.len() <= max_count)
        ]

        # Take a sample of 5 rows or all rows if there are fewer than 5
        samples_in_range = samples_in_range.sample(n=min(5, len(samples_in_range)))
        
        samples_in_range['Word Count Range'] = f'{min_count}-{max_count} words'

        # Append the samples to the list
        samples.append(samples_in_range)

# Concatenate the list of samples DataFrames into a single DataFrame
samples_df = pd.concat(samples)

samples_df
# Out:
#                                                       Name  \
# 124630   Konzeptstudie über die Kompatibilität von Regi...
# 84529                                        A13_24998.jpg
# 126477                                      hou00201c00035
# 100504                                       A12_22337.JPG
# 63299                                Gent_2009_Peperstraat
# 110355   Replication Data for: Sequential Monte Carlo f...
# 60573         Farm inventory surveys in Rwanda: Birds data
# 108335   Replication Data for: A meta-analytic cognitiv...
# 62233    Romeinse constructie onder water, Maasbodem. P...
# 104282              State Legislative Historical Elections
# 84321    Replication Data for The Rise of Finance Compa...
# 74966    Replication Data for: Heterogeneous Solar Capa...
# 65457    Deventer, Bergschild 7. Projectnummer dendroch...
# 83765    Replication materials for: The origins of pers...
# 112879   Diretório e Executivas Nacionais - Brasil - Pa...
# 114872   Replication Data for: Effect of oil spills on ...
# 78038        Supplementary Figures for Bridging Sightlines
# 93404    Dataset of physico-chemical water parameters, ...
# 112961   Replication Data for: Endogenous taxation in o...
# 61729    Le Dictionnaire topographique. Une API pour le...
# 150338                                    Shear test data.
# 147433                                       Dermal Images
# 174260                                      LINF_260014700
# 152338   Towards High Performance Flexible Planar Super...
# 179658                                      LINF_230008300
# 190929                                      LINF_360025400
# 181537                            Moh Adib Jauhar PTIK UAS
# 173279   Data for: Controlling Interfacial Reactions of...
# 152582   Data for: Integrated chemostratigraphy (δ13C-δ...
# 140721    JDCR-D-21-00326R3, Pyoderma gangrenosum in a ...
# 149332   Data for: Global and local sensitivity analysi...
# 152396   Echolocating bats rapidly adjust their mouth g...
# 164270   Data for: Up-regulation of TNF Receptor-associ...
# 166593   Data for: A method of estimating the future me...
# 192971   A missing link in the evolution of dasytine so...
# 176095   Data for: Why should I pay more?  Testing the ...
# 190910            Two spearheads in Late Bronze Age hoards
# 169863   Data for: A Late Maeotian age for the enigmati...
# 166677                                             Dataset
# 165532   Clinical, laboratory, and radiologic findings ...
# 2681733                                 finals_2019_07_158
# 2728442           urticina_crassicornis_zanfona_1.fasta.gz
# 2718920              paeonia_lactiflora_spades_01.fasta.gz
# 2681584                                 finals_2019_07_379
# 2707851                  Chitala chitala decontaminated gx
# 2678087                       QoS values and QoS functions
# 2634289                               Polinomio cuadrático
# 2675256                   PowerTAC 2015-04 Finals Game 170
# 2719767  Anisotropic Superconductivity at KTaO3(111) in...
# 2641763                            20191212_rr07_sp56_ds11
# 2761640  Acetaldehyde binding energies: a coupled exper...
# 2671477  Multiplexed imaging reveals an IFN-γ-driven in...
# 2665278  Thromboprophylaxis in patients admitted to sur...
# 2693331  The future of coal investment, trade and stran...
# 2709405  AirGAM 2022r1 input data for all stations 2005...
# 2666618  Raw data - Macronutrient balance has opposing ...
# 2744128  Temporal emotional valence asymmetry influence...
# 2752696  Natural history specimens collected and/or ide...
# 2727949  Natural history specimens collected and/or ide...
# 2724575  Natural history specimens collected and/or ide...
#
#                                                Description          Model  \
# 124630                                                   I  gpt-3.5-turbo
# 84529    Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
# 126477                                                   D  gpt-3.5-turbo
# 100504   Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
# 63299                 Dendrochronological research project  gpt-3.5-turbo
# 110355                                                   R  gpt-3.5-turbo
# 60573                               Birds data from Rwanda  gpt-3.5-turbo
# 108335                                                   R  gpt-3.5-turbo
# 62233                 Dendrochronological research project  gpt-3.5-turbo
# 104282   State legislative general elections prior to 1...  gpt-3.5-turbo
# 84321    Stata code and non-proprietary data to replica...  gpt-3.5-turbo
# 74966    Replication Data for: Heterogeneous Solar Capa...  gpt-3.5-turbo
# 65457    Dendrochronological research project. The meas...  gpt-3.5-turbo
# 83765    Code for Stata and R to reproduce all tables a...  gpt-3.5-turbo
# 112879   Partidos Políticos do Brasil, Diretórios, Exec...  gpt-3.5-turbo
# 114872   This repository provides replication data for ...  gpt-3.5-turbo
# 78038    This set of figures contains the cornerplots o...  gpt-3.5-turbo
# 93404    This dataset presents the composition of selec...  gpt-3.5-turbo
# 112961   Replication Material for "Endogenous taxation ...  gpt-3.5-turbo
# 61729    Abstract and poster of paper 0681 presented at...  gpt-3.5-turbo
# 150338                                     Shear test data  gpt-3.5-turbo
# 147433   Original Images used for dermal image enhancem...  gpt-3.5-turbo
# 174260   protein kinase\nLeishmania infantum (strain JP...  gpt-3.5-turbo
# 152338                                    data manuscript   gpt-3.5-turbo
# 179658   tryptophanyl-tRNA synthetase | mt-TrpRS\nLeish...  gpt-3.5-turbo
# 190929   kinetoplastid kinetochore protein 1 | KKT1\nLe...  gpt-3.5-turbo
# 181537   Mencari jurnal penelitian sesuai intruksi Dari...  gpt-3.5-turbo
# 173279                                    data supplement   gpt-3.5-turbo
# 152582                                 Trace elements data  gpt-3.5-turbo
# 140721                   Supplemental data for case report  gpt-3.5-turbo
# 149332             Results obtained with the box-GRS model  gpt-3.5-turbo
# 152396   3D Tracking, acoustic, and simulation were gen...  gpt-3.5-turbo
# 164270         Validation of antibodies used in this study  gpt-3.5-turbo
# 166593   the data used is on world meteorological organ...  gpt-3.5-turbo
# 192971   Full-resolution image stack (TIFF) and model i...  gpt-3.5-turbo
# 176095   Perception of price unfairness and the demogra...  gpt-3.5-turbo
# 190910   This is supplementary data for the publication...  gpt-3.5-turbo
# 169863   Table.1 Calcareous nannofossils and diatoms fr...  gpt-3.5-turbo
# 166677   This file contains the daily spot prices, futu...  gpt-3.5-turbo
# 165532   A companion code and data repository for the s...  gpt-3.5-turbo
# 2681733                     Log and boot files of game 158  gpt-3.5-turbo
# 2728442                                                  .  gpt-3.5-turbo
# 2718920                                                  .  gpt-3.5-turbo
# 2681584                     Log and boot files of game 379  gpt-3.5-turbo
# 2707851                                                  .  gpt-3.5-turbo
# 2678087  Experiment results of QoS values and QoS funct...  gpt-3.5-turbo
# 2634289  Representación gráfica de un polinomio cuadrát...  gpt-3.5-turbo
# 2675256                     Log and boot files of game 170  gpt-3.5-turbo
# 2719767  Raw transport data for Anisotropic Superconduc...  gpt-3.5-turbo
# 2641763  Dataset supporting the article Behavioral fing...  gpt-3.5-turbo
# 2761640  CRYSTAL17  output files of the atomic structur...  gpt-3.5-turbo
# 2671477  MIBI-TOF images, segmentation output, cell phe...  gpt-3.5-turbo
# 2665278  This is a dataset for a clinical audit done in...  gpt-3.5-turbo
# 2693331  Dataset to support the publication "The future...  gpt-3.5-turbo
# 2709405  Contains EEA Airbase/AQ e-Reporting data and E...  gpt-3.5-turbo
# 2666618  This file contains the dataset used in the pap...  gpt-3.5-turbo
# 2744128  This repository contains the data used for the...  gpt-3.5-turbo
# 2752696  Natural history specimen data collected and/or...  gpt-3.5-turbo
# 2727949  Natural history specimen data collected and/or...  gpt-3.5-turbo
# 2724575  Natural history specimen data collected and/or...  gpt-3.5-turbo
#
#                                                Predictions  \
# 124630                                                  {}
# 84529    {Informatics, "Data submission, annotation, an...
# 126477   {"Data architecture, analysis and design", "Da...
# 100504   {Data integration and warehousing, Informatics...
# 63299           {Ecology, Biology, Environmental sciences}
# 110355   {Computational biology, Genetics, "Data archit...
# 60573        {Biodiversity, Agricultural science, Zoology}
# 108335   {Computational biology, "Data architecture, an...
# 62233                             {Environmental sciences}
# 104282                                                  {}
# 84321           {"Data architecture, analysis and design"}
# 74966    {Data integration and warehousing, Environment...
# 65457    {Data integration and warehousing, Biology, Mo...
# 83765    {Computational biology, Data integration and w...
# 112879                                   {Data governance}
# 114872   {Ecology, Public health and epidemiology, Envi...
# 78038                                            {Physics}
# 93404      {Ecology, Biodiversity, Environmental sciences}
# 112961                                                  {}
# 61729    {Data integration and warehousing, Computer sc...
# 150338   {Bioinformatics, Structural biology, Biotechno...
# 147433   {Dermatology, "Data architecture, analysis and...
# 174260              {Bioinformatics, Genetics, Proteomics}
# 152338                                                  {}
# 179658          {Microbiology, Biochemistry, Parasitology}
# 190929     {Molecular biology, Cell biology, Parasitology}
# 181537   {Data integration and warehousing, Data mining...
# 173279                           {Chemistry, Biomaterials}
# 152582                  {Biology, Biodiversity, Chemistry}
# 140721                   {Dermatology, Zoology, Pathology}
# 149332   {"Data architecture, analysis and design", Env...
# 152396             {Acoustics, Molecular biology, Physics}
# 164270               {Immunology, Animal study, Neurology}
# 166593   {Data mining, Open science, Environmental scie...
# 192971            {Evolutionary biology, Biology, Zoology}
# 176095                                                  {}
# 190910                                                  {}
# 169863                           {Biology, Marine biology}
# 166677                 {Data mining, Agricultural science}
# 165532   {Medicine, Public health and epidemiology, Inf...
# 2681733  {Computer science, Data management, Data visua...
# 2728442  {Genomics, Biodiversity, "Data submission, ann...
# 2718920             {Genomics, Biology, Molecular biology}
# 2681584  {Data integration and warehousing, Computer sc...
# 2707851  {Genetic variation, Molecular biology, Animal ...
# 2678087  {Data mining, "Data architecture, analysis and...
# 2634289        {Computational biology, Data visualisation}
# 2675256  {Data integration and warehousing, Computer sc...
# 2719767                               {Physics, Chemistry}
# 2641763                     {Medicine, Biology, Chemistry}
# 2761640  {"Molecular interactions, pathways and network...
# 2671477              {Bioinformatics, Immunology, Ecology}
# 2665278  {Data integration and warehousing, Data mining...
# 2693331             {Carbon cycle, Environmental sciences}
# 2709405          {Data management, Environmental sciences}
# 2666618       {Biology, Animal study, Nutritional science}
# 2744128         {"Data architecture, analysis and design"}
# 2752696                  {Genetics, Biodiversity, Zoology}
# 2727949  {Biodiversity, "Data submission, annotation, a...
# 2724575              {Microbiology, Biodiversity, Zoology}
#
#                                             Hallucinations  \
# 124630   {'Mechanical engineering', 'Aerospace engineer...
# 84529                                                set()
# 126477                                               set()
# 100504                                               set()
# 63299             {'Dendrochronological research project'}
# 110355                                               set()
# 60573                                                set()
# 108335                                               set()
# 62233                  {'Archaeology', 'Dendrochronology'}
# 104282   {'Social sciences', 'Political science', 'Rese...
# 84321       {'Banking', 'Small business', 'Data analysis'}
# 74966                        {'', 'Renewable energy', 'I'}
# 65457                                                set()
# 83765                                                set()
# 112879                   {'Political science', 'Election'}
# 114872                                               set()
# 78038                        {'Astrobiology', 'Astronomy'}
# 93404                                                set()
# 112961    {'Economics', 'Statistics', 'Political science'}
# 61729                                                set()
# 150338                                               set()
# 147433                                               set()
# 174260                                               set()
# 152338   {'Flexible electronics', 'Electrochemistry', '...
# 179658                                               set()
# 190929                                               set()
# 181537                                               set()
# 173279                               {'Materials science'}
# 152582                                         {'Geology'}
# 140721                                               set()
# 149332                                               set()
# 152396                                               set()
# 164270                                               set()
# 166593                                               set()
# 192971                                               set()
# 176095         {'Psychology', 'Demographics', 'Marketing'}
# 190910             {'History', 'Archaeology', 'Geography'}
# 169863                       {'Climate scienc', 'Geology'}
# 166677                                       {'Analytics'}
# 165532                                               set()
# 2681733                             {'Data visualization'}
# 2728442                                              set()
# 2718920                                              set()
# 2681584                                              set()
# 2707851                                              set()
# 2678087                             {'Experiment results'}
# 2634289                                    {'Mathematics'}
# 2675256                                              set()
# 2719767                       {'Condensed matter physics'}
# 2641763                            {'Predictive medicine'}
# 2761640                                              set()
# 2671477                                              set()
# 2665278                                              set()
# 2693331                                 {'Energy science'}
# 2709405                                    {'Meteorology'}
# 2666618                                              set()
# 2744128  {'Temporal analysis', 'Data analysis', 'Psycho...
# 2752696                                              set()
# 2727949                                              set()
# 2724575                                              set()
#
#                                    _id         Repository Word Count Range
# 124630    Dataverse_10.7910_DVN_UMKWCI  Harvard Dataverse       0-10 words
# 84529     Dataverse_10.7910_DVN_CJDNIE  Harvard Dataverse       0-10 words
# 126477    Dataverse_10.7910_DVN_VH5JLZ  Harvard Dataverse       0-10 words
# 100504    Dataverse_10.7910_DVN_JOAUYR  Harvard Dataverse       0-10 words
# 63299        Dataverse_10.34894_JBLFCO  Harvard Dataverse       0-10 words
# 110355    Dataverse_10.7910_DVN_O38OCG  Harvard Dataverse      11-20 words
# 60573    Dataverse_10.34725_DVN_JMJWYS  Harvard Dataverse      11-20 words
# 108335    Dataverse_10.7910_DVN_N9EJNR  Harvard Dataverse      11-20 words
# 62233        Dataverse_10.34894_DAILQJ  Harvard Dataverse      11-20 words
# 104282    Dataverse_10.7910_DVN_LEMNXZ  Harvard Dataverse      11-20 words
# 84321     Dataverse_10.7910_DVN_CGBBYP  Harvard Dataverse      21-30 words
# 74966     Dataverse_10.7910_DVN_69JI12  Harvard Dataverse      21-30 words
# 65457        Dataverse_10.34894_UQEGVF  Harvard Dataverse      21-30 words
# 83765     Dataverse_10.7910_DVN_C6WCUY  Harvard Dataverse      21-30 words
# 112879    Dataverse_10.7910_DVN_PBDZKH  Harvard Dataverse      21-30 words
# 114872    Dataverse_10.7910_DVN_Q7MM1G  Harvard Dataverse      31-40 words
# 78038     Dataverse_10.7910_DVN_8ZFKW1  Harvard Dataverse      31-40 words
# 93404     Dataverse_10.7910_DVN_GHOIM4  Harvard Dataverse      31-40 words
# 112961    Dataverse_10.7910_DVN_PCM2O2  Harvard Dataverse      31-40 words
# 61729        Dataverse_10.34894_AFYDEK  Harvard Dataverse      31-40 words
# 150338             Mendeley_7gm4rgfkyk           Mendeley       0-10 words
# 147433             Mendeley_5zwc6n6pjg           Mendeley       0-10 words
# 174260             Mendeley_nj8pcc8psh           Mendeley       0-10 words
# 152338             Mendeley_8h8zggfnrh           Mendeley       0-10 words
# 179658             Mendeley_s7s4c9nyn5           Mendeley       0-10 words
# 190929             Mendeley_yvjbpp89xp           Mendeley      11-20 words
# 181537             Mendeley_t5dyns635c           Mendeley      11-20 words
# 173279             Mendeley_n2mb4mf59x           Mendeley      11-20 words
# 152582             Mendeley_8m68g4wbwd           Mendeley      11-20 words
# 140721             Mendeley_2nmgm9s9bc           Mendeley      11-20 words
# 149332             Mendeley_6zdh4tzs4v           Mendeley      21-30 words
# 152396             Mendeley_8hwzr7jjmc           Mendeley      21-30 words
# 164270             Mendeley_gh9473zddg           Mendeley      21-30 words
# 166593             Mendeley_hntgbjm7b8           Mendeley      21-30 words
# 192971             Mendeley_zwrcvtjn6n           Mendeley      21-30 words
# 176095             Mendeley_pg9pp8srjz           Mendeley      31-40 words
# 190910             Mendeley_yv9z2ht3pm           Mendeley      31-40 words
# 169863             Mendeley_k9rr66tr9n           Mendeley      31-40 words
# 166677             Mendeley_hpt29c4hjj           Mendeley      31-40 words
# 165532             Mendeley_h55cyhs82c           Mendeley      31-40 words
# 2681733                 ZENODO_3339851             Zenodo       0-10 words
# 2728442                 ZENODO_8168159             Zenodo       0-10 words
# 2718920                 ZENODO_7931267             Zenodo       0-10 words
# 2681584                 ZENODO_3341136             Zenodo       0-10 words
# 2707851                 ZENODO_6676242             Zenodo       0-10 words
# 2678087                 ZENODO_1476814             Zenodo      11-20 words
# 2634289                 ZENODO_2541865             Zenodo      11-20 words
# 2675256                 ZENODO_1091359             Zenodo      11-20 words
# 2719767                 ZENODO_7459761             Zenodo      11-20 words
# 2641763                 ZENODO_4674342             Zenodo      11-20 words
# 2761640                 ZENODO_7495558             Zenodo      21-30 words
# 2671477                 ZENODO_5500722             Zenodo      21-30 words
# 2665278                 ZENODO_7255105             Zenodo      21-30 words
# 2693331                 ZENODO_4629990             Zenodo      21-30 words
# 2709405                 ZENODO_6334170             Zenodo      21-30 words
# 2666618                 ZENODO_6826897             Zenodo      31-40 words
# 2744128                 ZENODO_7415422             Zenodo      31-40 words
# 2752696                 ZENODO_8312447             Zenodo      31-40 words
# 2727949                 ZENODO_8151323             Zenodo      31-40 words
# 2724575                 ZENODO_8031009             Zenodo      31-40 words

# %%
samples_df.drop(['Predictions', 'Hallucinations'], axis=1, inplace=True)

# %%
samples_df.reset_index(drop=True, inplace=True)

# %%
samples_df.to_csv('outputs/hzm_word_count_samples.csv', index=False)

# %%
filename = 'outputs/hzm.csv'
outputs = pd.read_csv(filename, lineterminator='\n')

# %%
outputs['Predictions'] = outputs['Predictions'].apply(lambda preds: [re.sub(r'^\d+\.\s*', '', pred).strip('- ') for pred in preds.split('\n')])

# %%
samples_df.head()
# Out:
#                                                 Name  \
# 0  Konzeptstudie über die Kompatibilität von Regi...
# 1                                      A13_24998.jpg
# 2                                     hou00201c00035
# 3                                      A12_22337.JPG
# 4                              Gent_2009_Peperstraat
#
#                                          Description          Model  \
# 0                                                  I  gpt-3.5-turbo
# 1  Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
# 2                                                  D  gpt-3.5-turbo
# 3  Link to OCHRE database: http://pi.lib.uchicago...  gpt-3.5-turbo
# 4               Dendrochronological research project  gpt-3.5-turbo
#
#                             _id         Repository Word Count Range
# 0  Dataverse_10.7910_DVN_UMKWCI  Harvard Dataverse       0-10 words
# 1  Dataverse_10.7910_DVN_CJDNIE  Harvard Dataverse       0-10 words
# 2  Dataverse_10.7910_DVN_VH5JLZ  Harvard Dataverse       0-10 words
# 3  Dataverse_10.7910_DVN_JOAUYR  Harvard Dataverse       0-10 words
# 4     Dataverse_10.34894_JBLFCO  Harvard Dataverse       0-10 words

# %%
if all(samples_df['_id'] == outputs['_id']):
    outputs['Repository'] = samples_df['Repository']
    outputs['Word Count Range'] = samples_df['Word Count Range']

# %%
outputs.to_csv(filename, index=False, lineterminator='\n')
