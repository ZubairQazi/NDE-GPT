# %%
import requests
from tqdm.notebook import tqdm

# %%
response = requests.get('http://api.data.niaid.nih.gov/v1/query?q=lincs&fetch_all=true').json()

# %%
names = []
descriptions = []

for record in tqdm(response['hits']):
    if 'name' not in record:
        names.append('No name')
    else:
        names.append(record['name'])
    if 'description' not in record:
        descriptions.append('No description')
    else:
        descriptions.append(record['description'])

names, descriptions
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# (['LINCS - preprocessed',
#   'Columbia LINCS Trans-Center project data',
#   'LINCS Canvas Browser: interactive web app to query, browse and interrogate LINCS L1000 gene expression signatures.',
#   'LINCS MCF10A GRNs calculated with ANANSE',
#   'Systematic Quality Control Analysis of LINCS Data.',
#   'Compound signature detection on LINCS L1000 big data.',
#   'L1000 Dataset -small molecule perturbagens- LINCS Phase 1',
#   'L1000 Dataset -small molecule perturbagens- LINCS Joint Project',
#   'L1000 Dataset -small molecule perturbagens- LINCS Trans-Center Project',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics LINCS PHASE *II* (n=354,123; updated March 30, 2017)',
#   'Drug-induced adverse events prediction with the LINCS L1000 data.',
#   'broadinstitute/lincs-cell-painting: Full release of LINCS Cell Painting dataset',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics LINCS Pilot PHASE I (n=1,319,138; updated March 03, 2017)',
#   'L1000 Dataset -small molecule perturbagens- LINCS Phase 2 (June 2015)',
#   'L1000 Dataset -small molecule, CRISPR perturbagens- LINCS Phase 2 (March 2017)',
#   'L1000 Dataset -small molecule, CRISPR perturbagens- LINCS Phase 2 (December 2015)',
#   'Harnessing the biological complexity of Big Data from LINCS gene expression signatures.',
#   'Perturbational proteomic and transcriptional profiles of drug perturbations from Broad Institute LINCS Proteomic Characterization Center for Signaling and Epigenetics and Broad Institute LINCS Center for Transcriptomics (U54HG008097) (n=5,063)',
#   'LINCS L1000 dataset-based repositioning of CGP-60474 as a highly potent anti-endotoxemic agent.',
#   'l1kdeconv: an R package for peak calling analysis with LINCS L1000 data.',
#   'Coarse-grained simulations of a phase-separated membrane with different LINCS settings (part 1/3)',
#   'Coarse-grained simulations of a phase-separated membrane with different LINCS settings (part 2/3)',
#   'Coarse-grained simulations of a phase-separated membrane with different LINCS settings (part 3/3)',
#   'Ontological representation, integration, and analysis of LINCS cell line cells and their cellular responses.',
#   'L1000 Dataset - small molecule, nucleic acid perturbagens - LINCS Phase 2 (December 2021)',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics (NIH U54HL127366) [part 12]',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics (NIH U54HL127366) [part 11]',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics (NIH U54HL127366) [part 3]',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics (NIH U54HL127366) [part 9]',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics (NIH U54HL127366) [part 4]',
#   'L1000 Connectivity Map perturbational profiles from Broad Institute LINCS Center for Transcriptomics (NIH U54HL127366) [part 5]',
#   'Metrics for growth responses of MDA-MB-231 and HME-1 cell lines to LINCS Pilot Phase TransCenter Project kinase inhibitors',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 9 of 9: Calculated dose-response metrics for biological replicate 3',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 7 of 15: End-point dose-response metrics for biological replicate 1.',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 15 of 15: Calculated dose-response metrics.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 9 of 15: End-point dose-response metrics for biological replicate 3.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 8 of 9: Calculated dose-response metrics for biological replicate 2',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 8 of 15: End-point dose-response metrics for biological replicate 2.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 14 of 15: Time-dependent dose-response metrics for biological replicate 2.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 13 of 15: Time-dependent dose-response metrics for biological replicate 1.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 15 of 15: Time-dependent dose-response metrics for biological replicate 3.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 7 of 9: Calculated dose-response metrics for biological replicate 1',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 11 of 15: Time-dependent mean normalized growth rate inhibition values for biological replicate 2.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 1 of 9: Cell count and normalized growth rate inhibition values for biological replicate 1',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 10 of 15: Time-dependent mean normalized growth rate inhibition values for biological replicate 1.',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 1 of 15: Cell count and relative growth within biological replicate 1.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 3 of 9: Cell count and normalized growth rate inhibition values for biological replicate 3',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 2 of 9: Cell count and normalized growth rate inhibition values for biological replicate 2',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 6 of 9: Mean cell count and mean normalized growth rate inhibition values for biological replicate 3',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Repeat performed by Scientist B in 2019 to assess reproducibility. Dataset 2 of 2: Calculated dose response metrics.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Repeat performed by Scientist C to assess reproducibility. Dataset 1 of 2: Normalized growth rate inhibition values. ',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Repeat performed by Scientist A in 2019 to assess reproducibility. Dataset 1 of 2: Normalized growth rate inhibition values. ',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Repeat performed by Scientist C in 2019 to assess reproducibility. Dataset 2 of 2: Calculated dose response metrics.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 5 of 9: Mean cell count and mean normalized growth rate inhibition values for biological replicate 2',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 4 of 9: Mean cell count and mean normalized growth rate inhibition values for biological replicate 1',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Repeat performed by Scientist A in 2019 to assess reproducibility. Dataset 2 of 2: Calculated dose response metrics.',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 7 of 15: Mean cell count and mean growth rate across all replicates.',
#   'LINCS MCF 10A Common Project: Fixed-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Repeat performed by Scientist B in 2019 to assess reproducibility. Dataset 1 of 2: Normalized growth rate inhibition values. ',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 6 of 15: Mean cell count and mean growth rate across biological replicate 3.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 5 of 15: End-point mean cell counts and mean normalized growth rate inhibition values for biological replicate 2.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 2 of 15: End-point cell counts and normalized growth rate inhibition values for all technical replicates of biological replicate 2.',
#   'LINCS MCF 10A Common Project: Rolling-time-point sensitivity measures of the MCF 10A breast cell line to 8 small molecule perturbagens. Dataset 3 of 15: End-point cell counts and normalized growth rate inhibition values for all technical replicates of biological replicate 3.',
#   'LINCS MCF 10A Common Project: Highly-multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with 8 small molecule perturbagens. Dataset 4 of 6: Nuclear fluorescent intensity measurements at 48 hr.',
#   'LINCS MCF 10A Common Project: Highly-multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with 8 small molecule perturbagens. Dataset 1 of 6: Cytosolic fluorescent intensity measurements at 24 hr.',
#   'LINCS MCF 10A Common Project: Highly-multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with 8 small molecule perturbagens. Dataset 3 of 6: Cytosolic fluorescent intensity measurements at 48 hr.',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 12 of 15: Mean cell count and mean normalized growth rate inhibition values across biological replicate 2.',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 11 of 15: Mean cell count and mean normalized growth rate inhibition values across biological replicate 1.',
#   'LINCS MCF 10A Common Project: Highly-multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with 8 small molecule perturbagens. Dataset 2 of 6: Nuclear fluorescent intensity measurements at 24 hr.',
#   'LINCS MCF 10A Common Project: Highly-multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with 8 small molecule perturbagens. Dataset 5 of 6: Cytosolic fluorescent intensity measurements at 72 hr.',
#   'LINCS Pilot Phase Joint Project: Sensitivity measures of six breast cancer cell lines to a library of small molecule kinase inhibitors (single drug treatments). Dataset 13 of 15: Mean cell count and mean normalized growth rate inhibition values across biological replicate 3.',
#   'Ribociclib KINOMEscan',
#   'Torkinib KINOMEscan',
#   'BMX-IN-1 KINOMEscan',
#   'JNK-IN-11 KINOMEscan',
#   'BI-D1870 KINOMEscan',
#   'Tang Proliferation/Mitosis',
#   'Moerke 3 Color Apoptosis',
#   'BX795 KiNativ -- single dose experiment',
#   'On the impact of different templates on creating and understanding user stories - Supplemental Material',
#   'L1000 MCF10A Deep Dive Dataset: treatment with ligands',
#   'ReNcell differentiation: Phosphoproteomics during differentiation under basal conditions. Dataset 2 of 3',
#   'Ceritinib KINOMEscan',
#   'THZ-2-98-01 KINOMEscan',
#   'RNA-seq MCF10A Deep Dive Dataset: treatment with ligands',
#   'NG25 KINOMEscan',
#   'WZ4003 KINOMEscan',
#   'SCH772984 KINOMEscan',
#   'Bosutinib KINOMEscan',
#   'AS601245 KINOMEscan',
#   'Binding affinity of 6 small molecule JAK inhibitors for 5 kinases',
#   'Moerke 2 Color Apoptosis',
#   'ReNcell differentiation: Total proteomics during differentiation under basal conditions. Dataset 1 of 3',
#   'A549 cells -- High-throughput Secretomic Analysis of Single Cells',
#   'U87 cells -- High-throughput Secretomic Analysis of Single Cells',
#   'U937 cells -- High-throughput Secretomic Analysis of Single Cells',
#   'High-content imaging of six breast cancer cell lines treated with a library of small molecule kinase inhibitors.',
#   'RPPA MCF10A Deep Dive Dataset: treatment with ligands',
#   'Targeted metabolomics profiling data (i.e., peak intensity measurements) after acute exposure of BT-549 cells to DMSO or rapamycin, AZD8055 or Torin2 at two doses (100nM, 1000nM) for 6 hours. ',
#   'CyC IF MCF10A Deep Dive Dataset: treatment with ligands',
#   'GCP MCF10A Deep Dive Dataset: treatment with ligands',
#   'ReNcell differentiation: Total proteomics during differentiation with small molecule perturbagens. Dataset 3 of 3',
#   'MEMA HMEC240L Staining Set C',
#   'MEMA HCC1954 Staining Set 100 (DMSO control)',
#   'MEMA AU565 Staining Set 100 (Lapatinib treatment)',
#   'MEMA HMEC240L Staining Set 4',
#   'MEMA MCF10A Staining Set 3',
#   'MEMA HMEC122L Staining Set 1',
#   'MEMA AU565 Staining Set 100 (DMSO control)',
#   'Synovial Fibroblast 1: Secretion response of primary human synovial fibroblast samples from one healthy and one rheumatoid arthritis donor to a panel of 10 stimuli and 10 small molecule inhibitors',
#   'Breast Cancer Cell Density: Imaging assay of the density- and context-dependence of small molecule perturbagen response in breast cancer cell lines. Dataset 1 of 3: Cell count and normalized growth rate inhibition values.',
#   'Synovial Fibroblast 3.1: Secretion response of seven primary human synovial fibroblast samples from healthy and rheumatoid arthritis donors to a panel of 3 stimuli and 5 small molecule inhibitors (replicate 1 of 2)',
#   'PLSR model loadings (pMEK and pERK included) from analysis of the covariation of molecular signals with cell viability and apoptosis fraction in BRAF(V600E/D) melanoma cell lines',
#   'MEMA MCF10A Staining Set 1',
#   'MEMA HMEC122L Staining Set 4',
#   'MEMA HMEC122L Staining Set C',
#   'MEMA MCF10A Staining Set 2 no H3',
#   'MEMA HMEC240L Staining Set 1',
#   'MEMA MCF10A Staining Set I',
#   'MEMA MCF10A Staining Set C',
#   'MEMA HCC1954 Staining Set 100 (Lapatinib treatment)',
#   'Breast Cancer Deubiquitinating Enzyme (DUB) Inhibitor Profiling: Fixed-cell GR measures of 21 breast cell lines to 32 small molecule perturbagens. Dataset 1 of 2: Normalized growth rate inhibition values.',
#   'Growth factor-induced ERK activity pulsing dynamics in a mammary epithelial cell line. Dataset 3 of 3: mean reporter pulsing metrics.',
#   'Evaluation of the sensitivity of two triple-negative breast cancer cell lines (HCC1806, HCC70) to a collection of dual mTOR and PI3K-like kinase (PIKK) inhibitors. Dataset 2 of 2: GR metrics.',
#   'Breast Cancer Profiling Project, Gene Expression 1: Baseline mRNA sequencing on 35 breast cell lines',
#   'Evaluation of the sensitivities of six triple-negative breast cancer (TNBC) cell lines to 23 different PI3K/AKT/mTOR inhibitors or to a MEK inhibitor (trametinib). Dataset 2 of 2: GR metrics.',
#   'Growth factor-induced ERK activity and FoxO3a nuclear-cytoplasmic pulsing dynamics in a mammary epithelial cell line. Dataset 1 of 1: single-cell reporter measurements.',
#   'PLSR model loadings (pMEK and pERK excluded) from analysis of the covariation of molecular signals with cell viability and apoptosis fraction in BRAF(V600E/D) melanoma cell lines',
#   'Growth rate-corrected (GR) dose-response metric signatures across a panel of 71 breast cancer cell lines treated with a library of small molecule and antibody perturbagens. Dataset 3 of 4: Median, upper quartile, and lower quartile GR metrics per perturbagen. ',
#   'Evaluation of the sensitivity of two triple-negative breast cancer cell lines (HCC1806, HCC70) to a collection of dual mTOR and PI3K-like kinase (PIKK) inhibitors. Dataset 1 of 2: GR values.',
#   'Breast Cancer Profiling Project - Proteomics 2: 1 phosphoproteome dataset (including phosphotyrosine enrichment) for a 35-cell line breast cancer panel under basal conditions ',
#   'MEMA MCF10A Deep Dive Dataset: treatment with ligands',
#   'Growth factor-induced ERK activity pulsing dynamics in a mammary epithelial cell line. Dataset 1 of 3: single-cell reporter measurements.',
#   'Growth factor-induced ERK activity pulsing dynamics in a mammary epithelial cell line. Dataset 2 of 3: single-cell reporter pulsing metrics.',
#   'IGF-I-induced FoxO3a nuclear-cytoplasmic pulsing dynamics in mammary epithelial cell lines following treatment with increasing doses of an AKT inhibitor. Dataset 1 of 3: single-cell reporter measurements.',
#   'EGF-induced FoxO3a nuclear-cytoplasmic pulsing dynamics in mammary epithelial cell lines following treatment with increasing doses of a MEK inhibitor. Dataset 3 of 3: mean reporter pulsing metrics.',
#   'diMN (Exp 3) - ALS and Control (unaffected) diMN cell lines differentiated from iPS cell lines using a short and direct differentiation protocol - Proteomics',
#   'IGF-I-induced FoxO3a nuclear-cytoplasmic pulsing dynamics in mammary epithelial cell lines following treatment with increasing doses of an AKT inhibitor. Dataset 3 of 3: mean reporter pulsing metrics.',
#   'Evaluation of the sensitivities of six triple-negative breast cancer (TNBC) cell lines to 23 different PI3K/AKT/mTOR inhibitors or to a MEK inhibitor (trametinib). Dataset 1 of 2: GR values.',
#   'EGF-induced FoxO3a nuclear-cytoplasmic pulsing dynamics in mammary epithelial cell lines following treatment with increasing doses of a MEK inhibitor. Dataset 2 of 3: single-cell reporter pulsing metrics.',
#   'Growth rate-corrected (GR) dose-response metric signatures across a panel of 71 breast cancer cell lines treated with a library of small molecule and antibody perturbagens. Dataset 4 of 4: Median, upper quartile, and lower quartile GR metrics per perturbagen class.',
#   'Immunofluorescence MCF10A Deep Dive Dataset: treatment with ligands',
#   'FoxO3a nuclear-cytoplasmic pulsing dynamics in a mammary epithelial cell line following growth-factor treatment with varying ERK/AKT activation loads. Dataset 2 of 3: single-cell reporter pulsing metrics.',
#   'Growth factor-induced FoxO3a nuclear-cytoplasmic pulsing dynamics of non-phosphorylatable reporters in mammary epithelial cell lines. Dataset 1 of 3: single-cell reporter measurements.',
#   'Growth factor-induced FoxO3a nuclear-cytoplasmic pulsing dynamics of non-phosphorylatable reporters in mammary epithelial cell lines. Dataset 2 of 3: single-cell reporter pulsing metrics.',
#   'Phosphorylation state and protein levels measured by imaging in BRAF(V600E/D) melanoma cell lines following treatment with combinations of two compounds (immunofluorescence dataset 2 of 4)',
#   'Protein levels measured by imaging in BRAF(V600E/D) melanoma cell lines following treatment with Vemurafenib in combination with chromatin-targeting compounds (immunofluorescence dataset 3 of 4)',
#   'Tyrosine Kinase Inhibitor-induced cardiotoxicity in hiPSC derived cardiomyocytes - pilot dataset',
#   'Growth factor-induced FoxO3a nuclear-cytoplasmic pulsing dynamics of non-phosphorylatable reporters in mammary epithelial cell lines. Dataset 3 of 3: mean reporter pulsing metrics.',
#   'FoxO3a nuclear-cytoplasmic pulsing dynamics in a mammary epithelial cell line following growth-factor treatment with varying ERK/AKT activation loads. Dataset 3 of 3: mean reporter pulsing metrics.',
#   'MEMA MCF7 Staining Set 1',
#   'MEMA YAPC Staining Set 2',
#   'Breast Cancer Profiling Project - Proteomics',
#   'GCP aggregated data - Chemical perturbations',
#   'Multiplexed imaging of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with nine kinase inhibitors',
#   'GCP - Drug treatment of vascular cell model systems',
#   'Breast Cancer Deubiquitinating Enzyme (DUB) Inhibitor Profiling: Fixed-cell GR measures of 21 breast cell lines to 32 small molecule perturbagens. Dataset 2 of 2: Calculated dose response metrics.',
#   'GCP data - neurodev compounds',
#   'LINCS-data',
#   'A review of connectivity map and computational approaches in pharmacogenomics.',
#   'GCP data - Selected Cell Lines treated with an HSP90 inhibitor',
#   'GCP - Selected chemical agents in schizophrenia patient-derived neural progenitor cells',
#   'MEMA MCF7 Staining Set 2',
#   'MEMA MCF7 Staining Set 3',
#   'MEMA YAPC Staining Set 3',
#   'GCP data - epigenetic compounds',
#   'MEMA PC3 Staining Set 3',
#   'MEMA PC3 Staining Set 1',
#   'MEMA PC3 Staining Set 2',
#   'MEMA YAPC Staining Set 1',
#   'Breast Cancer Profiling Project, Drug Sensitivity phase II: Fixed-cell GR measures of 33 breast cell lines and PDX lines to 16 small molecule perturbagens from library plate II. Dataset 2 of 2: Calculated dose response metrics',
#   'Breast Cancer Profiling Project, Drug Sensitivity 1: Fixed-cell GR measures of 35 breast cell lines to 34 small molecule perturbagens. Dataset 2 of 2: Calculated dose response metrics.',
#   'Breast Cancer Profiling Project, Drug Sensitivity phase II: Fixed-cell GR measures of 33 breast cell lines and PDX lines to 16 small molecule perturbagens from library plate II. Dataset 1 of 2: Normalized growth rate inhibition values',
#   'Breast Cancer Profiling Project - Proteomics 3: 1 total proteome dataset for a 27-cell line breast cancer panel under basal conditions ',
#   'Highly multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the COLO 858 melanoma cell line',
#   'ATAC-Seq MCF10A Deep Dive Dataset: treatment with ligands',
#   'Breast Cancer Profiling Project, Drug Sensitivity 1: Fixed-cell GR measures of 35 breast cell lines to 34 small molecule perturbagens. Dataset 1 of 2: Normalized growth rate inhibition values.',
#   'Cellarium single cell metabolic profiling assay',
#   'Transcriptomics dataset (March 2016)',
#   'Tyrosine Kinase Inhibitor-induced cardiotoxicity in hiPSC derived cardiomyocytes - pilot dataset (qPCR validation)',
#   'Breast cell line dose response to target inhibition measured by high throughput microscopy',
#   'P100 data - neurodev compounds',
#   'Homo sapiens',
#   'L1000 gene expression profiling assay - DOS small molecule perturbagens',
#   'P100 data - epigenetic compounds',
#   'MEMA PC3 Staining Set 2 no H3',
#   'GCP data - kinase inhibitors',
#   'Transcriptomics dataset (June 2015)',
#   'Cell signaling response to growth factors measured by high throughput microscopy',
#   'Breast Cancer Profiling Project - Proteomics 1: 1 total proteome dataset for a 35-cell line breast cancer panel under basal conditions',
#   'P100 aggregated data - Chemical perturbations',
#   'FoxO3a nuclear-cytoplasmic pulsing dynamics in a mammary epithelial cell line following growth-factor treatment with varying ERK/AKT activation loads. Dataset 1 of 3: single-cell reporter measurements.',
#   'IGF-I-induced FoxO3a nuclear-cytoplasmic pulsing dynamics in mammary epithelial cell lines following treatment with increasing doses of an AKT inhibitor. Dataset 2 of 3: single-cell reporter pulsing metrics.',
#   'EGF-induced FoxO3a nuclear-cytoplasmic pulsing dynamics in mammary epithelial cell lines following treatment with increasing doses of a MEK inhibitor. Dataset 1 of 3: single-cell reporter measurements.',
#   'Metrics other than potency reveal systematic variation in responses to cancer drugs',
#   'Cell signaling response to cytokines measured by high throughput microscopy',
#   'Basal profile of receptor tyrosine kinase signaling network measured by ELISA',
#   'Growth rate-corrected (GR) dose-response metrics across a panel of 71 breast cancer cell lines treated with a library of small molecule and antibody perturbagens. Dataset 2 of 4: Calculated dose-response metrics. ',
#   'MEMA PC3 cell line dataset',
#   'Domain-Specific Language domain analysis and evaluation: a systematic literature review',
#   'diMN (Exp 3) - ALS and Control (unaffected) diMN cell lines differentiated from iPS cell lines using a short and direct differeintiation protocol - RNA-seq',
#   'Drug-drug synergy results from titration experiments',
#   'cyc D activation dynamics in MCF10A cells treated with the four core compounds.',
#   'iMN (Exp 2) - ALS, SMA and Control (unaffected) iMN cell lines differentiated from iPS cell lines using a long differentiation protocol - RNA-seq',
#   'Tyrosine Kinase Inhibitor-induced cardiotoxicity in hiPSC derived cardiomyocytes - Proteomics',
#   'Growth rate-corrected (GR) dose-response metrics across a panel of 71 breast cancer cell lines treated with a library of small molecule and antibody perturbagens. Dataset 1 of 4: Relative cell counts and normalized growth rate inhibition values across technical replicates.',
#   'Phosphorylation state and protein levels measured by imaging in BRAF(V600E/D) melanoma cell lines following treatment with combinations of two compounds (immunofluorescence dataset 1 of 4)',
#   'Phosphorylation state and protein levels measured by imaging in BRAF(V600E/D) melanoma cell lines following treatment with combinations of two compounds (immunofluorescence dataset 4 of 4)',
#   'Data for "A Random Walk" manuscript',
#   'DCC-2036 KiNativ -- single dose experiment',
#   'GCP aggregated data - CRISPR perturbations',
#   'GCP data - Chemical perturbations (MCF10A Common Project)',
#   'Live-cell imaging of cell-to-cell variability in caspase-8 FRET reporter activity and cell fate trajectory modeling',
#   'Sustainable data and metadata management at the BD2K-LINCS Data Coordination and Integration Center.',
#   'Multiplexed imaging of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with EGF',
#   'WZ3105 KiNativ -- single dose experiment',
#   'PCI-32765 KiNativ -- single dose experiment',
#   'Assessing user stories: the influence of template differences and gender-related problem-solving styles - Supplemental material',
#   'Deep Learning Benchmarks on L1000 Gene Expression Data.',
#   'Viability and apoptosis measured by imaging in BRAF(V600E/D) melanoma cell lines following treatment with combinations of three compounds (viability/apoptosis dataset 2 of 2)',
#   'Simulations of DPPC/DOPC/CHOL 2/1/1 mixture using the model by Carpenter et al., Part 3',
#   'Simulations of DPPC/DOPC/CHOL 3/3/2 mixture using the model by Carpenter et al., Part 3',
#   'Viability and apoptosis measured by imaging in BRAF(V600E/D) melanoma cell lines following treatment with combinations of two compounds (viability/apoptosis dataset 1 of 2)',
#   'Aggregated ChEMBL bioactivity data (v20)',
#   'Highly-multiplexed imaging by Cyclic Immunofluorescence (CycIF) of protein levels and protein phosphorylation states in the MCF 10A breast cell line treated with EGF or four kinase inhibitors',
#   'PD173074 KINOMEscan',
#   'XMD8-92 KiNativ -- single dose experiment',
#   'QL-X-138 KiNativ -- single dose experiment',
#   'XMD-12 KiNativ -- single dose experiment',
#   'XMD16-144 KiNativ -- single dose experiment',
#   'JWE-035 KiNativ -- single dose experiment',
#   'XMD11-50 KiNativ -- single dose experiment',
#   'XMD8-85 KiNativ -- single dose experiment',
#   'NPK76-II-72-1 KiNativ -- single dose experiment',
#   'P100 aggregated data - CRISPR perturbations',
#   'PLX-4720 KiNativ -- dose response experiment',
#   'JNK-IN-8 KiNativ -- single dose experiment',
#   'P100 data - Chemical perturbations (MCF10A Common Project)',
#   'CI-1033 KINOMEscan',
#   'WZ-1-84 KINOMEscan',
#   'Cell Painting morphological profiling assay',
#   'L1000 Consensus Signatures - shRNA perturbagens',
#   'WZ-4-145 KINOMEscan',
#   'WZ-7043 KINOMEscan',
#   'R406 KINOMEscan',
#   'A443654 KINOMEscan',
#   'AZ-628 KiNativ -- dose response experiment',
#   'Torin1 KiNativ -- single dose experiment',
#   'Sorafenib KiNativ -- dose response experiment',
#   'QL-XII-47 KiNativ -- single dose experiment',
#   'Torin2 KiNativ -- single dose experiment',
#   'NVP-BHG712 KiNativ -- multiple dose experiment',
#   'CH5424802 KiNativ -- single dose experiment',
#   '5z-7-oxozeaenol KiNativ -- single dose experiment',
#   'L1000 Consensus Signatures - CRISPR perturbagens',
#   'XMD11-85h KINOMEscan',
#   'XMD8-85 KINOMEscan',
#   'NPK76-II-72-1 KINOMEscan',
#   'JW-7-24-1 KINOMEscan',
#   'BMS-536924 KINOMEscan',
#   'BI-2536 KINOMEscan',
#   'ALW-II-38-3 KINOMEscan',
#   'ALW-II-49-7 KINOMEscan',
#   'A770041 KINOMEscan',
#   'PLX4032 KiNativ -- dose response experiment',
#   'Random-primed mRNA-sequencing transcriptomic dataset for 70 primary human cardiomyocyte cell samples',
#   "3'-DGE mRNA-sequencing transcriptomic dataset for 914 primary human cardiomyocyte cell samples",
#   'iMN (Exp 2) - iMN long Differentiation protocol - Imaging',
#   'PI3K inhibitors protect against glucocorticoid-induced skin atrophy.',
#   'FOXM1 functions collaboratively with PLAU to promote gastric cancer progression.',
#   'RO-3306 KINOMEscan',
#   'GSK429286A KINOMEscan',
#   'HKI-272 KINOMEscan',
#   'PLX4032 KINOMEscan',
#   'SB590885 KINOMEscan',
#   'CP724714 KINOMEscan',
#   'AZD-6482 KINOMEscan',
#   'XMD11-50 KINOMEscan',
#   'PLX-4720 KINOMEscan',
#   'PF02341066 KINOMEscan',
#   'Viability and apoptosis in BRAF(V600E/D) melanoma cell lines monitored by imaging',
#   'PF-3758309 KiNativ -- single dose experiment',
#   'BS-181 KINOMEscan',
#   'QL-XI-92 KINOMEscan',
#   'ZG-10 KINOMEscan',
#   'KU63794 KINOMEscan',
#   'Torin1 KINOMEscan',
#   'BMS345541 KINOMEscan',
#   'JWE-035 KINOMEscan',
#   'WZ3105 KINOMEscan',
#   '(R)-Roscovitine KINOMEscan',
#   'HG-6-64-1 KINOMEscan',
#   'ZM-447439 KINOMEscan',
#   'Datasets Used in Evaluation Of RNAi And CRISPR Technologies By Large Scale Gene Expression Profiling In The Connectivity Map',
#   'JNK-IN-5A KINOMEscan',
#   'CYT387 KINOMEscan',
#   'PHA-767491 KINOMEscan',
#   'GW843682 KINOMEscan',
#   'AZD4547 KINOMEscan',
#   'JNK-IN-8 KINOMEscan',
#   'OTSSP167 KINOMEscan',
#   'BX-912 KINOMEscan',
#   'AZ-628 KINOMEscan',
#   'XMD13-2 KINOMEscan',
#   'GSK2126458 KINOMEscan',
#   'AZD 5438 KINOMEscan',
#   'HG-14-8-02 KINOMEscan',
#   'KIN001-220 KINOMEscan',
#   'CP466722 KINOMEscan',
#   'PD0332991 KINOMEscan',
#   'XMD15-27 KINOMEscan',
#   'JNK-9L KINOMEscan',
#   'WYE-125132 KINOMEscan',
#   'NU7441 KINOMEscan',
#   'XMD14-99 KINOMEscan',
#   'Dinaciclib KINOMEscan',
#   'PD0325901 KINOMEscan',
#   'iMN (Exp 2) - ALS, SMA and Control (unaffected) iMN cell lines differentiated from iPS cell lines using a long differentiation protocol - Proteomics',
#   'Phosphorylation state and protein levels measured in BRAF(V600E/D) melanoma cell lines monitored by imaging',
#   'Average variable importance in the projection (VIP) scores from the PLSR models analyzing the covariation of molecular signals with cell viability and apoptosis fraction in BRAF(V600E/D) melanoma cell lines',
#   'AS-252424 KINOMEscan',
#   'ZSTK474 KINOMEscan',
#   'TGX221 KINOMEscan',
#   'Aggregated Tox21 bioactivity data',
#   'MPS-1-IN-1 KINOMEscan',
#   'WH-4-025 KINOMEscan',
#   'Proteomic cellular signatures of kinase inhibitor-induced cardiotoxicity',
#   'ERK and Akt activation dynamics in MCF10A cells treated with the four core compounds.',
#   'Discovering the anti-cancer potential of non-oncology drugs by systematic PRISM profiling',
#   'iPSC (Exp 1) - ALS, SMA and Control (unaffected) subject-derived iPSC lines - RNA-seq',
#   'BEZ235 KINOMEscan',
#   'A Next Generation Connectivity Map: L1000 Platform and the First 1,000,000 Profiles.',
#   'Measuring Cancer Drug Sensitivity and Resistance in Cultured Cells.',
#   'On transformative adaptive activation functions in neural networks for gene expression inference.',
#   'iPSC (Exp 1) - ALS, SMA and Control (unaffected) subject-derived iPSC lines- ATAC-seq',
#   'diMN (Exp 3) - ALS and Control (unaffected) diMN cell lines differentiated from iPS cell lines using a short and direct differeintiation protocol - Proteomics',
#   'iPSC (Exp 1) - ALS, SMA and Control (unaffected) subject-derived iPSC lines - SWATH-MS',
#   'GW-5074 KiNativ -- dose response experiment',
#   'SB590885 KiNativ -- dose response experiment',
#   'OTSSP167 KiNativ -- single dose experiment',
#   'EGF and Insulin combination dose and dynamic response of ERK, AKT, and mTOR signaling and the cell cycle (Cyclin D1) in serum- and growth-factor starved MCF10A cells.',
#   'XMD11-85h KiNativ -- single dose experiment',
#   '(s)-CR8 KINOMEscan',
#   'Broad Institute L1000 Connectivity Map and RNAseq gene expression profiles on tissue samples from the GTEx project',
#   'SP600125 KINOMEscan',
#   'HG-5-88-01 KINOMEscan',
#   'CGP60474 KINOMEscan',
#   'KIN001-127 KINOMEscan',
#   'GDC-0941 KINOMEscan',
#   'XMD8-92 KINOMEscan',
#   'BGJ398 KINOMEscan',
#   'Ibrutinib KINOMEscan',
#   'Baricitinib KINOMEscan',
#   'Abemaciclib KINOMEscan',
#   'NVP-TAE684 KINOMEscan',
#   'HG-5-113-01 KINOMEscan',
#   'WZ4002 KINOMEscan',
#   'Improving the Developer Experience with a Low-Code ProcessModelling Language: Companion site',
#   'Ibrutinib KiNativ -- single dose experiment',
#   'diMN (Exp 3) - ALS and Control (unaffected) diMN cell lines differentiated from iPS cell lines using a short and direct differeintiation protocol - ATAC-seq',
#   'iMN (Exp 2) - ALS, SMA and Control (unaffected) iMN cell lines differentiated from iPS cell lines using a long differentiation protocol - ATAC-seq',
#   'Imatinib KINOMEscan',
#   'R406 KINOMEscan-2',
#   'Pazopanib KINOMEscan',
#   'TG-101348 KINOMEscan',
#   'RAF-265 KINOMEscan',
#   'BIRB-796 KINOMEscan',
#   'Dasatinib KINOMEscan',
#   'HKI-272 KINOMEscan-2',
#   'LY-317615 KINOMEscan',
#   'Erlotinib KINOMEscan',
#   'GSK-461364A KINOMEscan',
#   'Ki-20227 KINOMEscan',
#   'Sorafenib KINOMEscan-2',
#   'Vandetanib KINOMEscan',
#   'GDC-0941 KINOMEscan-2',
#   'CEP-701 KINOMEscan',
#   'New ways to boost molecular dynamics simulations.',
#   'HG-6-64-01 KiNativ -- single dose experiment',
#   'PLX-4720 KINOMEscan-2',
#   'TAE-684 KINOMEscan',
#   'AZD-1152HQPA KINOMEscan-2',
#   'GSK-690693 KINOMEscan',
#   'Sunitinib KINOMEscan',
#   'GSK-1363089 KINOMEscan',
#   'SKI-606 KINOMEscan',
#   'MLN-8054 KINOMEscan',
#   'XMD-12 KINOMEscan',
#   'PHA-793887 KINOMEscan',
#   'HG-9-91-01 KINOMEscan',
#   'CGP74514A KINOMEscan',
#   'Sorafenib KINOMEscan',
#   'AZD7762 KINOMEscan',
#   'WH-4-023 KINOMEscan',
#   'TAK-715 KINOMEscan',
#   'Sigma A6730 KINOMEscan',
#   'AG1478 KINOMEscan',
#   'PHA-665752 KINOMEscan',
#   'AB-1010 KINOMEscan',
#   'VX-745 KINOMEscan',
#   'PKC-412 KINOMEscan',
#   'TKI-258 KINOMEscan',
#   'BYL719 KINOMEscan',
#   'BMS-345541 KINOMEscan',
#   'KW-2449 KINOMEscan',
#   'AC220 KINOMEscan',
#   'BIBW-2992 KINOMEscan',
#   'VX-680 KINOMEscan',
#   'Nilotinib KINOMEscan',
#   'SGX-523 KINOMEscan',
#   'Buparlisib KINOMEscan',
#   'PI-103 KINOMEscan',
#   'BI-2536 KINOMEscan-2',
#   'BMS-540215 KINOMEscan',
#   'AZD-6244 KINOMEscan',
#   'SB-203580 KINOMEscan',
#   'Gefitinib KINOMEscan',
#   'CG-930 KINOMEscan',
#   'Dabrafenib KINOMEscan',
#   'HG-14-10-04 KINOMEscan',
#   'GW-5074 KINOMEscan',
#   'GSK461364 KINOMEscan',
#   'MLN8054 KINOMEscan',
#   '5z-7-oxozeaenol KINOMEscan',
#   'AZD1152-HQPA KINOMEscan',
#   'QL-X-138 KINOMEscan',
#   'Torin2 KINOMEscan',
#   'XMD16-144 KINOMEscan',
#   'GSK1059615 KINOMEscan',
#   'Lapatinib KINOMEscan',
#   'Drug/Cell-line Browser: interactive canvas visualization of cancer drug/cell-line viability assay datasets.',
#   'Holistic optimization of an RNA-seq workflow for multi-threaded environments.',
#   'Connectivity Analyses of Bioenergetic Changes in Schizophrenia: Identification of Novel Treatments.',
#   'Transcriptomic profiling of human hippocampal progenitor cells treated with antidepressants and its application in drug repositioning.',
#   'Computational Drug Repositioning for Gastric Cancer using Reversal Gene Expression Profiles.',
#   'Centralized scientific communities are less likely to generate replicable results.',
#   'In Vitro and In Vivo Pipeline for Validation of Disease-Modifying Effects of Systems Biology-Derived Network Treatments for Traumatic Brain Injury-Lessons Learned.',
#   'Deep Learning Applications for Predicting Pharmacological Properties of Drugs and Drug Repurposing Using Transcriptomic Data.',
#   'Transcriptional profiling of LS1034 cells treated with tepoxalin',
#   'CGP082996 KINOMEscan',
#   'Molecular dynamics simulation trajectory of a fully hydrated DMPC lipid bilayer',
#   'Analysis of Post-TBI Gene Expression Signature Reveals Tubulins, NFE2L2, NFkB, CD44, and S100A4 as Treatment Targets for Traumatic Brain Injury',
#   'Genetic and transcriptional variation alters cancer cell line drug response',
#   'Genetic and transcriptional variation alters cancer cell line drug response [MCF7 strain L]',
#   'MGH (CMT) Growth Inhibition Assay Protocol (9 compound doses: 10.24 uM to 0.04 uM) -- DNA Staining',
#   'Inhibition of the neuromuscular acetylcholine receptor with atracurium activates FOXO/DAF-16-induced longevity (RNA-seq)',
#   'Systematically studying kinase inhibitor induced signaling network signatures by integrating both therapeutic and side effects.',
#   'BMS-387032 KINOMEscan',
#   'BIBF-1120 KINOMEscan',
#   'GSK-1838705A KINOMEscan',
#   'CI-1040 KINOMEscan',
#   'CI-1033 KINOMEscan-2',
#   'Transcriptomics-Based Drug Repurposing Approach Identifies Novel Drugs against Sorafenib-Resistant Hepatocellular Carcinoma.',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 6/94 mol% DMTAP/DMPC in 1.0 M NaCl',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 50/50 mol% DMTAP/DMPC in 1.0 M NaCl',
#   'Transcriptomics-based drug repurposing approach identifies novel drugs against sorafenib-resistant hepatocellular carcinoma',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 75/25 mol% DMTAP/DMPC in 1.0 M NaCl',
#   'INCB018424 KINOMEscan',
#   'GDC-0879 KINOMEscan',
#   'ABT-869 KINOMEscan',
#   'CP-690550 KINOMEscan',
#   'AT-7519 KINOMEscan',
#   'Flavopiridol KINOMEscan',
#   'Crizotinib KINOMEscan-2',
#   'MRT67307 KINOMEscan',
#   'Palbociclib KINOMEscan',
#   ' QL-XII-47 KINOMEscan',
#   'Transcriptional profiling of SF295 cells following MTF1 knockout by CRISPR/Cas9',
#   'AMG-706 KINOMEscan',
#   'Lapatinib KINOMEscan-2',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 75/25 mol% DMTAP/DMPC',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 50/50 mol% DMTAP/DMPC in 0.1 M NaCl',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 75/25 mol% DMTAP/DMPC in 0.1 M NaCl',
#   'Gene expression data of four cancer cell lines (A375, A549, MCF7, and PC3) treated with KR-37524',
#   'STL427944 suppresses FOXM1 via nuclear export and subsequent autophagic degradation',
#   'Analysis of Post-TBI Gene Expression Signature Reveals Tubulins, NFE2L2, NFkB, CD44, and S100A4 as Treatment Targets for Traumatic Brain Injury',
#   'Modulating membrane fluidity corrects Batten disease phenotypes in vitro and in vivo.',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 50/50 mol% DMTAP/DMPC in 0.5 M NaCl',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 6/94 mol% DMTAP/DMPC',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 75/25 mol% DMTAP/DMPC in 0.5 M NaCl',
#   'Molecular dynamics simulation trajectory of a cationic lipid bilayer: 50/50 mol% DMTAP/DMPC',
#   'SigMat: a classification scheme for gene signature matching.',
#   'GDC-0941 KINOMEscan-3',
#   'Taselisib KINOMEscan',
#   'Effects of mannose-binding lectin on pulmonary gene expression and innate immune inflammatory response to ozone.',
#   'Drug Gene Budger (DGB): an application for ranking drugs to modulate a specific gene based on transcriptomic signatures.',
#   'Screening of Drug Repositioning Candidates for Castration Resistant Prostate Cancer.',
#   'Translating in vitro CFTR rescue into small molecule correctors for cystic fibrosis using the Library of Integrated Network-based Cellular Signatures drug discovery platform',
#   'Transcriptomic metaanalyses of autistic brains reveals shared gene expression and biological pathway abnormalities with cancer.',
#   'LINCS-NeuroLINCS',
#   'Genetic and transcriptional variation alters cancer cell line drug response',
#   'Inhibition of the neuromuscular acetylcholine receptor with atracurium activates FOXO/DAF-16-induced longevity (RNA-seq)',
#   'Regulation of TROP2 expression in breast cancer',
#   'Multi-omics Analysis reveals novel therapeutic vulnerabilities in lung cancer',
#   'Encoding growth factor identity in the temporal dynamics of FoxO3 under the combinatorial control of ERK and AKT Kinases',
#   'Improving the Usability of a MAS DSML',
#   'Homo sapiens',
#   'TRANSCRIPT drug repurposing dataset',
#   'Homo sapiens',
#   'STL427944 suppresses FOXM1 via nuclear export and subsequent autophagic degradation',
#   'Data from: Gut microbiome critically impacts PCB-induced changes in metabolic fingerprints and the hepatic transcriptome in mice'],
#  ['<p>LINCS - PDRGC - preprocessed</p>',
#   'The Library of Integrated Network-based Cellular Signatures (LINCS) is a multi-institutional, collaborative project initiated by the National Institutes of Health whose goal is to identify and categorize molecular signatures that occur when cells are exposed to agents that perturb their normal function. Understanding how perturbations affect the behavior of cells is important because it can provide insights into the causes of disease and help researchers develop new therapeutic strategies.',
#   'For the Library of Integrated Network-based Cellular Signatures (LINCS) project many gene expression signatures using the L1000 technology have been produced. The L1000 technology is a cost-effective method to profile gene expression in large scale. LINCS Canvas Browser (LCB) is an interactive HTML5 web-based software application that facilitates querying, browsing and interrogating many of the currently available LINCS L1000 data. LCB implements two compacted layered canvases, one to visualize clustered L1000 expression data, and the other to display enrichment analysis results using 30 different gene set libraries. Clicking on an experimental condition highlights gene-sets enriched for the differentially expressed genes from the selected experiment. A search interface allows users to input gene lists and query them against over 100 000 conditions to find the top matching experiments. The tool integrates many resources for an unprecedented potential for new discoveries in systems biology and systems pharmacology. The LCB application is available at http://www.maayanlab.net/LINCS/LCB. Customized versions will be made part of the http://lincscloud.org and http://lincs.hms.harvard.edu websites.',
#   '<p>GRNs calculated using ANANSE presumably active in LINCS MCF10A cell cultures perturbated with various TFs.</p>',
#   'The Library of Integrated Cellular Signatures (LINCS) project provides comprehensive transcriptome profiling of human cell lines before and after chemical and genetic perturbations. Its L1000 platform utilizes 978 landmark genes to infer the transcript levels of 14,292 genes computationally. Here we conducted the L1000 data quality control analysis by using MCF7, PC3, and A375 cell lines as representative examples. Before perturbations, a promising 80% correlation in transcriptome was observed between L1000- and Affymetrix HU133A-platforms. After library-based shRNA perturbations, a moderate 30% of differentially expressed genes overlapped between any two selected controls viral vectors using the L1000 platform. The mitogen-activated protein kinase, vascular endothelial growth factor, and T-cell receptor pathways were identified as the most significantly shared pathways between chemical and genetic perturbations in cancer cells. In conclusion, L1000 platform is reliable in assessing transcriptome before perturbation. Its response to perturbagens needs to be interpreted with caution. A quality control analysis pipeline of L1000 is recommended before addressing biological questions.',
#   'The Library of Integrated Network-based Cellular Signatures (LINCS) L1000 big data provide gene expression profiles induced by over 10?000 compounds, shRNAs, and kinase inhibitors using the L1000 platform. We developed csNMF, a systematic compound signature discovery pipeline covering from raw L1000 data processing to drug screening and mechanism generation. The csNMF pipeline demonstrated better performance than the original L1000 pipeline. The discovered compound signatures of breast cancer were consistent with the LINCS KINOMEscan data and were clinically relevant. The csNMF pipeline provided a novel and complete tool to expedite signature-based drug discovery leveraging the LINCS L1000 resources.',
#   'Transcriptional profiles of cultured human cancer cell lines treated with small molecules: Expression of 978 representative genes is measured in 39 cell lines perturbed by 13 thousands of small molecules.',
#   'Transcriptional profiles of cultured human breast cancer cell lines treated with small molecules: 5 cell lines are treated with 109 small molecules and the expression of 978 representative genes is measured, as a part of the LINCS Joint Project.',
#   'Transcriptional profiles of cultured human breast and prostate cancer cell lines treated with small molecules: 6 cancer cell lines are treated with 6 small molecules, as a part of the LINCS Trans-Center Project. The expression level for 978 representative genes is measured.',
# ...
#   'Non-small cell lung cancer (NSCLC) comprises the majority (~85%) of all lung tumors, with lung adenocarcinoma (LUAD) and squamous cell carcinoma (LUSC) being the most frequently diagnosed histological subtypes. Currently, multi-modal omics profiles had been carried out in NSCLC, but no studies reported yet a systems biology approach to provide a complete picture of molecular perturbations specifically for LUAD and LUSC.\nIn this study, we integrated transcriptomics, metabolomics and adducteomics for the first time to analyze 30 paired human lung tumors and adjacent noncancerous tissues. We portrayed unique metabolite related gene signatures to distinguish LUAD from LUSC and several altered pathways aberrantly expressed at both transcriptional and metabolic levels. Additionally, the integration studies revealed a 28-metabolite gene signature in TCGA-LUAD cohort and demonstrated a significant association with survival, especially for 6 metabolite related genes as therapeutic targets. To further explore, we identified AZD-6482, a clinical trial drug from LINCS/connectivity map and found that it significantly inhibited 3 genes from the 28-gene signature. By integrating adducteomics, we found a differential expression of 307 genes correlated with 6 DNA adducts in LUSC although LUAD did not show much correlation. We found that γ-hydroxy-propanodeoxyguanosine (γ-OH-PdG) is the major DNA adduct formed in LUSC, but not in adjacent noncancerous tissue and significantly correlated with 295 modulated genes as well. We also have identified aberrant signaling pathways for each specific DNA adducts in LUSC compared to adjacent normal. Overall, we have provided a broad picture of integration of omics that can distinguish LUAD and LUSC, prediction of patient survival and identification of therapeutic targets and anticancer drugs. Ultimately, genes modulated by DNA adducts in LUSC could serve as biomarkers or therapeutic targets for cigarette smoke induced lung cancer.',
#   'Sampattavanich et al., Cell Systems (2018)\n\nThis data repository provides raw datasets for accompanying the paper, "Encoding growth factor identity in the temporal dynamics of FoxO3 under combinatorial regulation by ERK and Akt" by Sampattavanich et al., Cell Systems (2018)\n\nSynopsis:\nForkhead box O3 transcription factor (FoxO3) functions as an integrative node for diverse upstream signaling networks, and has been implicated in a number of biological processes including cycle arrest, apoptosis, oxidative stress, cell migration and cell metabolism. Regulators of FoxO3, including phosphorylation, energy stress, genotoxic stress, and cytokines, control its abundance, subcellular localization and DNA-binding capacity. In this paper we study how the identities and concentrations of growth factors are encoded in the dynamics of FoxO3 activation. Transcription factors like FoxO3 often switch between on and off states repeatedly over the course of a 12-24 hours period. Immunoblotting and similar methods can obscure this switching behavior due to asynchronicity between cells. In contrast, our use of time-lapse microscopy of fluorescent reporter proteins reveals that FoxO3 exhibits complex low wavelength and pulsatile translocation dynamics responsive to combinatorial control by ERK and Akt with the potential to encode the identities and concentrations of multiple extracellular growth factors.\n\nDataset Content:\n\nThis dataset includes raw datasets either in .MAT, or .CSV for regenerating all figures in the publication.  These folders should be placed inside the /rawdata folder in the git repository folder so that the reader can generate these figures on their own.  \n/parentalVSreporter - This dataset is used to regenerate fig.1B, S1B and S1C. \n/Workspace - This dataset is important for all fPCA and pulse score analysis in Fig.1-6\n/dualsensors - This dataset is used to regenerate Fig.6B\n/western - This dataset is used to regenerate Fig.1C and S1G\n/fixedcell - This dataset is used to regenerate Fig.7\n/Time-lapse video - This folder gives video files of the main dataset for Fig.1-2, varying different growth factors at various dosing, with different drug pre-treatment. \n\nTo learn more about this data, please also visit the accompanying HMS LINCS website shown below.',
#   '<p><strong>Improving the Usability of a MAS DSML</strong></p>\n\n<p>Tom&aacute;s Miranda, Moharram Challenger, Baris Tezel, Omer Faruk Alaca, Vasco Amaral, Miguel Goul&atilde;o, and Geylani Kardas</p>\n\n<p>Paper accepted for publication in the <a href="http://emas2018.dibris.unige.it/">6th International Workshop on Engineering Multi-Agent Systems (EMAS 2018)</a></p>\n\n<p>&nbsp;</p>\n\n<p><em><strong>Abstract&nbsp;</strong></em></p>\n\n<p><strong>&nbsp;Context:&nbsp;</strong>A significant effort has been devoted to the design and implementation of various domain-specific modeling languages (DSMLs) for the software agents domain.</p>\n\n<p><strong>Problem:&nbsp;</strong>Language usability is often tackled in an ad-hoc way, with the collection of anecdotal evidence supporting the process. However, usability plays an important role in the productivity, learnability and, ultimately, in the adoption of a MAS DSML by agent developers.</p>\n\n<p><strong>Method:&nbsp;</strong>In this paper, we apply the principles of The &ldquo;Physics&rdquo; of Notations (PoN) to improve the visual notation of a MAS DSML, called SEA_ML and evaluate the result in terms of usability.</p>\n\n<p><strong>Results:&nbsp;</strong>The evolved version of the language, SEA_ML++, was perceived as significantly improved in terms of icons comprehensibility, adequacy and usability, as a direct result of employing the principles of PoN. However, users were not significantly more efficient and effective with SEA_ML++, suggesting these two properties were not chiefly constrained by the identified shortcomings of the SEA_ML concrete syntax.</p>\n\n<p><em><strong>Study Participants</strong></em></p>\n\n<p><strong>Summary.&nbsp;</strong>This evaluation is comprised of a set of studies, each with its own subset of participants. No participants were involved in more than one study.</p>\n\n<ul>\n\t<li>Symbol selection study (25 participants)</li>\n\t<li>Concrete syntax evaluation experiment (24 + 12 participants)</li>\n</ul>\n\n<p><strong>Participants in the symbol selection study.&nbsp;</strong>The symbol selection experiment had 25 participants, 20 males, 5 females, all trained in Computer Science. Of these, 5 had completed their MSc, 16 their BSc and 4 were undergraduate Computer Science students at UNL. 11 had learned about MAS in the context of a course (although not using any of the particular languages in this experiment). The remaining 14 were not familiar with MAS. 9 participants had learned about the semantic web in the context of a course, 9 had only informal knowledge about it and the remaining 7 were not familiar with the semantic web.</p>\n\n<p>More details concerning the development of the SEA_ML++ version of SEA_ML can be found in: <a href="https://zenodo.org/api/files/b8f7c0ab-6121-479c-b356-440ff1cde8e1/SEA_MLPoN.pdf">SEA_MLPoN.pdf</a> .</p>\n\n<p><strong>Participants in the concrete syntax evaluation experiment.&nbsp;</strong>This evaluation experiment was run as a pair of replicated studies. The first replica was run in Universidade Nova de Lisboa, in Portugal. The second replica was run in the International Computer Institute, Ege University, Izmir, in Turkey.</p>\n\n<ul>\n\t<li><strong>UNL evaluation.&nbsp;</strong>At UNL we had 24 participants, including 19 males and 5 females, all trained in Computer Science. Of these, 8 have completed their MSc, 15 their BSc and 1 is an undergraduate Computer Science student. 12 of them had learned about MAS in the context of a course (although not using any of the particular languages in this experiment), and 1 had only informal knowledge about MAS. The remaining 11 were not familiar with MAS. 14 participants had learned about semantic web in the context of a course, 5 had informal knowledge about it, while 4 were not familiar with the semantic web.&nbsp;</li>\n\t<li><strong>EGE evaluation.&nbsp;</strong>At Ege University, we had 12 participants, all Computer Science graduate students who had learned about MAS  ...
#   'Experimental validation of candidate regulators of KRAS transcriptional components.',
#   '<p>Version 2.0.0 (05/29/2023)</p>\n\n<p>This is a drug repurposing dataset under MIT licence, compiled by Dr. Cl&eacute;mence R&eacute;da &lt;clemence.reda@uni-rostock.de&gt; at Universit&auml;t Rostock, comprising a drug-disease association matrix, and several drug-drug and disease-disease similarity matrices. It only uses transcriptomic data (i.e., gene activity/expression). The sparsity number is the percentage of nonzero values in the association matrix.</p>\n\n<p># drugs | # diseases | Sparsity number | # positive associations | # negative associations | # genes<br>\n------- | ---------- | --------------- | ----------------------- | ----------------------- | -------<br>\n204&nbsp;&nbsp;&nbsp;&nbsp; | 116&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; | 0.44%&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; | 401&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; | 11&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; | 12,096</p>\n\n<p>All drugs (resp., diseases) are associated with a gene expression feature vector of length 12,096 (that is, all drugs and diseases in the feature matrices appear in the association matrix, and vice versa).</p>\n\n<p>----------</p>\n\n<p>This dataset consists of three .CSV files:</p>\n\n<p>* Drug-Disease Association Matrix</p>\n\n<p>1. &quot;ratings_mat.csv&quot;</p>\n\n<p>This matrix contains values in {-1,0,1} where -1 stands for a negative association (i.e., the drug failed for some reason to treat the considered disease: e.g., lack of accrual in the associated clinical trial, or proven toxicity), 1 for a positive association (i.e., the drug was shown to treat the disease), and 0 for unknown associated status. The columns are diseases, identified by their MedGen Concept ID, whereas rows are drugs, identified by their DrugBank IDs or PubChem CIDs.</p>\n\n<p>* Drug Feature Matrix</p>\n\n<p>1. &quot;items.csv&quot;</p>\n\n<p>This matrix has drugs in its columns, identified by their DrugBank IDs or PubChem CIDs, and genes in its rows, identified by their HUGO Gene Symbol. Genewise transcriptomic variation induced by drug treatment, from the CREEDS or the LINCS L1000 databases.</p>\n\n<p>* Disease Feature Matrix</p>\n\n<p>1. &quot;users.csv&quot;</p>\n\n<p>This matrix has diseases in its columns, identified by their MedGen Concept IDs, and genes in its rows, identified by their HUGO Gene Symbol. Genewise transcriptomic variation induced by the disease, from the CREEDS database.</p>\n\n<p>----------</p>\n\n<p>Further information about the generation of those matrices is available by running the Jupyter notebook TRANSCRIPT_dataset.ipynb on the following GitHub repository: https://github.com/RECeSS-EU-Project/drug-repurposing-datasets. For any questions, please contact the author at &lt;clemence.reda@uni-rostock.de&gt; or the RECeSS project contributors at &lt;recess-project@proton.me&gt;.</p>',
#   'Generation of KRAS signatures using immortalized isogenic lung cells.',
#   'FOXM1 transcription factor is an oncogene and a crucial regulator of cancer chemoresistance. Existing pharmacological FOXM1 inhibitors attenuate resistance of cancer cells to treatment but exhibit insufficient specificity. We performed in silico screening of small molecules from NIH LINCS database to identify STL427944 compound that suppresses FOXM1 through a novel two-step mechanism. STL427944 treatment induces relocalization of nuclear FOXM1 protein to cytoplasm, where it is subsequently degraded in an autophagosome-dependent manner. Human cancer cells treated with STL427944 exhibit increased sensitivity to cytotoxic effects of conventional chemotherapeutic agents. Transcriptome-based analysis of STL427944-induced gene expression changes revealed prominent suppression of gene signatures characteristic for FOXM1 and its downstream targets but no significant changes in other important regulatory pathways, thereby suggesting high selectivity of STL427944 towards FOXM1. We expect that STL427944 or its derivatives may be used in combination with different chemotherapeutical drugs to overcome tumor chemoresistance and improve anti-cancer treatment efficacy.\nFor each experimental model and condition, two biological replicates were analyzed. Control samples were treated with vehicle alone (DMSO), with vehicle percentage not exceeding 0.3%.',
#   '<p class="western"><span><span><span>Polychlorinated biphenyls (PCBs) are ubiquitously detected in the environment and have been linked to metabolic diseases. The liver serves as a central hub for the metabolism of xenobiotics and endogenous metabolites. Gut dysbiosis is recognized as a critical regulator of disease susceptibility, however, little is known regarding how PCBs and gut microbiome interact to modulate the interface between xenobiotic and intermediary metabolism. We hypothesized that the gut microbiome regulates PCBs-mediated changes in the metabolic fingerprints and hepatic transcriptome. Ninety-day-old female conventional (CV) and germ-free (GF) C57BL/6 mice were orally exposed to the PCB Fox River Mixture (synthetic PCB mixture, 6 or 30 mg/kg) or corn oil (vehicle control, 10 ml/kg), once daily for 3 consecutive days. Organs were collected 24 hours after the final dose. RNA-Seq was conducted on liver, and endogenous aqueous metabolites (amino acids, carbohydrates, and nucleotides) were measured in liver and serum by LC-MS. The primary factor in clustering the transcriptomic and metabolomic signatures within the same exposure was by enterotype. The numbers of PCB-regulated genes were higher in CV than in GF conditions. The prototypical target genes of the major xenobiotic-sensing transcription factors AhR, PXR, and CAR were more readily up-regulated by PCBs in CV than in GF conditions, indicating the effect of PCBs on the hepatic transcriptome act partly through the gut microbiome. Xenobiotic and steroid metabolism pathways were up-regulated, whereas response to incorrect proteins pathway was down-regulated by PCBs in a gut microbiome-dependent manner. At the high PCB dose, NADP and arginine appear to interact with drug-metabolizing enzymes (Cyp1-3 family, DhcR7, and Nqo1), which are highly correlated with <i>Anaerotruncus</i> and <i>Roseburia</i> in CV mice, providing a novel explanation of gut-liver interaction in toxicant exposures. In GF exposure groups, hepatic glucose was down-regulated, whereas fructose 6-phosphate and glucose 6-phosphate were up-regulated, indicating increased glucose utilization potentiated by lack of gut microbiota. Through querying the LINCS L1000 chemical database, Enrichr predicted that therapeutic drugs targeting the anti-inflammatory and ER stress pathways are potential remedies to mitigate PCB toxicity. In conclusion, our findings demonstrate that habitation of the gut microbiota drives PCBs-mediated hepatic responses, possibly due to crosstalk between gut and liver. </span></span></span></p>'])

# %%
import pandas as pd

df = pd.DataFrame({'Name': names, 'Description': descriptions})
df
# Out:
#                                                   Name  \
# 0                                 LINCS - preprocessed
# 1             Columbia LINCS Trans-Center project data
# 2    LINCS Canvas Browser: interactive web app to q...
# 3             LINCS MCF10A GRNs calculated with ANANSE
# 4    Systematic Quality Control Analysis of LINCS D...
# ..                                                 ...
# 495                                       Homo sapiens
# 496                TRANSCRIPT drug repurposing dataset
# 497                                       Homo sapiens
# 498  STL427944 suppresses FOXM1 via nuclear export ...
# 499  Data from: Gut microbiome critically impacts P...
#
#                                            Description
# 0                  <p>LINCS - PDRGC - preprocessed</p>
# 1    The Library of Integrated Network-based Cellul...
# 2    For the Library of Integrated Network-based Ce...
# 3    <p>GRNs calculated using ANANSE presumably act...
# 4    The Library of Integrated Cellular Signatures ...
# ..                                                 ...
# 495  Experimental validation of candidate regulator...
# 496  <p>Version 2.0.0 (05/29/2023)</p>\n\n<p>This i...
# 497  Generation of KRAS signatures using immortaliz...
# 498  FOXM1 transcription factor is an oncogene and ...
# 499  <p class="western"><span><span><span>Polychlor...
#
# [500 rows x 2 columns]

# %%
from bs4 import BeautifulSoup

df['Name'] = df['Name'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
df['Description'] = df['Description'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())

df
# Out:
# /var/folders/2s/m_y5ncrj7wv6_6bqg4l26hq00000gn/T/ipykernel_40945/126205139.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   df['Name'] = df['Name'].apply(lambda x: BeautifulSoup(x, 'html.parser').get_text())
#                                                   Name  \
# 0                                 LINCS - preprocessed
# 1             Columbia LINCS Trans-Center project data
# 2    LINCS Canvas Browser: interactive web app to q...
# 3             LINCS MCF10A GRNs calculated with ANANSE
# 4    Systematic Quality Control Analysis of LINCS D...
# ..                                                 ...
# 495                                       Homo sapiens
# 496                TRANSCRIPT drug repurposing dataset
# 497                                       Homo sapiens
# 498  STL427944 suppresses FOXM1 via nuclear export ...
# 499  Data from: Gut microbiome critically impacts P...
#
#                                            Description
# 0                         LINCS - PDRGC - preprocessed
# 1    The Library of Integrated Network-based Cellul...
# 2    For the Library of Integrated Network-based Ce...
# 3    GRNs calculated using ANANSE presumably active...
# 4    The Library of Integrated Cellular Signatures ...
# ..                                                 ...
# 495  Experimental validation of candidate regulator...
# 496  Version 2.0.0 (05/29/2023)\nThis is a drug rep...
# 497  Generation of KRAS signatures using immortaliz...
# 498  FOXM1 transcription factor is an oncogene and ...
# 499  Polychlorinated biphenyls (PCBs) are ubiquitou...
#
# [500 rows x 2 columns]

# %%
df.to_csv('../datasets/LINCS.csv', index=False, lineterminator="\n")

# %%
pd.read_csv('../datasets/LINCS.csv', lineterminator="\n")
# Out:
#                                                   Name  \
# 0                                 LINCS - preprocessed
# 1             Columbia LINCS Trans-Center project data
# 2    LINCS Canvas Browser: interactive web app to q...
# 3             LINCS MCF10A GRNs calculated with ANANSE
# 4    Systematic Quality Control Analysis of LINCS D...
# ..                                                 ...
# 495                                       Homo sapiens
# 496                TRANSCRIPT drug repurposing dataset
# 497                                       Homo sapiens
# 498  STL427944 suppresses FOXM1 via nuclear export ...
# 499  Data from: Gut microbiome critically impacts P...
#
#                                            Description
# 0                         LINCS - PDRGC - preprocessed
# 1    The Library of Integrated Network-based Cellul...
# 2    For the Library of Integrated Network-based Ce...
# 3    GRNs calculated using ANANSE presumably active...
# 4    The Library of Integrated Cellular Signatures ...
# ..                                                 ...
# 495  Experimental validation of candidate regulator...
# 496  Version 2.0.0 (05/29/2023)\nThis is a drug rep...
# 497  Generation of KRAS signatures using immortaliz...
# 498  FOXM1 transcription factor is an oncogene and ...
# 499  Polychlorinated biphenyls (PCBs) are ubiquitou...
#
# [500 rows x 2 columns]

# %%
outputs = pd.read_csv('../outputs/9sroovd8.csv')

# %%
outputs['Predictions']
# Out:
# 0      Data integration and warehousing, Computationa...
# 1                 Cell biology, Genetics, Bioinformatics
# 2      Bioinformatics, Systems biology, Computational...
# 3        Bioinformatics, Computational biology, Genomics
# 4      Bioinformatics, Computational biology, Transcr...
#                              ...
# 495    Genetics, Gene expression, Transcription facto...
# 496      Bioinformatics, Drug discovery, Transcriptomics
# 497            Cell biology, Genetics, Molecular biology
# 498                 Biochemistry, Pharmacology, Oncology
# 499               Animal study, Microbiology, Toxicology
# Name: Predictions, Length: 500, dtype: object

# %%
with open('../EDAM/edam_topics.txt', 'r') as f:
    lines = f.readlines()

# Filter the lines to only include those with quotes
quoted_lines = [line.strip().replace('"', '') for line in lines if '"' in line]
# quoted_subsets = []
out = []
for line in outputs['Predictions']:
    ln = line
    for topic in quoted_lines:
        if topic in line:
            ln = ln.replace(topic, f'"{topic}"')
    out.append(ln)

out
# Out:
# ['Data integration and warehousing, Computational biology, "Data submission, annotation, and curation"',
#  'Cell biology, Genetics, Bioinformatics',
#  'Bioinformatics, Systems biology, Computational biology',
#  'Bioinformatics, Computational biology, Genomics',
#  'Bioinformatics, Computational biology, Transcriptomics',
#  'Bioinformatics, Drug discovery, Oncology',
#  'Cell biology, Drug discovery, Gene expression',
#  'Transcriptomics, Small molecules, Cancer',
#  'Transcriptomics, Small molecules, Cancer',
#  'Transcriptomics, Drug development, Bioinformatics',
#  'Bioinformatics, Drug discovery, Machine learning',
#  'Cell biology, Bioinformatics, Data management',
#  'Bioinformatics, Genomics, Transcriptomics',
#  'Gene expression, Computational biology, Bioinformatics',
#  'Bioinformatics, Computational biology, Genetics',
#  'Bioinformatics, Genomics, Drug discovery',
#  'Bioinformatics, Computational biology, Gene expression',
#  'Bioinformatics, Proteomics, Transcriptomics',
#  'Bioinformatics, Drug discovery, Immunology',
#  'Bioinformatics, Computational biology, Genetics',
#  'Computational biology, Biophysics, Membrane and lipoproteins',
#  'Bioinformatics, Computational biology, Biophysics',
#  'Biomolecular simulation, Biophysics, Computational biology',
#  'Cell biology, Bioinformatics, Ontology and terminology',
#  'Bioinformatics, Computational biology, Transcriptomics',
#  'Bioinformatics, Transcriptomics, Pharmacology',
#  'Transcriptomics, Bioinformatics, Biomedical science',
#  'Bioinformatics, Transcriptomics, Biomedical science',
#  'Transcriptomics, Data integration and warehousing, Drug discovery',
#  'Transcriptomics, Bioinformatics, Biomedical science',
#  'Bioinformatics, Transcriptomics, Genetics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, Data integration and warehousing',
#  'Cell biology, Drug discovery, Molecular biology',
#  'Pharmacology, Oncology, Cell biology',
#  'Cell biology, Drug development, Biotechnology',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, Pharmacology',
#  'Cell biology, Drug discovery, Biomedical science',
#  'Cell biology, Drug discovery, Biomedical science',
#  'Cell biology, Drug discovery, Pharmacology',
#  'Cell biology, Drug discovery, Computational biology',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, Cancerology',
#  'Cell biology, Drug discovery, Computational biology',
#  'Cell biology, Drug discovery, Biotechnology',
#  'Cell biology, Drug discovery, Molecular biology',
#  'Cell biology, Drug discovery, Genetics',
#  'Cell biology, Drug discovery, Genetics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, Reproductive health',
#  'Cell biology, Drug discovery, Computational biology',
#  'Cell biology, Drug discovery, Data integration and warehousing',
#  'Cell biology, Drug discovery, Computational biology',
#  'Cell biology, Drug discovery, Computational biology',
#  'Cell biology, Drug discovery, Computational biology',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Drug discovery, High-throughput screening',
#  'Cell biology, Drug discovery, Genetics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Proteomics, Drug development',
#  'Cell biology, Proteomics, Small molecules',
#  'Cell biology, Bioinformatics, Proteomics',
#  'Cell biology, Drug discovery, Oncology',
#  'Cell biology, Drug discovery, Biotechnology',
#  'Bioinformatics, Cell biology, Proteomics',
#  'Cell biology, Protein expression, Proteomics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioinformatics, Drug discovery, Proteins',
#  'Chemical biology, Drug discovery, Computational chemistry',
#  'Biochemistry, Biotechnology, Drug discovery',
#  'Cell biology, Molecular biology, Genetics',
#  'Cell biology, Genetics, Immunology',
#  'Bioinformatics, Drug discovery, Pharmacology',
#  'Computer science, Software engineering, Data mining',
#  'Cell biology, Drug discovery, Genetics',
#  'Cell biology, Proteomics, Neuroscience',
#  'Bioinformatics, Biotechnology, Pharmacology',
#  'Biochemistry, Biology, Genetics',
#  'RNA, Gene expression, Treatment effects',
#  'Bioinformatics, Biotechnology, Proteomics',
#  'Bioinformatics, Biotechnology, Drug discovery',
#  '"Chemical biology","Drug discovery","Biochemistry"',
#  'Biochemistry, Drug development, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteins',
#  'Cell biology, Biochemistry, Molecular biology',
#  'Cell biology, Proteomics, Neuroscience',
#  'Cell biology, Biotechnology, Microfluidics',
#  'Cell biology, Bioengineering, Microfluidics',
#  'Cell biology, Microfluidics, Biochemistry',
#  'Cell biology, Drug discovery, Proteomics',
#  'Cell biology, Genetics, Molecular biology',
#  'Metabolomics, Cell biology, Drug discovery',
#  'Cell biology, Drug discovery, Genetics',
#  'Cell biology, Molecular biology, Drug discovery',
#  'Proteomics, Cell biology, Drug discovery',
#  'Bioinformatics, Biology, Biotechnology',
#  'Bioinformatics, Biology, Biomarkers',
#  'Bioinformatics, Computational biology, Molecular biology',
#  'Bioinformatics, Biomarkers, Molecular interactions, pathways, and networks',
#  'Bioinformatics, Molecular biology, Computational biology',
#  'Bioinformatics, Computational biology, Functional genomics',
#  'Bioinformatics, Computational biology, Systems biology',
#  'Cell biology, Immunology, Rheumatology',
#  'Cell biology, Drug discovery, Cancer oncology',
#  'Cell biology, Biomedical science, Immunology',
#  'Bioinformatics, Cell biology, Biomarkers',
#  'Bioinformatics, Biology, Computational biology',
#  'Bioinformatics, Biotechnology, Computational biology',
#  'Biochemistry, Biology, Genetics',
#  'Biochemistry, Biology, Biotechnology',
#  'Bioinformatics, Computational biology, Systems biology',
#  'Biochemistry, Biology, Biotechnology',
#  'Bioinformatics, Biology, Biotechnology',
#  'Genomics, Drug development, Oncology',
#  'Cell biology, Drug discovery, Cancer',
#  'Cell biology, Biology, Bioinformatics',
#  'Cell biology, Bioinformatics, Drug discovery',
#  'Gene expression, Oncology, Cell biology',
#  'Cell biology, Drug development, Oncology',
#  'Cell biology, Bioinformatics, Computational biology',
#  'Bioinformatics, Molecular biology, Oncology',
#  'Drug discovery, Cancer research, Computational biology',
#  'Cell biology, Drug discovery, Pharmacology',
#  'Proteomics, Breast cancer, Cell biology',
#  'Cell biology, Drug discovery, Molecular biology',
#  'Biochemistry, Cell biology, Biotechnology',
#  'Cell biology, Biochemistry, Computational biology',
#  'Cell biology, Biochemistry, Molecular biology',
#  'Cell biology, Biochemistry, Drug discovery',
#  'Proteomics, Biochemistry, Genetics',
#  'Cell biology, Biomedical science, Drug discovery',
#  'Cell biology, Drug discovery, Pharmacology',
#  'Cell biology, Molecular biology, Nuclear acid sites, features and motifs',
#  'Drug discovery, Pharmacology, Biotechnology',
#  'Cell biology, Immunology, Biomedical science',
#  'Cell biology, Biomarkers, Single-cell analysis.',
#  'Cell biology, Bioinformatics, Computational biology',
#  'Cell biology, Molecular biology, Bioinformatics',
#  'Cell biology, Bioinformatics, Drug discovery',
#  'Cell biology, Drug discovery, Proteomics',
#  'Cell biology, Drug development, Molecular biology',
#  'Cell biology, Genetics, Molecular biology',
#  'Cell biology, Bioinformatics, Genetics',
#  'Bioinformatics, Computational biology, Genetics',
#  'Microbiology, Biotechnology, Molecular biology',
#  'Proteomics, Cancer, Cell biology',
#  'Biochemistry, Epigenetics, Genetics',
#  'Cell biology, Drug discovery, Proteomics',
#  'Cell biology, Drug development, Drug discovery',
#  'Cell biology, Drug discovery, Oncology',
#  'Epigenetics, Neurobiology, Drug discovery',
#  'Bioinformatics, Genomics, Data integration and warehousing',
#  'Computational biology, Pharmacogenomics, Drug discovery',
#  'Cell biology, Drug discovery, Biochemistry.',
#  'Cell biology, Neuroscience, Psychiatry',
#  'Bioinformatics, Biology, Biotechnology',
#  'Bioinformatics, Computational biology, Genetics',
#  'Bioinformatics, Molecular biology, Biotechnology',
#  'Epigenetics, Biology, Biotechnology',
#  'Biology, Biotechnology, Bioengineering',
#  'Biology, Bioinformatics, Biomarkers',
#  'Biology, Biotechnology, Bioinformatics',
#  'Bioinformatics, Biotechnology, Biology',
#  'Cell culture collection, Drug discovery, Drug development',
#  'Drug discovery, Oncology, Cell biology',
#  'Cell biology, Drug development, Oncology',
#  'Proteomics, Oncology, Cell biology',
#  'Cell biology, Proteomics, Biochemistry',
#  'Bioinformatics,Biology,Drug discovery',
#  'Drug discovery, Oncology, Cell biology',
#  'Cell biology, Metabolomics, Small molecules',
#  'Cell biology, Pharmacology, Transcriptomics',
#  'Cell biology, Pharmacology, Transcriptomics',
#  'Cell biology, Drug discovery, High throughput microscopy',
#  'Proteomics, Drug development, Cancer',
#  'Transcriptomics, Biomarkers, Biotechnology',
#  'Bioinformatics, Drug discovery, Gene expression',
#  'Protein expression, Epigenetics, Cell biology',
#  'Bioinformatics, Biotechnology, Molecular biology',
#  'Bioinformatics, Genetics, Epigenomics',
#  'Cell biology, Drug discovery, Toxicology',
#  'Cell biology, Bioinformatics, High-throughput technologies',
#  'Proteomics, Breast Cancer, Cell biology',
#  'Bioinformatics, Proteomics, Data integration and warehousing',
#  'Cell biology, Genetics, Molecular biology',
#  'Cell biology, Molecular biology, Data integration and warehousing',
#  'Cell biology, Molecular biology, Bioengineering',
#  'Pharmacology, Cancer, Drug development',
#  'Cell biology, Immunology, High throughput microscopy',
#  'Biochemistry, Biology, Proteomics',
#  'Cell biology, Drug discovery, Bioinformatics',
#  'Cell biology, Oncology, Biotechnology',
#  'Software engineering, Computational biology, Data mining',
#  'Genomics, Transcriptomics, Neurology',
#  'Bioinformatics, Drug discovery, Pharmacology',
#  'Cell biology, Biochemistry, Biotechnology',
#  'Transcriptomics, Genetics, Neurology',
#  'Cell biology, Proteomics, Drug discovery',
#  'Cell biology, Oncology, Drug discovery',
#  'Cell biology, Molecular biology, Drug discovery',
#  'Cell biology, Biochemistry, Biomarkers',
#  'Bioinformatics, Computational biology, Genetics',
#  'Biochemistry, Proteomics, Mass Spectrometry',
#  'Epigenetics, Genetics, Bioinformatics',
#  'Epigenetics, Functional genomics, Computational biology',
#  'Cell biology, Computational biology, Systems biology',
#  'Data management, Data integration and warehousing, Computational biology',
#  'Cell biology, Protein expression, Proteomics',
#  'Biochemistry, Proteomics, Drug discovery',
#  'Biochemistry, Proteomics, Pharmacology',
#  'Computer science, Gender medicine, "Data architecture, analysis and design"',
#  'Bioinformatics, Computational biology, Machine learning',
#  'Cell biology, Oncology, Drug discovery',
#  'Biophysics, Computational biology, Lipids',
#  'Biomolecular simulation, Lipids, Computational biology',
#  'Cell biology, Drug discovery, Biochemistry',
#  'Chemical biology, Cheminformatics, Data integration and warehousing',
#  'Cell biology, Biochemistry, Proteomics',
#  'Biochemistry, Drug discovery, Molecular biology',
#  'Biochemistry, Proteomics, Mass spectrometry',
#  'Biochemistry, Proteomics, Drug discovery',
#  'Biochemistry, Analytical chemistry, Proteomics',
#  'Analytical chemistry, Biochemistry, Proteomics',
#  'Biochemistry, Molecular biology, Proteomics',
#  'Biochemistry, Proteomics, Analytical chemistry',
#  'Biochemistry, Analytical chemistry, Cell biology',
#  'Biochemistry, Biology, Proteomics',
#  'Bioinformatics, Computational biology, Proteomics',
#  'Analytical chemistry, Biochemistry, Proteomics',
#  'Biochemistry, Biotechnology, Proteomics',
#  'Biochemistry, Computational biology, Proteomics',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Cell biology, Drug discovery, Small molecules',
#  'Cell biology, Genetics, Molecular biology',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Biochemistry, Drug discovery, Data integration and warehousing',
#  'Bioinformatics, Chemical biology, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Computational biology, Proteomics',
#  'Biochemistry, Proteomics, Drug development',
#  'Biochemistry, Biomarkers, Proteomics',
#  'Analytical chemistry, Biochemistry, Proteomics',
#  'Biochemistry, Biology, Proteomics',
#  'Biochemistry, Biotechnology, Proteomics',
#  'Biochemistry, Biotechnology, Proteomics',
#  'Biochemistry, Biotechnology, Proteomics',
#  'Bioinformatics, Genomics, Drug discovery.',
#  'Biochemistry, Drug discovery, Structural biology',
#  'Biochemistry, Drug discovery, Chemistry',
#  'Biochemistry, Proteomics, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioinformatics, Drug discovery, Molecular biology',
#  'Analytical chemistry, Bioinformatics, Drug discovery',
#  'Biochemistry, Drug discovery, Protein interactions',
#  'Bioinformatics, Computational biology, Drug discovery',
#  'Biochemistry, Proteomics, Data integration and warehousing',
#  'Transcriptomics, Cell biology, Cardiology',
#  'Transcriptomics, Cell biology, Cardiology',
#  'Cell biology, Imaging, Bioinformatics',
#  'Dermatology,Drug discovery,Translational medicine',
#  'Bioinformatics, Genetics, Oncology',
#  'Biochemistry, Drug discovery, Pharmacology.',
#  'Bioinformatics, Chemical biology, Drug discovery',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Drug discovery, Bioinformatics, Chemical biology',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Genetics',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Bioinformatics, Compound libraries and screening, Genetics',
#  'Pharmacology, Drug discovery, Bioinformatics',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Cell biology, Molecular biology, Oncology',
#  'Biochemistry, Proteomics, Biotechnology',
#  'Bioinformatics, Drug discovery, Genetics',
#  'Biochemistry, Drug discovery, Proteins',
#  'Bioinformatics, Chemical biology, Data visualisation',
#  'Bioinformatics, Chemistry, Pharmacology',
#  'Biochemistry, Drug discovery, Biotechnology',
#  'Analytical chemistry, Pharmacology, Proteomics',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Pharmacology, Drug discovery',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Analytical chemistry, Bioinformatics, Drug discovery',
#  'Bioinformatics, Drug discovery, Chemistry',
#  'Bioinformatics, Genetics, Transcriptomics',
#  'Bioengineering, Computational biology, Drug discovery',
#  'Biochemistry, Pharmacology, Computational biology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Bioinformatics, Drug discovery, Chemistry',
#  'Biochemistry, Drug discovery, Data mining',
#  'Biochemistry, Drug discovery, Data integration and warehousing',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Computational biology, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioinformatics, Chemical biology, Drug development',
#  'Biochemistry, Drug discovery, Data visualisation',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteins',
#  'Cell biology, Proteomics, Biotechnology',
#  'Cell biology, Molecular biology, Proteomics',
#  'Bioinformatics, Cell biology, Genomics',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Enzymes',
#  'Biochemistry, Drug discovery, Genetics',
#  'Bioinformatics, Toxicology, "Data submission, annotation, and curation"',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Proteomics, Drug development, Cardiology',
#  'Cell biology, Biochemistry, Molecular biology',
#  'Drug discovery, Pharmacology, Oncology',
#  'Transcriptomics, Genetics, Neurology',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Bioinformatics, Genomics, Drug discovery',
#  'Cell biology, Pharmacology, Drug discovery',
#  'Bioinformatics, Genetics, Computational biology',
#  'Epigenetics, Transcriptomics, Neurology',
#  'Neurobiology, Proteomics, Cell biology',
#  'Proteomics, Bioinformatics, Cell biology',
#  'Biochemistry, Molecular biology, Proteomics',
#  'Biochemistry, Chemistry, Proteomics',
#  'Biochemistry, Proteomics, Mass spectrometry',
#  'Bioinformatics, Cell biology, Proteomics',
#  'Biochemistry,Biology,Proteomics',
#  'Biochemistry, Biotechnology, Drug discovery',
#  'Bioinformatics, Transcriptomics, Genomics',
#  'Biochemistry, Pharmacology, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Biotechnology, Drug discovery',
#  'Bioinformatics, Data mining, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Enzymes',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Compound libraries and screening, Bioengineering, Drug discovery',
#  'Software engineering, Data integration and warehousing, Data management',
#  'Biochemistry, Cell biology, Proteomics',
#  'Epigenetics, Cell biology, Transcriptomics',
#  'Epigenomics, Neurology, Biomarkers',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Chemistry',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Computational biology, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteins',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Molecular biology, Drug discovery',
#  'Bioinformatics, Biomolecular simulation, Computational biology',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Molecular biology',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Bioinformatics, Computational biology, Structural biology',
#  'Biochemistry, Proteomics, Data integration and warehousing',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Compound libraries and screening, Biochemistry, Computational biology',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Proteins',
#  'Biochemistry, Drug discovery, Proteins',
#  'Chemical biology, Drug discovery, Pharmacology',
#  'Biochemistry, Drug development, Compound libraries and screening',
#  'Biochemistry, Drug discovery, Protein interactions',
#  'Analytical chemistry, Biochemistry, Drug discovery',
#  'Biochemistry, Drug development, Pharmacology',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Analytical chemistry, Drug discovery, Pharmacology',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Bioinformatics, Cell biology, Drug discovery',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Bioinformatics, Biotechnology, Drug discovery',
#  'Bioinformatics, Computational biology, Drug discovery',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteins',
#  'Biochemistry, Drug discovery, Biotechnology',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Bioengineering, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Proteins',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Biotechnology, Pharmacology',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Chemical biology, Drug discovery, Computational biology',
#  'Compound libraries and screening, Biochemistry, Biotechnology',
#  'Biochemistry, Drug discovery, Proteins',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Analytical chemistry, Bioinformatics, Drug discovery',
#  'Biochemistry, Pharmacology, Data integration and warehousing',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Compound libraries and screening, Bioinformatics, Proteomics',
#  'Bioinformatics, Biotechnology, Drug discovery',
#  'Biochemistry, Drug discovery, Proteins',
#  'Compound libraries and screening, Drug discovery, Biochemistry',
#  'Bioinformatics, Computational biology, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Bioinformatics, Drug development, Computational biology',
#  'Bioinformatics, Computational biology, Genetics',
#  'Bioinformatics, Biology, Psychiatry',
#  'Transcriptomics, Drug discovery, Psychiatry',
#  'Bioinformatics, Computational biology, Drug discovery',
#  'Biology, Biomedical science, Genetics',
#  'Neurobiology, Systems biology, Trauma medicine',
#  'Bioinformatics, Drug development, Transcriptomics',
#  'Cell biology, Drug discovery, Oncology',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Biomolecular simulation, Bioinformatics, Biophysics',
#  'Animal study, Genetics, Transcriptomics',
#  'Genetic variation, Transcriptomics, Drug response',
#  'Genetic variation, Transcription factors and regulatory sites, Oncology',
#  'Bioinformatics, Chemistry, Genetics',
#  'Animal study, Functional genomics, Drug discovery',
#  'Bioinformatics, Drug discovery, Systems biology',
#  'Bioinformatics, Chemistry, Drug discovery',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Chemical biology, Bioinformatics, Drug discovery',
#  'Analytical chemistry, Biochemistry, Drug discovery',
#  'Transcriptomics, Drug discovery, Oncology',
#  'Biomolecular simulation, Biophysics, Computational chemistry',
#  'Biomolecular simulation, Lipids, Biophysics',
#  'Transcriptomics, Drug discovery, Hepatic and biliary medicine',
#  'Biophysics, Computational biology, Molecular dynamics',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Biotechnology, Drug development',
#  'Chemical biology, Pharmacology, Drug discovery',
#  'Biochemistry, Pharmacology, Drug discovery',
#  'Biochemistry, Biotechnology, Drug discovery',
#  'Bioinformatics, Drug discovery, Chemistry',
#  'Biochemistry, Drug discovery, Pharmacology',
#  'Bioinformatics, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Computational biology',
#  'Bioinformatics, Drug discovery, Oncology',
#  'Compound libraries and screening, Cheminformatics, Drug discovery',
#  'Biochemistry, Drug discovery, Chemistry',
#  'Biophysics, Computational biology, Structural biology',
#  'Biomolecular simulation, Biophysics, Computational biology',
#  'Biophysics, Computational chemistry, Lipids',
#  'Gene expression, Drug discovery, Cancer',
#  'Biochemistry, Oncology, Drug discovery',
#  'Gene expression, Trauma medicine, Animal study',
#  'Cell biology, Drug development, Genetics',
#  'Biophysics, Computational biology, Membrane and lipoproteins',
#  'Biophysics, Computational biology, Bioinformatics',
#  'Biophysics, Computational biology, Structural biology',
#  'Biomolecular simulation, Biophysics, Molecular dynamics',
#  'Bioinformatics, Biology, Computational biology',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Biochemistry, Drug discovery, Proteomics',
#  'Immunology, Gene expression, Transcriptomics',
#  'Bioinformatics, Pharmacology, Drug development',
#  'Bioinformatics, Drug development, Oncology',
#  'Bioinformatics, Computational biology, Drug discovery',
#  'Transcriptomics, Genomics, Oncology',
#  'Cell biology, Genomics, Omics',
#  'Genetics, Transcriptomics, Drug development',
#  'Bioinformatics, Drug discovery, Transcriptomics',
#  'Gene expression, Oncology, Comparative genomics',
#  'Cancer, Omics, Therapeutics',
#  'Cell biology, Bioinformatics, Genetics',
#  'Computer science, Bioinformatics, Data integration and warehousing',
#  'Genetics, Gene expression, Transcription factors and regulatory sites',
#  'Bioinformatics, Drug discovery, Transcriptomics',
#  'Cell biology, Genetics, Molecular biology',
#  'Biochemistry, Pharmacology, Oncology',
#  'Animal study, Microbiology, Toxicology']

# %%
outputs['Predictions'] = out

# %%
outputs['Ground Truth'] = ['\"Molecular interactions, pathways and networks\", Metabolomics, Protein binding sites'] * len(outputs)

# %%
outputs.to_csv('../outputs/9sroovd8.csv', index=False, lineterminator='\n')
