# %%
import pandas as pd
import numpy as np
import os

import torch
from torch.utils.data import TensorDataset, Dataset

from transformers import BertForSequenceClassification, BertConfig, BertTokenizer
from transformers import Trainer, TrainingArguments

os.environ["WANDB_PROJECT"] = "NDE GPT"
os.environ["WANDB_LOG_MODEL"] = "checkpoint"

# %%
mendeley = pd.read_csv('../datasets/nde_prod/Mendeley.csv', lineterminator='\n')

# %%
mendeley.columns
# Out:
# Index(['_id', 'Date', 'Description', 'includedInDataCatalog', 'Name', 'URL',
#        'Abstract'],
#       dtype='object')

# %%
ids = ['Mendeley_h6trntnthr', 'Mendeley_db2zgbxwmj', 'Mendeley_bx3c6yvrjs', 'Mendeley_n3y4czk55y']

# %%
mendeley_ads = mendeley[mendeley['_id'].isin(ids)]
mendeley_ads
# Out:
#                        _id        Date  \
# 17807  Mendeley_bx3c6yvrjs  2020-11-20
# 20507  Mendeley_db2zgbxwmj  2023-06-27
# 26250  Mendeley_h6trntnthr  2023-04-05
# 33970  Mendeley_n3y4czk55y  2023-05-08
#
#                                              Description  \
# 17807  Wethrift helps shoppers save millions of dolla...
# 20507  Cara Hack IG,  Hack Instagram Twitter Tiktok O...
# 26250  Cara Hack FB - Android iPhone 2023. Yaitu meng...
# 33970  1. UiPath\nPATH\n\nUiPath is a global software...
#
#       includedInDataCatalog                                Name  \
# 17807              Mendeley                   macys coupon code
# 20507              Mendeley         Cara Hack IG Mudah Lewat HP
# 26250              Mendeley  Cara Hack FB - Android iPhone 2023
# 33970              Mendeley                      RPA stock data
#
#                                                  URL  Abstract
# 17807  https://data.mendeley.com/datasets/bx3c6yvrjs       NaN
# 20507  https://data.mendeley.com/datasets/db2zgbxwmj       NaN
# 26250  https://data.mendeley.com/datasets/h6trntnthr       NaN
# 33970  https://data.mendeley.com/datasets/n3y4czk55y       NaN

# %%
dataverse = pd.read_csv('../datasets/nde_prod/Harvard Dataverse.csv', lineterminator='\n')

ids = ['Dataverse_10.7910_DVN_LFZEVI', 'Dataverse_10.7910_DVN_2TAGUY']

dataverse_ads = dataverse[dataverse['_id'].isin(ids)]
dataverse_ads
# Out:
#                                 _id        Date  \
# 15501  Dataverse_10.7910_DVN_2TAGUY  2021-04-01
# 48699  Dataverse_10.7910_DVN_LFZEVI  2020-03-17
#
#                                              Description  \
# 15501  Do you want to buy Julva cream at discount pri...
# 48699  Here is the latest discount code for Power Sug...
#
#       includedInDataCatalog  \
# 15501     Harvard Dataverse
# 48699     Harvard Dataverse
#
#                                                     Name  \
# 15501  Data of Julva Discount Coupon for Dr Anna cabe...
# 48699  Replication Data for: Power Suggest Pro Coupon...
#
#                                       URL  Abstract
# 15501  https://doi.org/10.7910/DVN/2TAGUY       NaN
# 48699  https://doi.org/10.7910/DVN/LFZEVI       NaN

# %%
ads = pd.concat([mendeley_ads, dataverse_ads])
ads = ads.assign(Label=1)
ads
# Out:
#                                 _id        Date  \
# 17807           Mendeley_bx3c6yvrjs  2020-11-20
# 20507           Mendeley_db2zgbxwmj  2023-06-27
# 26250           Mendeley_h6trntnthr  2023-04-05
# 33970           Mendeley_n3y4czk55y  2023-05-08
# 15501  Dataverse_10.7910_DVN_2TAGUY  2021-04-01
# 48699  Dataverse_10.7910_DVN_LFZEVI  2020-03-17
#
#                                              Description  \
# 17807  Wethrift helps shoppers save millions of dolla...
# 20507  Cara Hack IG,  Hack Instagram Twitter Tiktok O...
# 26250  Cara Hack FB - Android iPhone 2023. Yaitu meng...
# 33970  1. UiPath\nPATH\n\nUiPath is a global software...
# 15501  Do you want to buy Julva cream at discount pri...
# 48699  Here is the latest discount code for Power Sug...
#
#       includedInDataCatalog  \
# 17807              Mendeley
# 20507              Mendeley
# 26250              Mendeley
# 33970              Mendeley
# 15501     Harvard Dataverse
# 48699     Harvard Dataverse
#
#                                                     Name  \
# 17807                                  macys coupon code
# 20507                        Cara Hack IG Mudah Lewat HP
# 26250                 Cara Hack FB - Android iPhone 2023
# 33970                                     RPA stock data
# 15501  Data of Julva Discount Coupon for Dr Anna cabe...
# 48699  Replication Data for: Power Suggest Pro Coupon...
#
#                                                  URL  Abstract  Label
# 17807  https://data.mendeley.com/datasets/bx3c6yvrjs       NaN      1
# 20507  https://data.mendeley.com/datasets/db2zgbxwmj       NaN      1
# 26250  https://data.mendeley.com/datasets/h6trntnthr       NaN      1
# 33970  https://data.mendeley.com/datasets/n3y4czk55y       NaN      1
# 15501             https://doi.org/10.7910/DVN/2TAGUY       NaN      1
# 48699             https://doi.org/10.7910/DVN/LFZEVI       NaN      1

# %%
# Load the pre-trained BERT model for sequence classification
model = BertForSequenceClassification.from_pretrained('bert-base-cased', torch_dtype=torch.float16)

# Modify the last layer for binary classification
num_labels = 2  # Number of classes for binary classification
model.config.num_labels = num_labels
model.classifier = torch.nn.Linear(model.config.hidden_size, num_labels)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
random_mendeley_sample = mendeley.sample(n=3)
random_dataverse_sample = dataverse.sample(n=3)

data = pd.concat([random_mendeley_sample, random_dataverse_sample]).assign(Label=1)
data
# Out:
#                                 _id        Date  \
# 3147            Mendeley_3k6zwrktsd  2020-03-09
# 44407           Mendeley_v852rn2mv6  2022-01-05
# 20511           Mendeley_db52syhgr8  2019-09-22
# 32425  Dataverse_10.7910_DVN_E2XIRQ  2020-12-05
# 33454  Dataverse_10.7910_DVN_EKHTI6  2021-10-25
# 32174  Dataverse_10.7910_DVN_DXXA2N  2020-02-06
#
#                                              Description  \
# 3147   Xiong, Q. L., Luo, X.J., Xiao, Y., Liang, P.H....
# 44407  The dataset contains perceptions of Vietnamese...
# 20511  African map showing the investigated countries...
# 32425  TIAS 11-909 First signed 09/09/2011 Last signe...
# 33454  “Review of Economics and Statistics: Forthcomi...
# 32174  Data and codebooks from the project ""Rural In...
#
#       includedInDataCatalog  \
# 3147               Mendeley
# 44407              Mendeley
# 20511              Mendeley
# 32425     Harvard Dataverse
# 33454     Harvard Dataverse
# 32174     Harvard Dataverse
#
#                                                     Name  \
# 3147   Data from: Fire from policy, human interventio...
# 44407  Vietnamese teachers' perceptions of the implem...
# 20511  Figure 1. African map showing the investigated...
# 32425  Executive Agreements Database, Statement Conce...
# 33454  Replication Data for: Spending Response to a P...
# 32174  Rural Institutional Innovation: Can Village Co...
#
#                                                  URL  Abstract  Label
# 3147   https://data.mendeley.com/datasets/3k6zwrktsd       NaN      1
# 44407  https://data.mendeley.com/datasets/v852rn2mv6       NaN      1
# 20511  https://data.mendeley.com/datasets/db52syhgr8       NaN      1
# 32425             https://doi.org/10.7910/DVN/E2XIRQ       NaN      1
# 33454             https://doi.org/10.7910/DVN/EKHTI6       NaN      1
# 32174             https://doi.org/10.7910/DVN/DXXA2N       NaN      1

# %%
training_data = pd.concat([data, ads])
training_data
# Out:
#                                 _id        Date  \
# 3147            Mendeley_3k6zwrktsd  2020-03-09
# 44407           Mendeley_v852rn2mv6  2022-01-05
# 20511           Mendeley_db52syhgr8  2019-09-22
# 32425  Dataverse_10.7910_DVN_E2XIRQ  2020-12-05
# 33454  Dataverse_10.7910_DVN_EKHTI6  2021-10-25
# 32174  Dataverse_10.7910_DVN_DXXA2N  2020-02-06
# 17807           Mendeley_bx3c6yvrjs  2020-11-20
# 20507           Mendeley_db2zgbxwmj  2023-06-27
# 26250           Mendeley_h6trntnthr  2023-04-05
# 33970           Mendeley_n3y4czk55y  2023-05-08
# 15501  Dataverse_10.7910_DVN_2TAGUY  2021-04-01
# 48699  Dataverse_10.7910_DVN_LFZEVI  2020-03-17
#
#                                              Description  \
# 3147   Xiong, Q. L., Luo, X.J., Xiao, Y., Liang, P.H....
# 44407  The dataset contains perceptions of Vietnamese...
# 20511  African map showing the investigated countries...
# 32425  TIAS 11-909 First signed 09/09/2011 Last signe...
# 33454  “Review of Economics and Statistics: Forthcomi...
# 32174  Data and codebooks from the project ""Rural In...
# 17807  Wethrift helps shoppers save millions of dolla...
# 20507  Cara Hack IG,  Hack Instagram Twitter Tiktok O...
# 26250  Cara Hack FB - Android iPhone 2023. Yaitu meng...
# 33970  1. UiPath\nPATH\n\nUiPath is a global software...
# 15501  Do you want to buy Julva cream at discount pri...
# 48699  Here is the latest discount code for Power Sug...
#
#       includedInDataCatalog  \
# 3147               Mendeley
# 44407              Mendeley
# 20511              Mendeley
# 32425     Harvard Dataverse
# 33454     Harvard Dataverse
# 32174     Harvard Dataverse
# 17807              Mendeley
# 20507              Mendeley
# 26250              Mendeley
# 33970              Mendeley
# 15501     Harvard Dataverse
# 48699     Harvard Dataverse
#
#                                                     Name  \
# 3147   Data from: Fire from policy, human interventio...
# 44407  Vietnamese teachers' perceptions of the implem...
# 20511  Figure 1. African map showing the investigated...
# 32425  Executive Agreements Database, Statement Conce...
# 33454  Replication Data for: Spending Response to a P...
# 32174  Rural Institutional Innovation: Can Village Co...
# 17807                                  macys coupon code
# 20507                        Cara Hack IG Mudah Lewat HP
# 26250                 Cara Hack FB - Android iPhone 2023
# 33970                                     RPA stock data
# 15501  Data of Julva Discount Coupon for Dr Anna cabe...
# 48699  Replication Data for: Power Suggest Pro Coupon...
#
#                                                  URL  Abstract  Label
# 3147   https://data.mendeley.com/datasets/3k6zwrktsd       NaN      1
# 44407  https://data.mendeley.com/datasets/v852rn2mv6       NaN      1
# 20511  https://data.mendeley.com/datasets/db52syhgr8       NaN      1
# 32425             https://doi.org/10.7910/DVN/E2XIRQ       NaN      1
# 33454             https://doi.org/10.7910/DVN/EKHTI6       NaN      1
# 32174             https://doi.org/10.7910/DVN/DXXA2N       NaN      1
# 17807  https://data.mendeley.com/datasets/bx3c6yvrjs       NaN      1
# 20507  https://data.mendeley.com/datasets/db2zgbxwmj       NaN      1
# 26250  https://data.mendeley.com/datasets/h6trntnthr       NaN      1
# 33970  https://data.mendeley.com/datasets/n3y4czk55y       NaN      1
# 15501             https://doi.org/10.7910/DVN/2TAGUY       NaN      1
# 48699             https://doi.org/10.7910/DVN/LFZEVI       NaN      1

# %%
training_data['Name_Description'] = training_data['Name'].str.cat(training_data['Description'], sep=' - ')
training_data
# Out:
#                                 _id        Date  \
# 3147            Mendeley_3k6zwrktsd  2020-03-09
# 44407           Mendeley_v852rn2mv6  2022-01-05
# 20511           Mendeley_db52syhgr8  2019-09-22
# 32425  Dataverse_10.7910_DVN_E2XIRQ  2020-12-05
# 33454  Dataverse_10.7910_DVN_EKHTI6  2021-10-25
# 32174  Dataverse_10.7910_DVN_DXXA2N  2020-02-06
# 17807           Mendeley_bx3c6yvrjs  2020-11-20
# 20507           Mendeley_db2zgbxwmj  2023-06-27
# 26250           Mendeley_h6trntnthr  2023-04-05
# 33970           Mendeley_n3y4czk55y  2023-05-08
# 15501  Dataverse_10.7910_DVN_2TAGUY  2021-04-01
# 48699  Dataverse_10.7910_DVN_LFZEVI  2020-03-17
#
#                                              Description  \
# 3147   Xiong, Q. L., Luo, X.J., Xiao, Y., Liang, P.H....
# 44407  The dataset contains perceptions of Vietnamese...
# 20511  African map showing the investigated countries...
# 32425  TIAS 11-909 First signed 09/09/2011 Last signe...
# 33454  “Review of Economics and Statistics: Forthcomi...
# 32174  Data and codebooks from the project ""Rural In...
# 17807  Wethrift helps shoppers save millions of dolla...
# 20507  Cara Hack IG,  Hack Instagram Twitter Tiktok O...
# 26250  Cara Hack FB - Android iPhone 2023. Yaitu meng...
# 33970  1. UiPath\nPATH\n\nUiPath is a global software...
# 15501  Do you want to buy Julva cream at discount pri...
# 48699  Here is the latest discount code for Power Sug...
#
#       includedInDataCatalog  \
# 3147               Mendeley
# 44407              Mendeley
# 20511              Mendeley
# 32425     Harvard Dataverse
# 33454     Harvard Dataverse
# 32174     Harvard Dataverse
# 17807              Mendeley
# 20507              Mendeley
# 26250              Mendeley
# 33970              Mendeley
# 15501     Harvard Dataverse
# 48699     Harvard Dataverse
#
#                                                     Name  \
# 3147   Data from: Fire from policy, human interventio...
# 44407  Vietnamese teachers' perceptions of the implem...
# 20511  Figure 1. African map showing the investigated...
# 32425  Executive Agreements Database, Statement Conce...
# 33454  Replication Data for: Spending Response to a P...
# 32174  Rural Institutional Innovation: Can Village Co...
# 17807                                  macys coupon code
# 20507                        Cara Hack IG Mudah Lewat HP
# 26250                 Cara Hack FB - Android iPhone 2023
# 33970                                     RPA stock data
# 15501  Data of Julva Discount Coupon for Dr Anna cabe...
# 48699  Replication Data for: Power Suggest Pro Coupon...
#
#                                                  URL  Abstract  Label  \
# 3147   https://data.mendeley.com/datasets/3k6zwrktsd       NaN      1
# 44407  https://data.mendeley.com/datasets/v852rn2mv6       NaN      1
# 20511  https://data.mendeley.com/datasets/db52syhgr8       NaN      1
# 32425             https://doi.org/10.7910/DVN/E2XIRQ       NaN      1
# 33454             https://doi.org/10.7910/DVN/EKHTI6       NaN      1
# 32174             https://doi.org/10.7910/DVN/DXXA2N       NaN      1
# 17807  https://data.mendeley.com/datasets/bx3c6yvrjs       NaN      1
# 20507  https://data.mendeley.com/datasets/db2zgbxwmj       NaN      1
# 26250  https://data.mendeley.com/datasets/h6trntnthr       NaN      1
# 33970  https://data.mendeley.com/datasets/n3y4czk55y       NaN      1
# 15501             https://doi.org/10.7910/DVN/2TAGUY       NaN      1
# 48699             https://doi.org/10.7910/DVN/LFZEVI       NaN      1
#
#                                         Name_Description
# 3147   Data from: Fire from policy, human interventio...
# 44407  Vietnamese teachers' perceptions of the implem...
# 20511  Figure 1. African map showing the investigated...
# 32425  Executive Agreements Database, Statement Conce...
# 33454  Replication Data for: Spending Response to a P...
# 32174  Rural Institutional Innovation: Can Village Co...
# 17807  macys coupon code - Wethrift helps shoppers sa...
# 20507  Cara Hack IG Mudah Lewat HP - Cara Hack IG,  H...
# 26250  Cara Hack FB - Android iPhone 2023 - Cara Hack...
# 33970  RPA stock data - 1. UiPath\nPATH\n\nUiPath is ...
# 15501  Data of Julva Discount Coupon for Dr Anna cabe...
# 48699  Replication Data for: Power Suggest Pro Coupon...

# %%
X, y = training_data['Name_Description'], training_data['Label']

# %%
X=[x[0] for x in np.vstack(X).astype(str)]
y=np.vstack(y).astype(int)

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')

# %%
class TextDataset(Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

encodings = tokenizer(X, padding=True, truncation=True, max_length=512, return_tensors='pt')
dataset = TextDataset(encodings, y)

training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64,
    warmup_steps=500,
    weight_decay=0.01,
    report_to="wandb"
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset
)

trainer.train()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: zubairqazi. Use `wandb login --relogin` to force relogin
# wandb version 0.17.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.3
# Run data is saved locally in <code>/home/zqazi/NDE-GPT/test_notebooks/wandb/run-20240617_104351-r0nijv7v</code>
# Syncing run <strong><a href='https://wandb.ai/zubairqazi/NDE%20GPT/runs/r0nijv7v' target="_blank">laced-sea-3</a></strong> to <a href='https://wandb.ai/zubairqazi/NDE%20GPT' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/zubairqazi/NDE%20GPT' target="_blank">https://wandb.ai/zubairqazi/NDE%20GPT</a>
#  View run at <a href='https://wandb.ai/zubairqazi/NDE%20GPT/runs/r0nijv7v' target="_blank">https://wandb.ai/zubairqazi/NDE%20GPT/runs/r0nijv7v</a>
# /tmp/ipykernel_1352938/2994206815.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
